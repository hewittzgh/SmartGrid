# %%
# -*- coding: utf-8 -*-
# @Time: 2022/2/20 11:58
# @Author: Gonghao Zhang
# @Email: hewittzgh@gmail.com
# @File: DAPplace.ipynb
# @Software: JupyterLab

# %%
import math
import copy
import time
import random
import numpy as np
import networkx as nx
import gurobipy as gp
from gurobipy import GRB
from scipy import spatial
from sklearn import cluster
import matplotlib.pyplot as plt
from networkx.algorithms import bipartite
import sklearn_extra.cluster as ex_cluster
from sklearn.metrics import pairwise_distances

# %%
# define the decorator decorator to calculate the running time of the function
def decorator_with_param(name):
    def run_time(func):
        def warp(*args, **kwargs):
            t_start = time.perf_counter()
            ret = func(*args, **kwargs)
            t_end = time.perf_counter()
            print("[INFO] " + name + " function run time: " + "%f" % (t_end - t_start))
            return ret
        return warp
    return run_time

# %%
class HeuristicApproach(object):
    """HeuristicApproach class implements a heuristic optimization method for DAP placement
    Attributes:
        rho: density of smart meter                                default = 2000              (SMs/km^2)              [float]
        A: area                                                    default = 4                 (km^2)                  [float]
        N_POLE: the number of Poles                                default = 2500                                      [int]
        N_MAX_SP: the maximal number of SMs per DAP                default = 2000                                      [int]
        N_MAX_SS: the maximal number of SMs per relay SM           default = 10                                        [int]
        D_MAX: maximum communication distance                      default = 100               (m)                     [float]
        a: unit price of DAP                                       default = 2000              (dollar)                [float]
        b: the transmission cost for one SM per unit path loss     default = 2.53e-10          (dollar)                [float]
        c: delay cost per unit path                                default = 5                 (dollar)                [float]
        PL0: the initial expected path loss over distance dij      default = 43                (dB)                    [float]
        d0: unit distance                                          default = 1                 (m)                     [float]
        alpha: PL proportional power                               default = 3                                         [float]
        DRAW_CONTROL: drawing or not                               default = False                                     [bool]
        DRAW_NODE_SIZE: node size to draw                          default = 1                                         [float]
        DRAW_EDGE_WIDTH: edge width to draw                        default = 0.01                                      [float]
        ILP_INFO: printing ILP info or not                         default = False                                     [bool]
    """
    
    def __init__(self, 
                 rho = 2000, A = 4, N_POLE = 2500, N_MAX_SP = 2000, N_MAX_SS = 5, D_MAX = 200, 
                 a = 2000, b = 2.53e-10, c = 5, PL0 = 43, d0 = 1, alpha = 3, 
                 DRAW_CONTROL = False, DRAW_NODE_SIZE = 1, DRAW_EDGE_WIDTH = 0.01, ILP_INFO = False):
        """Inits HeuristicApproach class with preset value."""
        
        # define parameter
        self.PARAM_rho              = rho                                         # density of smart meter
        self.PARAM_A                = A                                           # area
        self.PARAM_N_POLE           = N_POLE                                      # the number of Poles
        self.PARAM_N_MAX_SP         = N_MAX_SP                                    # the maximal number of SMs per DAP
        self.PARAM_N_MAX_SS         = N_MAX_SS                                    # the maximal number of SMs per relay SM
        self.PARAM_D_MAX            = D_MAX                                       # maximum communication distanc
        self.PARAM_a                = a                                           # unit price of DAP
        self.PARAM_b                = b                                           # the transmission cost for one SM per unit path loss
        self.PARAM_c                = c                                           # delay cost per unit path
        self.PARAM_PL0              = PL0                                         # the initial expected path loss over distance dij
        self.PARAM_d0               = d0                                          # unit distance
        self.PARAM_alpha            = alpha                                       # PL proportional power

        self.DRAW_CONTROL           = DRAW_CONTROL                                # drawing or not
        self.DRAW_NODE_SIZE         = DRAW_NODE_SIZE                              # node size to draw
        self.DRAW_EDGE_WIDTH        = DRAW_EDGE_WIDTH                             # edge width to draw
        self.ILP_INFO               = ILP_INFO                                    # print ILP info or not
        
        self.N_SM                   = int(self.PARAM_rho * self.PARAM_A)          # the number of SMs
        self.AREA_RANGE             = 1000 * math.sqrt(self.PARAM_A)              # m
        self.RETURN_STEP1           = False                                       # indicates whether the first step needs to be returned
        
        # define variables
        self.sm_nodes_index                    = []                               # smart meters nodes index
        self.sm_nodes_pos_list                 = []                               # smart meters nodes position list
        self.sm_nodes_pos                      = {}                               # smart meters nodes position
        self.pole_nodes_index                  = []                               # pole nodes index
        self.pole_nodes_pos_list               = []                               # pole nodes position list
        self.pole_nodes_pos                    = {}                               # pole nodes position
        
    def InitializeCleanEnvironment(self):
        """Initialize a clean running environment."""
        
        self.K                      = math.ceil(self.N_SM / self.PARAM_N_MAX_SP)  # the number of initial clusters
        self.RETURN_STEP1           = False                                       # indicates whether the first step needs to be returned
        
        # define variables
        self.old_cluster_centers_index         = []                               # old clustering centers index
        self.new_cluster_centers_index         = []                               # new clustering centers index
        self.cluster_centers_pos_list          = []                               # clustering centers position list
        self.cluster_center_sm_edges           = []                               # old clustering center -> its smart meter edge
        self.old_bipartite_center_pole_edges   = []                               # old edge of cluster center pointing to pole in bipartite
        self.new_bipartite_center_pole_edges   = []                               # new edge of cluster center pointing to pole in bipartite
        self.old_selected_pole_index           = []                               # old pole selected to place DAP index
        self.new_selected_pole_index           = []                               # new pole selected to place DAP index
        self.old_selected_pole_pos             = {}                               # old pole selected to place DAP position
        self.new_selected_pole_pos             = {}                               # new pole selected to place DAP position
        
        if self.DRAW_CONTROL:
            
            self.cluster_centers_pos                      = {}                        # clustering centers position
            self.old_cluster_sm_nodes_color               = []                        # old smart meter node color belonging to different cluster
            self.new_cluster_sm_nodes_color               = []                        # new smart meter node color belonging to different cluster
            self.old_bipartite_cluster_centers_pos        = {}                        # old cluster centers position in bipartite layout
            self.new_bipartite_cluster_centers_pos        = {}                        # new cluster centers position in bipartite layout
            self.old_bipartite_poles_pos                  = {}                        # old poles position in bipartite layout
            self.new_bipartite_poles_pos                  = {}                        # new poles position in bipartite layout
            self.old_bipartite_match_poles_pos            = {}                        # old matched poles position in bipartite layout
            self.new_bipartite_match_poles_pos            = {}                        # new matched poles position in bipartite layout
            self.old_bitpartite_match_edges               = []                        # old cluster centers to matched poles edges
            self.new_bitpartite_match_edges               = []                        # new cluster centers to matched poles edges
            
        self.tol                               = 1e-4                             # convergence tolerance
        self.old_cost                          = float('inf')                     # K cost
        self.new_cost                          = 0                                # K + 1 cost
        self.old_installation_cost             = 0                                # K installation cost
        self.new_installation_cost             = 0                                # K + 1 installation cost
        self.old_routing_cost                  = 0                                # K routing cost
        self.new_routing_cost                  = 0                                # K + 1 routing cost   
        self.old_routing                       = {}                               # K routing
        self.new_routing                       = {}                               # K + 1 routing
        self.Iter                              = 0                                # the number of iterations
        self.Iter_index                        = []                               # with the iteration of index
        self.Iter_installation_cost            = []                               # with the iteration of installation cost
        self.Iter_transmission_cost            = []                               # with the iteration of transmission cost
        self.Iter_delay_cost                   = []                               # with the iteration of delay cost
        
        # define Graphs for operating
        self.G = nx.DiGraph()                                                      # overall graph
        self.B = nx.DiGraph()                                                      # bipartite graph for minimum weight matching
        
        # setting the gurobipy ILP environment
        self.env = gp.Env(empty = True)
        self.env.setParam('OutputFlag', self.ILP_INFO)
        self.env.start()
        
    def ManualChangeParameter(self, N_MAX_SS = None, D_MAX = None, c = None, alpha = None):
        """Manual Change parameters to compare results.
        Attributes:
            N_MAX_SS
            D_MAX
            c
            alpha
        """
        
        if N_MAX_SS != None:
            self.PARAM_N_MAX_SS = N_MAX_SS
            
        if D_MAX != None:
            self.PARAM_D_MAX = D_MAX
            
        if c != None:
            self.PARAM_c = c
            
        if alpha != None:
            self.PARAM_alpha = alpha
        
    def GetSimData(self):
        """Generates simulation data."""
        
        self.sm_nodes_index.clear()
        self.sm_nodes_pos_list.clear()
        self.sm_nodes_pos.clear()
        self.pole_nodes_index.clear()
        self.pole_nodes_pos_list.clear()
        self.pole_nodes_pos.clear()
        
        sm_coor   = np.random.randint(- self.AREA_RANGE / 2, self.AREA_RANGE / 2 + 1, size = (self.N_SM, 2))
        pole_coor = np.random.randint(- self.AREA_RANGE / 2, self.AREA_RANGE / 2 + 1, size = (self.PARAM_N_POLE, 2))
        
        for index, pos in enumerate(sm_coor):
            sm_name = 's' + str(index + 1)
            sm_pos  = pos.tolist()
            self.sm_nodes_index.append(sm_name)
            self.sm_nodes_pos_list.append(sm_pos)
            self.sm_nodes_pos[sm_name] = sm_pos
            
        for index, pos in enumerate(pole_coor):
            pole_name = 'p' + str(index + 1)
            pole_pos  = pos.tolist()
            self.pole_nodes_index.append(pole_name)
            self.pole_nodes_pos_list.append(pole_pos)
            self.pole_nodes_pos[pole_name] = pole_pos
        
    def DisCutoff(self, x, y):
        """Cutoff distance compute for pairwise_distances."""
        M = math.pow(self.AREA_RANGE, 10) # very large number
        X = np.vstack([x, y])
        dis = spatial.distance.pdist(X)
        if dis > self.PARAM_D_MAX:
            dis = M * dis
        return dis
    
    def DisEnergy(self, x, y):
        """Energy distance compute for pairwise_distances."""
        X = np.vstack([x, y])
        dis = spatial.distance.pdist(X)
        d = self.PARAM_b * self.PL(dis)
        return d
    
    def DisCutoffEnergy(self, x, y):
        """Cutoff-Energy distance compute for pairwise_distances."""
        M = math.pow(self.AREA_RANGE, 10) # very large number
        X = np.vstack([x, y])
        dis = spatial.distance.pdist(X)
        d = self.PARAM_b * self.PL(dis)
        if dis > self.PARAM_D_MAX:
            d = M * d
        return d
            
    @decorator_with_param('KmeansClustering')
    def KmeansClustering(self, cluster_data):
        """KMeans clustering method.
        Attributes:
            cluster_data: data for KMeans clustering                          [np.array]
        Returns:
            labels: clustering labels                                         [np.array]
            centers: clustering centers                                       [np.array]
        """
        
        kmeans = cluster.KMeans(n_clusters = self.K, random_state = 0).fit(cluster_data)
        return kmeans.labels_, kmeans.cluster_centers_
    
    @decorator_with_param('MiniBatchKmeansClustering')
    def MiniBatchKmeansClustering(self, cluster_data, batch_size = 1024):
        """Mini-Batch KMeans clustering method.
        Attributes:
            cluster_data: data for mini-batch KMeans clustering               [np.array]
            batch_size: size of the mini batches
                        default: 1024
                        recommend: batch_size >= 256 * number of cores        [int]
        Returns:
            labels: clustering labels                                         [np.array]
            centers: clustering centers                                       [np.array]
        """
        
        minibatchkmeans = cluster.MiniBatchKMeans(n_clusters = self.K, random_state = 0, batch_size = batch_size).fit(cluster_data)
        return minibatchkmeans.labels_, minibatchkmeans.cluster_centers_
    
    @decorator_with_param('KMedoidsClustering')
    def KMedoidsClustering(self, distance_matrix):
        """KMedoids clustering method.
        Attributes:
            distance_matrix: precomputed distance matrix                      [np.ndarray]
        Returns:
            labels: clustering labels                                         [np.array]
            centers: clustering centers                                       [np.array]
        """
        
        kmedoids = ex_cluster.KMedoids(n_clusters = self.K, metric = 'precomputed', random_state = 0).fit(distance_matrix)
        
        cluster_centers_ = []
        for k in range(self.K):
            k_index = [index for index, label in enumerate(kmedoids.labels_) if label == k]
            k_pos_x = 0
            k_pos_y = 0
            for i in k_index:
                k_pos_x += self.sm_nodes_pos_list[i][0]
                k_pos_y += self.sm_nodes_pos_list[i][1]
            k_pos_x = k_pos_x / len(k_index)
            k_pos_y = k_pos_y / len(k_index)
            cluster_centers_.append(np.array([k_pos_x, k_pos_y]))
            
        return kmedoids.labels_, cluster_centers_
    
    @decorator_with_param('SpectralClustering')
    def SpectralClustering(self, distance_matrix):
        """Spectral clustering method.
        Attributes:
            distance_matrix: precomputed distance matrix                      [np.ndarray]
        Returns:
            labels: clustering labels                                         [np.array]
            centers: clustering centers                                       [np.array]
        """
        
        spectral = cluster.SpectralClustering(n_clusters = self.K, random_state = 0, affinity = 'precomputed').fit(distance_matrix)
        
        cluster_centers_ = []
        for k in range(self.K):
            k_index = [index for index, label in enumerate(spectral.labels_) if label == k]
            k_pos_x = 0
            k_pos_y = 0
            for i in k_index:
                k_pos_x += self.sm_nodes_pos_list[i][0]
                k_pos_y += self.sm_nodes_pos_list[i][1]
            k_pos_x = k_pos_x / len(k_index)
            k_pos_y = k_pos_y / len(k_index)
            cluster_centers_.append(np.array([k_pos_x, k_pos_y]))
            
        return spectral.labels_, cluster_centers_
    
    @decorator_with_param('AgglomerativeClustering')
    def AgglomerativeClustering(self, distance_matrix):
        """Agglomerative clustering method.
        Attributes:
            distance_matrix: precomputed distance matrix                      [np.ndarray]
        Returns:
            labels: clustering labels                                         [np.array]
            centers: clustering centers                                       [np.array]
        """
        
        agglomerative = cluster.AgglomerativeClustering(n_clusters = self.K, affinity = 'precomputed', linkage = 'complete').fit(distance_matrix)
        
        cluster_centers_ = []
        for k in range(self.K):
            k_index = [index for index, label in enumerate(agglomerative.labels_) if label == k]
            k_pos_x = 0
            k_pos_y = 0
            for i in k_index:
                k_pos_x += self.sm_nodes_pos_list[i][0]
                k_pos_y += self.sm_nodes_pos_list[i][1]
            k_pos_x = k_pos_x / len(k_index)
            k_pos_y = k_pos_y / len(k_index)
            cluster_centers_.append(np.array([k_pos_x, k_pos_y]))
            
        return agglomerative.labels_, cluster_centers_
    
    def PL(self, distance):
        """Compute PL value of dij.
        Attributes:
            distance: the distance between node i and node j                  [float]
        Returns:
            plvalue: the PL value of dij                                      [float]
        """
        
        plvalue = self.PARAM_PL0 * math.pow(distance / self.PARAM_d0, self.PARAM_alpha)
        return plvalue
    
    @decorator_with_param('MiniWeightMatching')
    def MiniWeightMatching(self, weight='weight'):
        """Minimum weight matching.
        Attributes:
            weight: the edge data key used to provide each value
                    default: 'weight'                                         [string]
        Returns:
            mwm: minimum weight matching result                               [python.dictionary]
        """
        
        mwfm = bipartite.minimum_weight_full_matching(self.B, weight=weight)
        return mwfm
    
    @decorator_with_param("ILP")
    def ILP(self, edges, Beta, nodes_index, source_node, target_node):
        """Integer linear programming.
        Attributes:
            edges: indices for accessing the graph edges variables            [gurobipy.tuplelist]
            Beta: objective coefficient(s) for graph edges variables          [gurobipy.tupledict]
            nodes_index: smart meter nodes index in graph                     [python.list]
        Returns:
            routing: routing path                                             [python.dictionary]
            routing_cost: routing cost                                        [float]
        """
        
        routing = {}
        routing_cost = 0
        
        # Create optimization model
        m = gp.Model(env = self.env, name = 'netflow')

        # Create variables
        flow = m.addVars(edges, lb = 0, obj = Beta, vtype = GRB.INTEGER, name = "flow")

        # constraints 26
        m.addConstrs((flow[i, j] == 1 for i, j in edges.select(source_node, '*')), "constraints_26")

        # Flow-conservation constraints 27
        m.addConstrs((flow.sum(i, '*') == flow.sum('*', i) for i in nodes_index), "constraints_27")

        # constraints 28
        m.addConstr(flow.sum('*', target_node) == len(nodes_index), "constraints_28")

        # constraints 29
        m.addConstrs((flow.sum('*', i) <= self.PARAM_N_MAX_SS for i in nodes_index), "constraints_29")

        # Compute optimal solution
        m.optimize()
        
        if m.Status == GRB.INFEASIBLE:
            self.K += 1
            m.dispose()
            self.RETURN_STEP1 = True
        elif m.Status == GRB.OPTIMAL:
            routing_cost = m.ObjVal
            routing = m.getAttr('X', flow)
            m.dispose()
            self.RETURN_STEP1 = False

        return routing, routing_cost
    
    def ClearILPEnv(self):
        """Clear ILP environment."""
        self.env.dispose()
    
    def OurHeuristic(self, clustering_type = 'kmeans', custom_metric = 'eu'):
        """The concrete implementation of our Heuristic Approach.
        Attributes:
            clustering_type: clustering algorithm used
                             default: 'kmeans'                                 
                             support: 'kmeans' 'minibatchkmeans' 'kmedoids' 'spectral' 'agglomerative'     [string]
            custom_metric: custom metrics, including 'eu', 'en', 'ct', 'cte'
                            'eu': euclidean
                            'en': energy
                            'ct': cutoff
                            'cte': cutoff-energy                                                           [string]
        """
        
        if clustering_type == 'kmeans' or clustering_type == 'minibatchkmeans':
            if custom_metric != 'eu':
                print("[ERROR] " + "'kmeans' or 'minibatchkmeans' does not support this input distance type.")
                return -1
        elif clustering_type == 'kmedoids' or clustering_type == 'spectral' or clustering_type =='agglomerative':
            if custom_metric == 'eu':
                print("[INFO] generating distance matrix for", clustering_type, "and", custom_metric, "...")
                distance_matrix = pairwise_distances(np.array(self.sm_nodes_pos_list), metric = 'euclidean')

            elif custom_metric == 'en':
                print("[INFO] generating distance matrix for", clustering_type, "and", custom_metric, "...")
                distance_matrix = pairwise_distances(np.array(self.sm_nodes_pos_list), metric = self.DisEnergy)

            elif custom_metric == 'ct':
                print("[INFO] generating distance matrix for", clustering_type, "and", custom_metric, "...")
                distance_matrix = pairwise_distances(np.array(self.sm_nodes_pos_list), metric = self.DisCutoff)

            elif custom_metric == 'cte':
                print("[INFO] generating distance matrix for", clustering_type, "and", custom_metric, "...")
                distance_matrix = pairwise_distances(np.array(self.sm_nodes_pos_list), metric = self.DisCutoffEnergy)

            else:
                print("[ERROR] " + "'kmedoids' or 'spectral' or 'agglomerative' does not support this input distance type.")
                return -1
        else:
            print("[ERROR] " + "the set clustering method is not supported.")
            return -1

        self.G.add_nodes_from(self.sm_nodes_index)
        self.G.add_nodes_from(self.pole_nodes_index)
        
        if self.DRAW_CONTROL:
            
            # %matplotlib qt5
            # Set subplots and axes
            fig, ax = plt.subplots(2, 2, figsize=(20, 20))
            plt.subplots_adjust(left=0.05, bottom=0.05, top=0.95, right=0.95, hspace=0.2, wspace=0.1)
            ax[0][0].set_title("Smart Meters and Poles Distribution Map")
            ax[0][1].set_title("Heuristic Approach Visualization")
            ax[1][0].set_title("Assign Cluster Centers Bipartite")
            ax[1][1].set_title("Cost Optimization and Contributions")
            
        if self.DRAW_CONTROL:
            
            # set canvas and axis
            ax[0][0].set_xlim([-self.AREA_RANGE/2 - self.AREA_RANGE/30, self.AREA_RANGE/2 + self.AREA_RANGE/30])
            ax[0][0].set_ylim([-self.AREA_RANGE/2 - self.AREA_RANGE/30, self.AREA_RANGE/2 + self.AREA_RANGE/30])
            
            # set drawing options for the graph
            sm_nodes_draw_options = {
                "ax":            ax[0][0], 
                "pos":           self.sm_nodes_pos, 
                "nodelist":      self.sm_nodes_index, 
                "node_color":    "blue", 
                "node_size":     self.DRAW_NODE_SIZE, 
                "node_shape":    'o',
                "label":         "Smart Meters Nodes"
            }
            pole_nodes_draw_options = {
                "ax":            ax[0][0], 
                "pos":           self.pole_nodes_pos, 
                "nodelist":      self.pole_nodes_index, 
                "node_color":    "red", 
                "node_size":     self.DRAW_NODE_SIZE, 
                "node_shape":    '^', 
                "label":         "Pole Nodes"
            }
            
            # Draw
            nx.draw_networkx_nodes(self.G, **sm_nodes_draw_options)
            nx.draw_networkx_nodes(self.G, **pole_nodes_draw_options)
            
            # Draw Settings
            ax[0][0].legend(loc = 'lower right')
            ax[0][0].set_title("Smart Meters and Poles Distribution Map")
            ax[0][0].tick_params(left = True, bottom = True, labelleft = True, labelbottom = True)
            
            plt.pause(0.1)
        
        while True:
            
            print("[ITERATION] " + "Start iteration " + str(self.Iter + 1) + " ... ")
            
            # Step 1: cluster dataset with K centers
            
            if clustering_type == 'kmeans':
                cluster_labels, cluster_centers = self.KmeansClustering(np.array(self.sm_nodes_pos_list))
                
            elif clustering_type == 'minibatchkmeans':
                cluster_labels, cluster_centers = self.MiniBatchKmeansClustering(np.array(self.sm_nodes_pos_list))
                
            elif clustering_type == 'kmedoids':
                cluster_labels, cluster_centers = self.KMedoidsClustering(distance_matrix)
            
            elif clustering_type == 'spectral':
                cluster_labels, cluster_centers = self.SpectralClustering(distance_matrix)
            
            elif clustering_type == 'agglomerative':
                cluster_labels, cluster_centers = self.AgglomerativeClustering(distance_matrix)
                
            # analysis of clustering results
            self.new_cluster_centers_index.clear()
            self.cluster_centers_pos_list.clear()
            if self.DRAW_CONTROL:
                self.cluster_centers_pos.clear()
            
            for index, pos in enumerate(cluster_centers):
                cluster_center_name = 'c' + str(index + 1)
                cluster_center_pos  = pos.tolist()
                self.new_cluster_centers_index.append(cluster_center_name)
                self.cluster_centers_pos_list.append(cluster_center_pos)
                if self.DRAW_CONTROL:
                    self.cluster_centers_pos[cluster_center_name] = cluster_center_pos
                
            self.cluster_center_sm_edges.clear()
            for index, label in enumerate(cluster_labels):
                self.cluster_center_sm_edges.append(('c' + str(label + 1), 's' + str(index + 1)))
                
            self.G.add_nodes_from(self.new_cluster_centers_index)
            self.G.add_edges_from(self.cluster_center_sm_edges)
            
            if self.DRAW_CONTROL:
                
                # defines the function to get the cluster color map (hexadecimal)
                gen_colors = lambda n: list(map(lambda i: "#" + "%06x" % random.randint(0, 0xFFFFFF), range(n)))
                color_map = gen_colors(self.K) # for example, return ['#8fa420', '#82bdeb', '#7f3c17', '#bcf4c4']
                
                self.new_cluster_sm_nodes_color.clear()
                for i in cluster_labels:
                    self.new_cluster_sm_nodes_color.append(color_map[i])
                    
                ax[0][1].cla()
                # set canvas and axis
                ax[0][1].set_xlim([-self.AREA_RANGE/2 - self.AREA_RANGE/30, self.AREA_RANGE/2 + self.AREA_RANGE/30])
                ax[0][1].set_ylim([-self.AREA_RANGE/2 - self.AREA_RANGE/30, self.AREA_RANGE/2 + self.AREA_RANGE/30])
            
                # set drawing options for the graph
                cluster_sm_nodes_draw_options = {
                    "ax":            ax[0][1], 
                    "pos":           self.sm_nodes_pos, 
                    "nodelist":      self.sm_nodes_index, 
                    "node_size":     self.DRAW_NODE_SIZE, 
                    "node_color":    self.new_cluster_sm_nodes_color, 
                    "node_shape":    'o', 
                    "label":         "Smart Meters of Different Clusters"
                }
                cluster_centers_draw_options = {
                    "ax":            ax[0][1], 
                    "pos":           self.cluster_centers_pos, 
                    "nodelist":      self.new_cluster_centers_index, 
                    "node_size":     10 * self.DRAW_NODE_SIZE, 
                    "node_color":    "red", 
                    "node_shape":    'o', 
                    "label":         "Clustering Centers"
                }
                cluster_center_sm_edges_draw_options = {
                    "ax":            ax[0][1], 
                    "pos":           dict(**self.cluster_centers_pos, **self.sm_nodes_pos), 
                    "edgelist":      self.cluster_center_sm_edges, 
                    "width":         2 * self.DRAW_EDGE_WIDTH, 
                    "edge_color":    "black", 
                    "style":         'solid', 
                    "arrows":        False, 
                    "label":         "Smart Meters to Clustering Center Edges"
                }
                
                # Draw
                nx.draw_networkx_nodes(self.G, **cluster_sm_nodes_draw_options)
                nx.draw_networkx_nodes(self.G, **cluster_centers_draw_options)
                nx.draw_networkx_edges(self.G, **cluster_center_sm_edges_draw_options)
                
                # Draw Settings
                ax[0][1].legend(loc = 'lower right')
                ax[0][1].set_title("Heuristic Approach Visualization")
                ax[0][1].text(0.01, 0.95, "K = " + str(self.K), transform=ax[0][1].transAxes, 
                              fontdict={'size': '10', 'color': 'black', 'weight': 'bold'})
                ax[0][1].tick_params(left = True, bottom = True, labelleft = True, labelbottom = True)

                # 0.1s pause to display
                plt.pause(0.1)
            
            # constraint 15
            for cc in self.new_cluster_centers_index:
                if self.G.out_degree(cc) > self.PARAM_N_MAX_SP:
                    # constraint 15 violated
                    self.K += 1
                    self.RETURN_STEP1 = True
                    break
                    
            if self.RETURN_STEP1:
                self.RETURN_STEP1 = False
                self.G.remove_edges_from(self.cluster_center_sm_edges)
                self.G.remove_nodes_from(self.new_cluster_centers_index)
                continue
                
            # Step 2: assign clustering centers to poles
            disM = spatial.distance_matrix(self.cluster_centers_pos_list, self.pole_nodes_pos_list)
            self.new_bipartite_center_pole_edges.clear()
            for i, c_name in enumerate(self.new_cluster_centers_index):
                for j, p_name in enumerate(self.pole_nodes_index):
                    w = (disM[[i], [j]])[0]
                    self.new_bipartite_center_pole_edges.append((c_name, p_name, {'weight': w}))
                    
            self.B.add_nodes_from(self.new_cluster_centers_index, bipartite = 0)
            self.B.add_nodes_from(self.pole_nodes_index, bipartite = 1)
            self.B.add_edges_from(self.new_bipartite_center_pole_edges)
            
            # minimum weight matching
            mwfmresult = self.MiniWeightMatching(weight='weight')
            mwmresult  = dict([(key, mwfmresult[key]) for key in self.new_cluster_centers_index])
            self.new_selected_pole_index  = [m for m in mwmresult.values()]
            
            self.new_selected_pole_pos.clear()
            for i in self.new_selected_pole_index:
                self.new_selected_pole_pos[i] = self.pole_nodes_pos[i]
            
            if self.DRAW_CONTROL:
                
                bottom_nodes, top_nodes = bipartite.sets(self.B)
                
                bitpartite_nodes_pos    = nx.bipartite_layout(self.B, bottom_nodes)
                
                self.new_bipartite_cluster_centers_pos = dict([(key, bitpartite_nodes_pos[key]) for key in bottom_nodes])
                self.new_bipartite_poles_pos           = dict([(key, bitpartite_nodes_pos[key]) for key in top_nodes])
                self.new_bipartite_match_poles_pos     = dict([(key, bitpartite_nodes_pos[key]) for key in mwmresult.values()])
                
                self.new_bitpartite_match_edges.clear()
                for i in mwmresult.keys():
                    self.new_bitpartite_match_edges.append((i, mwmresult[i]))
                    
                # Set drawing options for the graph
                bipartite_cluster_centers_draw_options = {
                    "ax": ax[1][0], 
                    "pos": self.new_bipartite_cluster_centers_pos, 
                    "nodelist": bottom_nodes, 
                    "node_size": 10 * self.DRAW_NODE_SIZE, 
                    "node_color": "red", 
                    "node_shape": 'o', 
                    "label": "Clustering Center Node"
                }
                bipartite_poles_draw_options = {
                    "ax": ax[1][0], 
                    "pos": self.new_bipartite_poles_pos, 
                    "nodelist": top_nodes, 
                    "node_size": self.DRAW_NODE_SIZE, 
                    "node_color": "red", 
                    "node_shape": '^', 
                    "label": "Pole Node"
                }
                bipartite_match_poles_draw_options = {
                    "ax": ax[1][0], 
                    "pos": self.new_bipartite_match_poles_pos, 
                    "nodelist": self.new_selected_pole_index, 
                    "node_size": 10 * self.DRAW_NODE_SIZE, 
                    "node_color": "green", 
                    "node_shape": '^', 
                    "label": "Assigned Pole Node (place DAP)"
                }
                bipartite_common_edges_draw_options = {
                    "ax": ax[1][0], 
                    "pos": dict(**self.new_bipartite_cluster_centers_pos, **self.new_bipartite_poles_pos), 
                    "edgelist": self.new_bipartite_center_pole_edges, 
                    "width": self.DRAW_EDGE_WIDTH, 
                    "edge_color": "grey", 
                    "arrows": False
                }
                bipartite_match_edges_draw_options = {
                    "ax": ax[1][0], 
                    "pos": dict(**self.new_bipartite_cluster_centers_pos, **self.new_bipartite_match_poles_pos), 
                    "edgelist": self.new_bitpartite_match_edges, 
                    "width": 30 * self.DRAW_EDGE_WIDTH, 
                    "edge_color": "blue", 
                    "arrowsize": 100 * self.DRAW_EDGE_WIDTH, 
                    "arrowstyle": '->'
                }
                
                ax[1][0].cla()
                # Draw
                nx.draw_networkx_nodes(self.B, **bipartite_cluster_centers_draw_options)
                nx.draw_networkx_nodes(self.B, **bipartite_poles_draw_options)
                nx.draw_networkx_nodes(self.B, **bipartite_match_poles_draw_options)
                nx.draw_networkx_edges(self.B, **bipartite_common_edges_draw_options)
                nx.draw_networkx_edges(self.B, **bipartite_match_edges_draw_options)
                
                # Draw Settings
                ax[1][0].legend(loc = 'lower right')
                ax[1][0].set_title("Assign Cluster Centers Bipartite")
                ax[1][0].text(0.01, 0.95, "K = " + str(self.K), transform=ax[1][0].transAxes, 
                              fontdict={'size': '10', 'color': 'black', 'weight': 'bold'})
                
                plt.pause(0.1)
            
            if self.DRAW_CONTROL:
                
                # Set drawing options for the graph
                selected_pole_nodes_draw_options = {
                    "ax": ax[0][1], 
                    "pos": self.new_selected_pole_pos, 
                    "nodelist": self.new_selected_pole_index, 
                    "node_size": 20 * self.DRAW_NODE_SIZE, 
                    "node_color": "yellow", 
                    "node_shape": '^', 
                    "label": "Selected Poles"
                }
                
                # Draw
                nx.draw_networkx_nodes(self.G, **selected_pole_nodes_draw_options)

                # Draw Settings
                ax[0][1].legend(loc = 'lower right')
                ax[0][1].set_title("Heuristic Approach Visualization")
                ax[0][1].text(0.01, 0.95, "K = " + str(self.K), transform=ax[0][1].transAxes, 
                              fontdict={'size': '10', 'color': 'black', 'weight': 'bold'})
                ax[0][1].tick_params(left = True, bottom = True, labelleft = True, labelbottom = True)
                
                plt.pause(0.1)
            
            # Step3: find routing of clusters
            # ergodic clusters
            self.new_routing_cost = 0
            self.new_routing.clear()
            for index, s in enumerate(self.new_cluster_centers_index):
                
                subG_sm_nodes_index    = []
                subG_sm_nodes_pos_list = []
                
                for sm_node_index in self.G.neighbors(s):
                    sm_node_pos = self.sm_nodes_pos[sm_node_index]
                    subG_sm_nodes_index.append(sm_node_index)
                    subG_sm_nodes_pos_list.append(sm_node_pos)
                    
                t = mwmresult[s]
                subG = self.G.subgraph(subG_sm_nodes_index + [s, t])
                
                dis_sm   = spatial.distance_matrix(subG_sm_nodes_pos_list, subG_sm_nodes_pos_list)
                dis_sm_t = spatial.distance_matrix(subG_sm_nodes_pos_list, [self.new_selected_pole_pos[t]])
                
                # get filted distance between sm u and sm v or sm u and dap t
                subG_filted_edges_dict = {}
                for i, sm_u in enumerate(subG_sm_nodes_index):
                    d_ut = (dis_sm_t[[i], [0]])[0]
                    if d_ut <= self.PARAM_D_MAX:
                        subG_filted_edges_dict[sm_u, t] = self.PARAM_b * self.PL(d_ut)
                        for j, sm_v in enumerate(subG_sm_nodes_index):
                            d_uv = (dis_sm[[i], [j]])[0]
                            if j != i and d_uv <= self.PARAM_D_MAX and d_uv < d_ut:
                                subG_filted_edges_dict[sm_u, sm_v] = self.PARAM_b * self.PL(d_uv) + self.PARAM_c
                    else:
                        for j, sm_v in enumerate(subG_sm_nodes_index):
                            d_uv = (dis_sm[[i], [j]])[0]
                            if j != i and d_uv <= self.PARAM_D_MAX:
                                subG_filted_edges_dict[sm_u, sm_v] = self.PARAM_b * self.PL(d_uv) + self.PARAM_c
                                
                for edge in subG.edges():
                    subG_filted_edges_dict[edge] = 0
                    
                subG_edges, Beta = gp.multidict(subG_filted_edges_dict)
                
                self.G.remove_edges_from(subG_edges.select(s, '*'))
                self.G.add_edges_from(subG_edges)
                
                if self.DRAW_CONTROL:
                    
                    # Set drawing options for the graph
                    G_filted_edges_draw_options = {
                        "ax":            ax[0][1], 
                        "pos":           dict(**self.sm_nodes_pos, **self.cluster_centers_pos, **self.new_selected_pole_pos), 
                        "width":         2 * self.DRAW_EDGE_WIDTH, 
                        "edge_color":    "black", 
                        "style":         'solid', 
                        "arrows":        False, 
                        "label":         "filted edges"
                    }
                    
                    ax[0][1].cla()
                    # Set canvas and axis
                    ax[0][1].set_xlim([-self.AREA_RANGE/2 - self.AREA_RANGE/30, self.AREA_RANGE/2 + self.AREA_RANGE/30])
                    ax[0][1].set_ylim([-self.AREA_RANGE/2 - self.AREA_RANGE/30, self.AREA_RANGE/2 + self.AREA_RANGE/30])

                    # Draw
                    nx.draw_networkx_nodes(self.G, **cluster_sm_nodes_draw_options)
                    nx.draw_networkx_nodes(self.G, **cluster_centers_draw_options)
                    nx.draw_networkx_nodes(self.G, **selected_pole_nodes_draw_options)
                    nx.draw_networkx_edges(self.G, **G_filted_edges_draw_options)


                    # Draw Settings
                    ax[0][1].legend(loc = 'lower right')
                    ax[0][1].set_title("Heuristic Approach Visualization")
                    ax[0][1].text(0.01, 0.95, "K = " + str(self.K), transform=ax[0][1].transAxes, 
                              fontdict={'size': '10', 'color': 'black', 'weight': 'bold'})
                    ax[0][1].tick_params(left = True, bottom = True, labelleft = True, labelbottom = True)

                    plt.pause(0.1)
                
                cur_routing, cur_routing_cost = self.ILP(subG_edges, Beta, subG_sm_nodes_index, s, t)
                
                if self.RETURN_STEP1:
                    break
                else:
                    self.new_routing_cost += cur_routing_cost
                    self.new_routing.update(cur_routing)
                    
            if self.RETURN_STEP1:
                self.RETURN_STEP1 = False
                self.G.clear_edges()
                self.G.remove_nodes_from(self.new_cluster_centers_index)
                continue
                
            self.new_installation_cost = self.PARAM_a * self.K
            self.new_cost              = self.new_installation_cost + self.new_routing_cost
            
            
            
            if self.new_cost - self.old_cost > self.tol:
                print("[DESCRIBE] " + "The best routing and lowest cost have been found.", "The minimum cost is " + str(self.old_cost) + ".")
                break
            else:
                print("[OBJECTIVE] " + "old cost: " + str(self.old_cost) + ", new cost: " + str(self.new_cost))
                print("[DESCRIBE] " + "Optimal route and lowest cost not found.")
                
                self.K += 1
                self.Iter += 1
                self.old_cost                          = self.new_cost
                self.old_installation_cost             = self.new_installation_cost
                self.old_routing_cost                  = self.new_routing_cost
                self.old_routing                       = copy.deepcopy(self.new_routing)
                self.old_bipartite_center_pole_edges   = copy.deepcopy(self.new_bipartite_center_pole_edges)
                self.old_selected_pole_index           = copy.deepcopy(self.new_selected_pole_index)
                self.old_selected_pole_pos             = copy.deepcopy(self.new_selected_pole_pos)
                self.old_cluster_centers_index         = copy.deepcopy(self.new_cluster_centers_index)
                
                if self.DRAW_CONTROL:
                    self.old_cluster_sm_nodes_color        = copy.deepcopy(self.new_cluster_sm_nodes_color)
                    self.old_bipartite_cluster_centers_pos = copy.deepcopy(self.new_bipartite_cluster_centers_pos)
                    self.old_bipartite_poles_pos           = copy.deepcopy(self.new_bipartite_poles_pos)
                    self.old_bipartite_match_poles_pos     = copy.deepcopy(self.new_bipartite_match_poles_pos)
                    self.old_bitpartite_match_edges        = copy.deepcopy(self.new_bitpartite_match_edges)
                
                self.G.clear_edges()
                self.G.remove_nodes_from(self.new_cluster_centers_index)
                
                self.Iter_index.append(self.Iter)
                
                self.Iter_installation_cost.append(self.new_installation_cost)
                
                delay_cost = 0
                for edge in self.new_routing.keys():
                    if edge[0] in self.new_cluster_centers_index or edge[1] in self.new_selected_pole_index:
                        pass
                    else:
                        delay_cost += self.PARAM_c * self.new_routing[edge]

                transmission_cost = self.new_routing_cost - delay_cost
                
                self.Iter_transmission_cost.append(transmission_cost)
                
                self.Iter_delay_cost.append(delay_cost)
                
                if self.DRAW_CONTROL:
                    
                    ax[1][1].cla()
                    
                    bottom_delay_cost = []
                    for i in range(len(self.Iter_transmission_cost)):
                        sum = self.Iter_transmission_cost[i] + self.Iter_installation_cost[i]
                        bottom_delay_cost.append(sum)
                    
                    ax[1][1].bar(self.Iter_index, self.Iter_installation_cost, width = 0.35, 
                                 color = 'blue', label = "Installation Cost")
                    ax[1][1].bar(self.Iter_index, self.Iter_transmission_cost, 
                                 bottom = self.Iter_installation_cost, width = 0.35, color = 'orange', label = "Transmission Cost")
                    ax[1][1].bar(self.Iter_index, self.Iter_delay_cost, 
                                 bottom = bottom_delay_cost, width = 0.35, color = 'green', label = "Delay Cost")
                    
                    for index, it in enumerate(self.Iter_index):
                        ax[1][1].text(it - 0.10, self.Iter_installation_cost[index] + self.Iter_transmission_cost[index] + self.Iter_delay_cost[index], 
                                      str(int(self.Iter_installation_cost[index] + self.Iter_transmission_cost[index] + self.Iter_delay_cost[index])))
                    
                    ax[1][1].legend(loc = 'lower right')
                    ax[1][1].set_title("Cost Optimization and Contributions")
                    ax[1][1].set_xlabel("Iterations / times")
                    ax[1][1].set_xlim([0, self.Iter + 1])
                    
                    plt.pause(0.1)
                    
        print("[Result]:", 
              "Installation Cost:", self.Iter_installation_cost[-1], 
              "Transmission Cost:", self.Iter_transmission_cost[-1], 
              "Delay Cost", self.Iter_delay_cost[-1], 
              "Total Cost", self.old_cost)
                
        if self.DRAW_CONTROL:
            
            self.G.clear_edges()
            
            routing_edge = []
            for edge in self.old_routing.keys():
                w_package = self.old_routing[edge]
                if w_package != 0:
                    routing_edge.append((edge[0], edge[1], {'width': w_package}))

            self.G.add_edges_from(routing_edge)
            self.G.remove_nodes_from(self.old_cluster_centers_index)    
            
            # Set drawing options for the graph
            G_cluster_sm_nodes_draw_options = {
                "ax":            ax[0][1], 
                "pos":           self.sm_nodes_pos, 
                "nodelist":      self.sm_nodes_index, 
                "node_size":     self.DRAW_NODE_SIZE, 
                "node_color":    self.old_cluster_sm_nodes_color, 
                "node_shape":    'o', 
                "label":         "Smart Meters of Different Clusters"
            }
            G_selected_pole_nodes_draw_options = {
                "ax":            ax[0][1], 
                "pos":           self.old_selected_pole_pos, 
                "nodelist":      self.old_selected_pole_index, 
                "node_size":     20 * self.DRAW_NODE_SIZE, 
                "node_color":    "yellow", 
                "node_shape":    '^', 
                "label":         "Selected Poles"
            }
            G_routing_edges_draw_options = {
                "ax":            ax[0][1], 
                "pos":           dict(**self.sm_nodes_pos, **self.pole_nodes_pos), 
                "width":         [w[2] * 10 * self.DRAW_EDGE_WIDTH for w in self.G.edges.data('width')], 
                "edge_color":    "black", 
                "style":         'solid', 
                "arrows":        False, 
                "label":         "routing edges"
            }
            
            ax[0][1].cla()
            # Set canvas and axis
            ax[0][1].set_xlim([-self.AREA_RANGE/2 - self.AREA_RANGE/30, self.AREA_RANGE/2 + self.AREA_RANGE/30])
            ax[0][1].set_ylim([-self.AREA_RANGE/2 - self.AREA_RANGE/30, self.AREA_RANGE/2 + self.AREA_RANGE/30])

            # Draw
            nx.draw_networkx_nodes(self.G, **G_cluster_sm_nodes_draw_options)
            nx.draw_networkx_nodes(self.G, **G_selected_pole_nodes_draw_options)
            nx.draw_networkx_edges(self.G, **G_routing_edges_draw_options)

            # Draw Settings
            ax[0][1].legend(loc = 'lower right')
            ax[0][1].set_title("Heuristic Approach Result")
            ax[0][1].text(0.01, 0.95, "K = " + str(self.K - 1), transform=ax[0][1].transAxes, 
                          fontdict={'size': '10', 'color': 'black', 'weight': 'bold'})
            ax[0][1].tick_params(left = True, bottom = True, labelleft = True, labelbottom = True)

            plt.pause(0.1)
            
        if self.DRAW_CONTROL:
            
            self.B.clear()
            
            self.B.add_nodes_from(self.old_cluster_centers_index, bipartite = 0)
            self.B.add_nodes_from(self.pole_nodes_index, bipartite = 1)
            self.B.add_edges_from(self.old_bipartite_center_pole_edges)
            
            B_bipartite_cluster_centers_draw_options = {
                "ax": ax[1][0], 
                "pos": self.old_bipartite_cluster_centers_pos, 
                "nodelist": self.old_cluster_centers_index, 
                "node_size": 10 * self.DRAW_NODE_SIZE, 
                "node_color": "red", 
                "node_shape": 'o', 
                "label": "Clustering Center Node"
            }
            B_bipartite_poles_draw_options = {
                "ax": ax[1][0], 
                "pos": self.old_bipartite_poles_pos, 
                "nodelist": self.pole_nodes_index, 
                "node_size": self.DRAW_NODE_SIZE, 
                "node_color": "red", 
                "node_shape": '^', 
                "label": "Pole Node"
            }
            B_bipartite_match_poles_draw_options = {
                "ax": ax[1][0], 
                "pos": self.old_bipartite_match_poles_pos, 
                "nodelist": self.old_selected_pole_index, 
                "node_size": 10 * self.DRAW_NODE_SIZE, 
                "node_color": "green", 
                "node_shape": '^', 
                "label": "Assigned Pole Node (place DAP)"
            }
            B_bipartite_common_edges_draw_options = {
                "ax": ax[1][0], 
                "pos": dict(**self.old_bipartite_cluster_centers_pos, **self.old_bipartite_poles_pos), 
                "edgelist": self.old_bipartite_center_pole_edges, 
                "width": self.DRAW_EDGE_WIDTH, 
                "edge_color": "grey", 
                "arrows": False
            }
            B_bipartite_match_edges_draw_options = {
                "ax": ax[1][0], 
                "pos": dict(**self.old_bipartite_cluster_centers_pos, **self.old_bipartite_match_poles_pos), 
                "edgelist": self.old_bitpartite_match_edges, 
                "width": 30 * self.DRAW_EDGE_WIDTH, 
                "edge_color": "blue", 
                "arrowsize": 100 * self.DRAW_EDGE_WIDTH, 
                "arrowstyle": '->'
            }
            
            ax[1][0].cla()
            # Draw
            nx.draw_networkx_nodes(self.B, **B_bipartite_cluster_centers_draw_options)
            nx.draw_networkx_nodes(self.B, **B_bipartite_poles_draw_options)
            nx.draw_networkx_nodes(self.B, **B_bipartite_match_poles_draw_options)
            nx.draw_networkx_edges(self.B, **B_bipartite_common_edges_draw_options)
            nx.draw_networkx_edges(self.B, **B_bipartite_match_edges_draw_options)

            # Draw Settings
            ax[1][0].legend(loc = 'lower right')
            ax[1][0].set_title("Assign Cluster Centers Bipartite")
            ax[1][0].text(0.01, 0.95, "K = " + str(self.K - 1), transform=ax[1][0].transAxes, 
                          fontdict={'size': '10', 'color': 'black', 'weight': 'bold'})
            
            plt.pause(0.1)
            
        self.ClearILPEnv()

# %% [markdown]
# ##### Compare the effects of different clustering algorithms on the heuristic algorithms

# %%
ha = HeuristicApproach(N_MAX_SS=10, D_MAX=150, c=5, DRAW_CONTROL=True, ILP_INFO=False)
ha.GetSimData()

# %%
ha.InitializeCleanEnvironment()
ha.OurHeuristic(clustering_type = 'kmeans', custom_metric = 'eu')
# Out:
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.125852
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.110908
# [INFO] MiniWeightMatching function run time: 0.026662
# [INFO] ILP function run time: 4.645944
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.158373
# [INFO] MiniWeightMatching function run time: 0.037196
# [INFO] ILP function run time: 2.861551
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.166342
# [INFO] MiniWeightMatching function run time: 0.034683
# [INFO] ILP function run time: 3.965157
# [INFO] ILP function run time: 2.556628
# [INFO] ILP function run time: 2.463046
# [INFO] ILP function run time: 3.801694
# [INFO] ILP function run time: 4.146851
# [INFO] ILP function run time: 3.583964
# [INFO] ILP function run time: 3.294777
# [OBJECTIVE] old cost: inf, new cost: 76041.29727079133
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] KmeansClustering function run time: 0.225530
# [INFO] MiniWeightMatching function run time: 0.039818
# [INFO] ILP function run time: 3.453427
# [INFO] ILP function run time: 2.464912
# [INFO] ILP function run time: 2.677837
# [INFO] ILP function run time: 2.374016
# [INFO] ILP function run time: 2.487632
# [INFO] ILP function run time: 3.122239
# [INFO] ILP function run time: 3.067666
# [INFO] ILP function run time: 2.340070
# [OBJECTIVE] old cost: 76041.29727079133, new cost: 71208.9828607552
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] KmeansClustering function run time: 0.257548
# [INFO] MiniWeightMatching function run time: 0.039439
# [INFO] ILP function run time: 2.101534
# [INFO] ILP function run time: 1.691971
# [INFO] ILP function run time: 2.296527
# [INFO] ILP function run time: 2.334542
# [INFO] ILP function run time: 2.360142
# [INFO] ILP function run time: 2.526395
# [INFO] ILP function run time: 2.453597
# [INFO] ILP function run time: 2.445512
# [INFO] ILP function run time: 2.608171
# [OBJECTIVE] old cost: 71208.9828607552, new cost: 68202.21431738566
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] KmeansClustering function run time: 0.230794
# [INFO] MiniWeightMatching function run time: 0.044124
# [INFO] ILP function run time: 1.644035
# [INFO] ILP function run time: 1.774308
# [INFO] ILP function run time: 1.350664
# [INFO] ILP function run time: 2.336253
# [INFO] ILP function run time: 2.092585
# [INFO] ILP function run time: 1.692857
# [INFO] ILP function run time: 1.688611
# [INFO] ILP function run time: 2.355229
# [INFO] ILP function run time: 2.399470
# [INFO] ILP function run time: 2.236829
# [OBJECTIVE] old cost: 68202.21431738566, new cost: 67187.22947884
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 5 ...
# [INFO] KmeansClustering function run time: 0.246990
# [INFO] MiniWeightMatching function run time: 0.048412
# [INFO] ILP function run time: 1.745435
# [INFO] ILP function run time: 1.762168
# [INFO] ILP function run time: 1.232787
# [INFO] ILP function run time: 2.197174
# [INFO] ILP function run time: 1.605679
# [INFO] ILP function run time: 1.349695
# [INFO] ILP function run time: 1.479817
# [INFO] ILP function run time: 1.995958
# [INFO] ILP function run time: 1.692395
# [INFO] ILP function run time: 1.960800
# [INFO] ILP function run time: 1.852192
# [OBJECTIVE] old cost: 67187.22947884, new cost: 65751.76805444146
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 6 ...
# [INFO] KmeansClustering function run time: 0.262739
# [INFO] MiniWeightMatching function run time: 0.049272
# [INFO] ILP function run time: 1.548895
# [INFO] ILP function run time: 1.466059
# [INFO] ILP function run time: 1.672225
# [INFO] ILP function run time: 1.239469
# [INFO] ILP function run time: 1.242438
# [INFO] ILP function run time: 1.721433
# [INFO] ILP function run time: 1.376708
# [INFO] ILP function run time: 1.646192
# [INFO] ILP function run time: 1.472793
# [INFO] ILP function run time: 1.561107
# [INFO] ILP function run time: 1.962364
# [INFO] ILP function run time: 1.420611
# [OBJECTIVE] old cost: 65751.76805444146, new cost: 65054.07483710926
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 7 ...
# [INFO] KmeansClustering function run time: 0.275374
# [INFO] MiniWeightMatching function run time: 0.052955
# [INFO] ILP function run time: 1.205740
# [INFO] ILP function run time: 1.431142
# [INFO] ILP function run time: 1.152336
# [INFO] ILP function run time: 1.378905
# [INFO] ILP function run time: 1.679276
# [INFO] ILP function run time: 1.251679
# [INFO] ILP function run time: 1.705615
# [INFO] ILP function run time: 1.392321
# [INFO] ILP function run time: 1.073511
# [INFO] ILP function run time: 1.208409
# [INFO] ILP function run time: 1.716046
# [INFO] ILP function run time: 1.659845
# [INFO] ILP function run time: 1.324305
# [OBJECTIVE] old cost: 65054.07483710926, new cost: 64363.20007694771
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 8 ...
# [INFO] KmeansClustering function run time: 0.318225
# [INFO] MiniWeightMatching function run time: 0.059858
# [INFO] ILP function run time: 1.066151
# [INFO] ILP function run time: 0.954293
# [INFO] ILP function run time: 1.099988
# [INFO] ILP function run time: 1.090462
# [INFO] ILP function run time: 1.409113
# [INFO] ILP function run time: 1.391665
# [INFO] ILP function run time: 0.826653
# [INFO] ILP function run time: 1.006666
# [INFO] ILP function run time: 1.179475
# [INFO] ILP function run time: 1.437165
# [INFO] ILP function run time: 1.123530
# [INFO] ILP function run time: 1.374089
# [INFO] ILP function run time: 1.248878
# [INFO] ILP function run time: 1.350894
# [OBJECTIVE] old cost: 64363.20007694771, new cost: 63934.17166099199
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 9 ...
# [INFO] KmeansClustering function run time: 0.334531
# [INFO] MiniWeightMatching function run time: 0.062054
# [INFO] ILP function run time: 0.935546
# [INFO] ILP function run time: 1.111262
# [INFO] ILP function run time: 0.794903
# [INFO] ILP function run time: 0.972003
# [INFO] ILP function run time: 1.002429
# [INFO] ILP function run time: 1.157284
# [INFO] ILP function run time: 1.041621
# [INFO] ILP function run time: 1.129242
# [INFO] ILP function run time: 1.256389
# [INFO] ILP function run time: 1.253467
# [INFO] ILP function run time: 1.072302
# [INFO] ILP function run time: 1.030393
# [INFO] ILP function run time: 1.527511
# [INFO] ILP function run time: 0.976480
# [INFO] ILP function run time: 1.252337
# [OBJECTIVE] old cost: 63934.17166099199, new cost: 63648.01964422779
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 10 ...
# [INFO] KmeansClustering function run time: 0.396647
# [INFO] MiniWeightMatching function run time: 0.069802
# [INFO] ILP function run time: 0.629961
# [INFO] ILP function run time: 1.081606
# [INFO] ILP function run time: 1.115380
# [INFO] ILP function run time: 0.936144
# [INFO] ILP function run time: 1.143368
# [INFO] ILP function run time: 0.942363
# [INFO] ILP function run time: 0.921024
# [INFO] ILP function run time: 0.967225
# [INFO] ILP function run time: 1.214277
# [INFO] ILP function run time: 1.087593
# [INFO] ILP function run time: 1.007814
# [INFO] ILP function run time: 0.927308
# [INFO] ILP function run time: 1.184908
# [INFO] ILP function run time: 1.079870
# [INFO] ILP function run time: 0.998583
# [INFO] ILP function run time: 0.681024
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 63648.01964422779.
# [Result]: Installation Cost: 30000 Transmission Cost: 228.01964422778838 Delay Cost 33420.0 Total Cost 63648.01964422779

# %%
ha.InitializeCleanEnvironment()
ha.OurHeuristic(clustering_type = 'minibatchkmeans', custom_metric = 'eu')
# Out:
# [ITERATION] Start iteration 1 ...
# [INFO] MiniBatchKmeansClustering function run time: 0.149227
# [ITERATION] Start iteration 1 ...
# [INFO] MiniBatchKmeansClustering function run time: 0.044108
# [ITERATION] Start iteration 1 ...
# [INFO] MiniBatchKmeansClustering function run time: 0.045926
# [INFO] MiniWeightMatching function run time: 0.030379
# [INFO] ILP function run time: 4.619196
# [INFO] ILP function run time: 3.505775
# [INFO] ILP function run time: 2.894449
# [ITERATION] Start iteration 1 ...
# [INFO] MiniBatchKmeansClustering function run time: 0.043726
# [INFO] MiniWeightMatching function run time: 0.035088
# [INFO] ILP function run time: 3.843280
# [INFO] ILP function run time: 3.056433
# [ITERATION] Start iteration 1 ...
# [INFO] MiniBatchKmeansClustering function run time: 0.053416
# [INFO] MiniWeightMatching function run time: 0.035886
# [INFO] ILP function run time: 2.750398
# [INFO] ILP function run time: 2.802958
# [INFO] ILP function run time: 2.465271
# [INFO] ILP function run time: 2.855115
# [INFO] ILP function run time: 3.582814
# [INFO] ILP function run time: 3.174184
# [INFO] ILP function run time: 2.819446
# [INFO] ILP function run time: 1.795176
# [OBJECTIVE] old cost: inf, new cost: 72306.27098007876
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] MiniBatchKmeansClustering function run time: 0.062578
# [INFO] MiniWeightMatching function run time: 0.040384
# [INFO] ILP function run time: 3.247893
# [INFO] ILP function run time: 2.058836
# [INFO] ILP function run time: 3.491093
# [INFO] ILP function run time: 1.814855
# [INFO] ILP function run time: 2.441482
# [INFO] ILP function run time: 2.024422
# [INFO] ILP function run time: 1.655761
# [INFO] ILP function run time: 1.958103
# [INFO] ILP function run time: 3.027793
# [OBJECTIVE] old cost: 72306.27098007876, new cost: 70494.59853759609
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] MiniBatchKmeansClustering function run time: 0.056629
# [INFO] MiniWeightMatching function run time: 0.044522
# [INFO] ILP function run time: 2.167460
# [INFO] ILP function run time: 2.184373
# [INFO] ILP function run time: 2.155009
# [INFO] ILP function run time: 2.468194
# [INFO] ILP function run time: 2.321498
# [INFO] ILP function run time: 2.440813
# [INFO] ILP function run time: 2.075608
# [INFO] ILP function run time: 1.486346
# [INFO] ILP function run time: 1.526537
# [INFO] ILP function run time: 1.246705
# [OBJECTIVE] old cost: 70494.59853759609, new cost: 68126.20904733233
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] MiniBatchKmeansClustering function run time: 0.063427
# [INFO] MiniWeightMatching function run time: 0.048705
# [INFO] ILP function run time: 1.183550
# [INFO] ILP function run time: 2.201958
# [INFO] ILP function run time: 1.889768
# [INFO] ILP function run time: 1.182935
# [INFO] ILP function run time: 1.700921
# [INFO] ILP function run time: 1.954529
# [INFO] ILP function run time: 1.645552
# [INFO] ILP function run time: 2.295962
# [INFO] ILP function run time: 1.657741
# [INFO] ILP function run time: 1.481473
# [INFO] ILP function run time: 1.786274
# [OBJECTIVE] old cost: 68126.20904733233, new cost: 66535.34088196902
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 5 ...
# [INFO] MiniBatchKmeansClustering function run time: 0.069854
# [INFO] MiniWeightMatching function run time: 0.051154
# [INFO] ILP function run time: 1.510835
# [INFO] ILP function run time: 1.933038
# [INFO] ILP function run time: 1.679101
# [INFO] ILP function run time: 1.410832
# [INFO] ILP function run time: 1.128530
# [INFO] ILP function run time: 1.906506
# [INFO] ILP function run time: 1.230602
# [INFO] ILP function run time: 1.544138
# [INFO] ILP function run time: 1.719909
# [INFO] ILP function run time: 1.170688
# [INFO] ILP function run time: 1.961648
# [INFO] ILP function run time: 1.230857
# [OBJECTIVE] old cost: 66535.34088196902, new cost: 65238.96056483215
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 6 ...
# [INFO] MiniBatchKmeansClustering function run time: 0.069090
# [INFO] MiniWeightMatching function run time: 0.054233
# [INFO] ILP function run time: 0.983108
# [INFO] ILP function run time: 1.152996
# [INFO] ILP function run time: 1.369812
# [INFO] ILP function run time: 1.441847
# [INFO] ILP function run time: 1.433599
# [INFO] ILP function run time: 1.691474
# [INFO] ILP function run time: 1.307465
# [INFO] ILP function run time: 1.684523
# [INFO] ILP function run time: 1.428663
# [INFO] ILP function run time: 0.960118
# [INFO] ILP function run time: 1.012468
# [INFO] ILP function run time: 1.713226
# [INFO] ILP function run time: 1.422919
# [OBJECTIVE] old cost: 65238.96056483215, new cost: 64932.66804633917
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 7 ...
# [INFO] MiniBatchKmeansClustering function run time: 0.067099
# [INFO] MiniWeightMatching function run time: 0.061579
# [INFO] ILP function run time: 1.439443
# [INFO] ILP function run time: 1.189793
# [INFO] ILP function run time: 1.658666
# [INFO] ILP function run time: 1.038149
# [INFO] ILP function run time: 0.926197
# [INFO] ILP function run time: 1.271137
# [INFO] ILP function run time: 1.043444
# [INFO] ILP function run time: 1.234051
# [INFO] ILP function run time: 1.817056
# [INFO] ILP function run time: 0.587517
# [INFO] ILP function run time: 1.613735
# [INFO] ILP function run time: 0.992200
# [INFO] ILP function run time: 1.218634
# [INFO] ILP function run time: 0.915969
# [OBJECTIVE] old cost: 64932.66804633917, new cost: 64464.72680325569
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 8 ...
# [INFO] MiniBatchKmeansClustering function run time: 0.073867
# [INFO] MiniWeightMatching function run time: 0.067694
# [INFO] ILP function run time: 1.298021
# [INFO] ILP function run time: 1.184206
# [INFO] ILP function run time: 1.083111
# [INFO] ILP function run time: 0.949523
# [INFO] ILP function run time: 1.086790
# [INFO] ILP function run time: 1.217037
# [INFO] ILP function run time: 0.954734
# [INFO] ILP function run time: 1.094933
# [INFO] ILP function run time: 1.291390
# [INFO] ILP function run time: 1.134541
# [INFO] ILP function run time: 1.177293
# [INFO] ILP function run time: 0.808418
# [INFO] ILP function run time: 1.079391
# [INFO] ILP function run time: 0.664117
# [INFO] ILP function run time: 0.907024
# [OBJECTIVE] old cost: 64464.72680325569, new cost: 63910.60181951049
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 9 ...
# [INFO] MiniBatchKmeansClustering function run time: 0.066901
# [INFO] MiniWeightMatching function run time: 0.066896
# [INFO] ILP function run time: 1.215694
# [INFO] ILP function run time: 1.201111
# [INFO] ILP function run time: 1.030987
# [INFO] ILP function run time: 1.169477
# [INFO] ILP function run time: 1.039450
# [INFO] ILP function run time: 0.892565
# [INFO] ILP function run time: 0.789771
# [INFO] ILP function run time: 1.404160
# [INFO] ILP function run time: 0.980533
# [INFO] ILP function run time: 0.760506
# [INFO] ILP function run time: 0.965096
# [INFO] ILP function run time: 1.000512
# [INFO] ILP function run time: 0.833180
# [INFO] ILP function run time: 1.105346
# [INFO] ILP function run time: 0.784673
# [INFO] ILP function run time: 0.929394
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 63910.60181951049.
# [Result]: Installation Cost: 30000 Transmission Cost: 230.60181951049162 Delay Cost 33680.0 Total Cost 63910.60181951049

# %%
ha.InitializeCleanEnvironment()
ha.OurHeuristic(clustering_type = 'kmedoids', custom_metric = 'eu')
# Out:
# [INFO] generating distance matrix for kmedoids and eu ...
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 3.442492
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 3.878396
# [INFO] MiniWeightMatching function run time: 0.026897
# [INFO] ILP function run time: 3.862043
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 2.339851
# [INFO] MiniWeightMatching function run time: 0.034103
# [INFO] ILP function run time: 2.883882
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 2.438774
# [INFO] MiniWeightMatching function run time: 0.033053
# [INFO] ILP function run time: 4.009747
# [INFO] ILP function run time: 2.796156
# [INFO] ILP function run time: 3.450286
# [INFO] ILP function run time: 3.727214
# [INFO] ILP function run time: 2.821257
# [INFO] ILP function run time: 2.508479
# [INFO] ILP function run time: 5.645280
# [OBJECTIVE] old cost: inf, new cost: 76388.66771691022
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] KMedoidsClustering function run time: 3.610144
# [INFO] MiniWeightMatching function run time: 0.038421
# [INFO] ILP function run time: 3.433570
# [INFO] ILP function run time: 2.709725
# [INFO] ILP function run time: 2.914314
# [INFO] ILP function run time: 2.774971
# [INFO] ILP function run time: 2.953600
# [INFO] ILP function run time: 2.318040
# [INFO] ILP function run time: 2.576021
# [INFO] ILP function run time: 3.153207
# [OBJECTIVE] old cost: 76388.66771691022, new cost: 71517.8237481585
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] KMedoidsClustering function run time: 2.683164
# [INFO] MiniWeightMatching function run time: 0.043459
# [INFO] ILP function run time: 2.359305
# [INFO] ILP function run time: 1.842773
# [INFO] ILP function run time: 2.140135
# [INFO] ILP function run time: 2.657521
# [INFO] ILP function run time: 2.413711
# [INFO] ILP function run time: 2.091378
# [INFO] ILP function run time: 2.253023
# [INFO] ILP function run time: 2.785785
# [INFO] ILP function run time: 2.169154
# [OBJECTIVE] old cost: 71517.8237481585, new cost: 68492.87149552377
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] KMedoidsClustering function run time: 2.066025
# [INFO] MiniWeightMatching function run time: 0.425029
# [INFO] ILP function run time: 1.356700
# [INFO] ILP function run time: 1.830527
# [INFO] ILP function run time: 2.350211
# [INFO] ILP function run time: 2.496368
# [INFO] ILP function run time: 2.055950
# [INFO] ILP function run time: 1.570177
# [INFO] ILP function run time: 2.446573
# [INFO] ILP function run time: 2.374523
# [INFO] ILP function run time: 1.634777
# [INFO] ILP function run time: 2.426197
# [OBJECTIVE] old cost: 68492.87149552377, new cost: 66894.80611622885
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 5 ...
# [INFO] KMedoidsClustering function run time: 1.994998
# [INFO] MiniWeightMatching function run time: 0.048504
# [INFO] ILP function run time: 1.289136
# [INFO] ILP function run time: 1.928179
# [INFO] ILP function run time: 1.521101
# [INFO] ILP function run time: 1.906111
# [INFO] ILP function run time: 1.973181
# [INFO] ILP function run time: 2.174378
# [INFO] ILP function run time: 1.526351
# [INFO] ILP function run time: 1.603456
# [INFO] ILP function run time: 1.331862
# [INFO] ILP function run time: 2.107173
# [INFO] ILP function run time: 1.708488
# [OBJECTIVE] old cost: 66894.80611622885, new cost: 66173.13120121622
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 6 ...
# [INFO] KMedoidsClustering function run time: 1.852803
# [INFO] MiniWeightMatching function run time: 0.052302
# [INFO] ILP function run time: 1.728322
# [INFO] ILP function run time: 1.812460
# [INFO] ILP function run time: 1.343615
# [INFO] ILP function run time: 1.615447
# [INFO] ILP function run time: 1.098945
# [INFO] ILP function run time: 1.792601
# [INFO] ILP function run time: 1.363608
# [INFO] ILP function run time: 1.365798
# [INFO] ILP function run time: 1.055493
# [INFO] ILP function run time: 1.930508
# [INFO] ILP function run time: 2.055912
# [INFO] ILP function run time: 1.556310
# [OBJECTIVE] old cost: 66173.13120121622, new cost: 65541.5518380794
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 7 ...
# [INFO] KMedoidsClustering function run time: 1.971652
# [INFO] MiniWeightMatching function run time: 0.053163
# [INFO] ILP function run time: 1.183524
# [INFO] ILP function run time: 1.620379
# [INFO] ILP function run time: 1.149390
# [INFO] ILP function run time: 1.479630
# [INFO] ILP function run time: 1.126304
# [INFO] ILP function run time: 1.347515
# [INFO] ILP function run time: 0.992678
# [INFO] ILP function run time: 1.203969
# [INFO] ILP function run time: 1.231740
# [INFO] ILP function run time: 1.458167
# [INFO] ILP function run time: 1.779370
# [INFO] ILP function run time: 1.290221
# [INFO] ILP function run time: 1.558567
# [OBJECTIVE] old cost: 65541.5518380794, new cost: 64285.06343715366
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 8 ...
# [INFO] KMedoidsClustering function run time: 1.705124
# [INFO] MiniWeightMatching function run time: 0.061220
# [INFO] ILP function run time: 1.103280
# [INFO] ILP function run time: 1.494728
# [INFO] ILP function run time: 0.854942
# [INFO] ILP function run time: 0.955781
# [INFO] ILP function run time: 1.200798
# [INFO] ILP function run time: 1.380197
# [INFO] ILP function run time: 1.132258
# [INFO] ILP function run time: 0.703972
# [INFO] ILP function run time: 1.567201
# [INFO] ILP function run time: 1.206950
# [INFO] ILP function run time: 1.853692
# [INFO] ILP function run time: 1.018594
# [INFO] ILP function run time: 1.656385
# [INFO] ILP function run time: 1.438173
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 64285.06343715366.
# [Result]: Installation Cost: 26000 Transmission Cost: 255.06343715365801 Delay Cost 38030.0 Total Cost 64285.06343715366

# %%
ha.InitializeCleanEnvironment()
ha.OurHeuristic(clustering_type = 'kmedoids', custom_metric = 'en')
# Out:
# [INFO] generating distance matrix for kmedoids and en ...
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 5.278024
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 1.697401
# [INFO] MiniWeightMatching function run time: 0.028702
# [INFO] ILP function run time: 2.988731
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 2.153151
# [INFO] MiniWeightMatching function run time: 0.033822
# [INFO] ILP function run time: 3.729987
# [INFO] ILP function run time: 4.382587
# [INFO] ILP function run time: 2.837160
# [INFO] ILP function run time: 3.067223
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 2.866551
# [INFO] MiniWeightMatching function run time: 0.033118
# [INFO] ILP function run time: 2.941704
# [INFO] ILP function run time: 3.356825
# [INFO] ILP function run time: 3.997861
# [INFO] ILP function run time: 3.727233
# [INFO] ILP function run time: 3.861611
# [INFO] ILP function run time: 2.801353
# [INFO] ILP function run time: 2.921340
# [OBJECTIVE] old cost: inf, new cost: 76733.64584561277
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] KMedoidsClustering function run time: 2.311808
# [INFO] MiniWeightMatching function run time: 0.036814
# [INFO] ILP function run time: 2.629523
# [INFO] ILP function run time: 2.828341
# [INFO] ILP function run time: 3.314303
# [INFO] ILP function run time: 2.504218
# [INFO] ILP function run time: 3.623777
# [INFO] ILP function run time: 2.528206
# [INFO] ILP function run time: 2.269997
# [INFO] ILP function run time: 2.393655
# [OBJECTIVE] old cost: 76733.64584561277, new cost: 71671.47818002541
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] KMedoidsClustering function run time: 1.969502
# [INFO] MiniWeightMatching function run time: 0.040559
# [INFO] ILP function run time: 2.474548
# [INFO] ILP function run time: 2.009062
# [INFO] ILP function run time: 2.672057
# [INFO] ILP function run time: 2.351812
# [INFO] ILP function run time: 2.295272
# [INFO] ILP function run time: 2.159256
# [INFO] ILP function run time: 1.744869
# [INFO] ILP function run time: 2.266335
# [INFO] ILP function run time: 2.499213
# [OBJECTIVE] old cost: 71671.47818002541, new cost: 68488.34887248545
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] KMedoidsClustering function run time: 2.336409
# [INFO] MiniWeightMatching function run time: 0.044016
# [INFO] ILP function run time: 1.373417
# [INFO] ILP function run time: 1.921675
# [INFO] ILP function run time: 2.364321
# [INFO] ILP function run time: 2.327126
# [INFO] ILP function run time: 1.633472
# [INFO] ILP function run time: 2.086348
# [INFO] ILP function run time: 2.707333
# [INFO] ILP function run time: 2.034162
# [INFO] ILP function run time: 1.706616
# [INFO] ILP function run time: 1.755868
# [OBJECTIVE] old cost: 68488.34887248545, new cost: 67417.95093697344
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 5 ...
# [INFO] KMedoidsClustering function run time: 2.067125
# [INFO] MiniWeightMatching function run time: 0.048027
# [INFO] ILP function run time: 1.452954
# [INFO] ILP function run time: 1.283285
# [INFO] ILP function run time: 2.165953
# [INFO] ILP function run time: 1.796870
# [INFO] ILP function run time: 1.475165
# [INFO] ILP function run time: 1.719933
# [INFO] ILP function run time: 1.790203
# [INFO] ILP function run time: 1.915834
# [INFO] ILP function run time: 1.550825
# [INFO] ILP function run time: 1.479060
# [INFO] ILP function run time: 2.192041
# [OBJECTIVE] old cost: 67417.95093697344, new cost: 66073.25179357722
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 6 ...
# [INFO] KMedoidsClustering function run time: 2.463334
# [INFO] MiniWeightMatching function run time: 0.052186
# [INFO] ILP function run time: 1.595387
# [INFO] ILP function run time: 1.380947
# [INFO] ILP function run time: 1.076685
# [INFO] ILP function run time: 1.227592
# [INFO] ILP function run time: 1.904088
# [INFO] ILP function run time: 1.717523
# [INFO] ILP function run time: 1.296255
# [INFO] ILP function run time: 1.930852
# [INFO] ILP function run time: 1.440552
# [INFO] ILP function run time: 1.112957
# [INFO] ILP function run time: 1.896269
# [INFO] ILP function run time: 2.141734
# [OBJECTIVE] old cost: 66073.25179357722, new cost: 65857.70073376023
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 7 ...
# [INFO] KMedoidsClustering function run time: 2.128819
# [INFO] MiniWeightMatching function run time: 0.054420
# [INFO] ILP function run time: 1.107319
# [INFO] ILP function run time: 1.224564
# [INFO] ILP function run time: 1.414507
# [INFO] ILP function run time: 1.025246
# [INFO] ILP function run time: 1.259940
# [INFO] ILP function run time: 0.947350
# [INFO] ILP function run time: 0.895469
# [INFO] ILP function run time: 1.570405
# [INFO] ILP function run time: 1.466547
# [INFO] ILP function run time: 1.364585
# [INFO] ILP function run time: 1.758980
# [INFO] ILP function run time: 1.924292
# [INFO] ILP function run time: 1.614982
# [OBJECTIVE] old cost: 65857.70073376023, new cost: 64676.07157352078
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 8 ...
# [INFO] KMedoidsClustering function run time: 1.627889
# [INFO] MiniWeightMatching function run time: 0.418660
# [INFO] ILP function run time: 1.158725
# [INFO] ILP function run time: 1.033228
# [INFO] ILP function run time: 1.041469
# [INFO] ILP function run time: 1.083491
# [INFO] ILP function run time: 1.071217
# [INFO] ILP function run time: 0.835862
# [INFO] ILP function run time: 0.708656
# [INFO] ILP function run time: 1.718884
# [INFO] ILP function run time: 1.319613
# [INFO] ILP function run time: 1.503277
# [INFO] ILP function run time: 1.598024
# [INFO] ILP function run time: 1.766030
# [INFO] ILP function run time: 1.640336
# [INFO] ILP function run time: 0.926670
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 64676.07157352078.
# [Result]: Installation Cost: 26000 Transmission Cost: 256.07157352077775 Delay Cost 38420.0 Total Cost 64676.07157352078

# %%
ha.InitializeCleanEnvironment()
ha.OurHeuristic(clustering_type = 'kmedoids', custom_metric = 'ct')
# Out:
# [INFO] generating distance matrix for kmedoids and ct ...
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 5.130814
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 4.041406
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 1.742505
# [INFO] MiniWeightMatching function run time: 0.032726
# [INFO] ILP function run time: 4.455501
# [INFO] ILP function run time: 2.794416
# [INFO] ILP function run time: 3.429900
# [INFO] ILP function run time: 2.508484
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 2.612905
# [INFO] MiniWeightMatching function run time: 0.033751
# [INFO] ILP function run time: 3.675995
# [INFO] ILP function run time: 3.370955
# [INFO] ILP function run time: 3.208927
# [INFO] ILP function run time: 3.328022
# [INFO] ILP function run time: 2.314421
# [INFO] ILP function run time: 3.754281
# [INFO] ILP function run time: 3.913387
# [OBJECTIVE] old cost: inf, new cost: 75686.78632854237
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] KMedoidsClustering function run time: 2.220037
# [INFO] MiniWeightMatching function run time: 0.038254
# [INFO] ILP function run time: 2.961376
# [INFO] ILP function run time: 3.174354
# [INFO] ILP function run time: 3.454537
# [INFO] ILP function run time: 2.623539
# [INFO] ILP function run time: 2.325012
# [INFO] ILP function run time: 3.171842
# [INFO] ILP function run time: 2.292154
# [INFO] ILP function run time: 2.499257
# [OBJECTIVE] old cost: 75686.78632854237, new cost: 72134.12444668441
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] KMedoidsClustering function run time: 2.104734
# [INFO] MiniWeightMatching function run time: 0.043438
# [INFO] ILP function run time: 2.389999
# [INFO] ILP function run time: 2.642935
# [INFO] ILP function run time: 2.520752
# [INFO] ILP function run time: 2.540366
# [INFO] ILP function run time: 2.059725
# [INFO] ILP function run time: 2.665300
# [INFO] ILP function run time: 1.762021
# [INFO] ILP function run time: 1.958942
# [INFO] ILP function run time: 2.655012
# [OBJECTIVE] old cost: 72134.12444668441, new cost: 68423.7338532373
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] KMedoidsClustering function run time: 2.075939
# [INFO] MiniWeightMatching function run time: 0.045306
# [INFO] ILP function run time: 2.054214
# [INFO] ILP function run time: 2.365159
# [INFO] ILP function run time: 1.891790
# [INFO] ILP function run time: 2.427775
# [INFO] ILP function run time: 1.467844
# [INFO] ILP function run time: 2.614424
# [INFO] ILP function run time: 1.771206
# [INFO] ILP function run time: 2.322040
# [INFO] ILP function run time: 2.442345
# [INFO] ILP function run time: 1.706167
# [OBJECTIVE] old cost: 68423.7338532373, new cost: 67104.39723949485
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 5 ...
# [INFO] KMedoidsClustering function run time: 2.079510
# [INFO] MiniWeightMatching function run time: 0.050498
# [INFO] ILP function run time: 1.455045
# [INFO] ILP function run time: 2.121737
# [INFO] ILP function run time: 1.860391
# [INFO] ILP function run time: 1.638095
# [INFO] ILP function run time: 2.098799
# [INFO] ILP function run time: 1.683743
# [INFO] ILP function run time: 1.891847
# [INFO] ILP function run time: 1.810929
# [INFO] ILP function run time: 1.411154
# [INFO] ILP function run time: 1.495867
# [INFO] ILP function run time: 1.614058
# [OBJECTIVE] old cost: 67104.39723949485, new cost: 65881.05663499855
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 6 ...
# [INFO] KMedoidsClustering function run time: 2.255680
# [INFO] MiniWeightMatching function run time: 0.052002
# [INFO] ILP function run time: 1.293583
# [INFO] ILP function run time: 1.559582
# [INFO] ILP function run time: 1.152977
# [INFO] ILP function run time: 1.076006
# [INFO] ILP function run time: 1.526204
# [INFO] ILP function run time: 1.209115
# [INFO] ILP function run time: 1.863657
# [INFO] ILP function run time: 1.861684
# [INFO] ILP function run time: 1.518810
# [INFO] ILP function run time: 1.416014
# [INFO] ILP function run time: 1.696240
# [INFO] ILP function run time: 1.831362
# [OBJECTIVE] old cost: 65881.05663499855, new cost: 65105.76464159357
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 7 ...
# [INFO] KMedoidsClustering function run time: 1.317033
# [INFO] MiniWeightMatching function run time: 0.061286
# [INFO] ILP function run time: 0.867986
# [INFO] ILP function run time: 1.019802
# [INFO] ILP function run time: 1.255848
# [INFO] ILP function run time: 1.371354
# [INFO] ILP function run time: 1.077416
# [INFO] ILP function run time: 1.103029
# [INFO] ILP function run time: 1.812963
# [INFO] ILP function run time: 2.054714
# [INFO] ILP function run time: 1.386264
# [INFO] ILP function run time: 0.669302
# [INFO] ILP function run time: 1.556302
# [INFO] ILP function run time: 1.617469
# [INFO] ILP function run time: 1.709832
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 65105.76464159357.
# [Result]: Installation Cost: 24000 Transmission Cost: 265.7646415935669 Delay Cost 40840.0 Total Cost 65105.76464159357

# %%
ha.InitializeCleanEnvironment()
ha.OurHeuristic(clustering_type = 'kmedoids', custom_metric = 'cte')
# Out:
# [INFO] generating distance matrix for kmedoids and cte ...
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 5.124791
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 4.123503
# [INFO] MiniWeightMatching function run time: 0.029000
# [INFO] ILP function run time: 2.720590
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 2.134930
# [INFO] MiniWeightMatching function run time: 0.035066
# [INFO] ILP function run time: 3.744149
# [INFO] ILP function run time: 4.377103
# [INFO] ILP function run time: 2.870285
# [INFO] ILP function run time: 3.064751
# [ITERATION] Start iteration 1 ...
# [INFO] KMedoidsClustering function run time: 2.836499
# [INFO] MiniWeightMatching function run time: 0.033277
# [INFO] ILP function run time: 2.978765
# [INFO] ILP function run time: 3.376073
# [INFO] ILP function run time: 4.208421
# [INFO] ILP function run time: 3.552374
# [INFO] ILP function run time: 3.714967
# [INFO] ILP function run time: 2.581412
# [INFO] ILP function run time: 2.897976
# [OBJECTIVE] old cost: inf, new cost: 76733.64584561277
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] KMedoidsClustering function run time: 2.440554
# [INFO] MiniWeightMatching function run time: 0.037854
# [INFO] ILP function run time: 2.625412
# [INFO] ILP function run time: 2.898468
# [INFO] ILP function run time: 3.241826
# [INFO] ILP function run time: 2.451129
# [INFO] ILP function run time: 3.679085
# [INFO] ILP function run time: 2.259401
# [INFO] ILP function run time: 2.147107
# [INFO] ILP function run time: 2.428689
# [OBJECTIVE] old cost: 76733.64584561277, new cost: 71602.12568927635
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] KMedoidsClustering function run time: 2.228539
# [INFO] MiniWeightMatching function run time: 0.045558
# [INFO] ILP function run time: 2.555684
# [INFO] ILP function run time: 2.062861
# [INFO] ILP function run time: 2.667368
# [INFO] ILP function run time: 2.549455
# [INFO] ILP function run time: 2.592645
# [INFO] ILP function run time: 2.312447
# [INFO] ILP function run time: 1.841771
# [INFO] ILP function run time: 2.050302
# [INFO] ILP function run time: 2.796163
# [OBJECTIVE] old cost: 71602.12568927635, new cost: 68552.27672254965
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] KMedoidsClustering function run time: 2.345669
# [INFO] MiniWeightMatching function run time: 0.045464
# [INFO] ILP function run time: 1.269451
# [INFO] ILP function run time: 1.967846
# [INFO] ILP function run time: 2.413188
# [INFO] ILP function run time: 2.277610
# [INFO] ILP function run time: 1.558926
# [INFO] ILP function run time: 2.256179
# [INFO] ILP function run time: 2.702571
# [INFO] ILP function run time: 2.170721
# [INFO] ILP function run time: 1.713511
# [INFO] ILP function run time: 1.960688
# [OBJECTIVE] old cost: 68552.27672254965, new cost: 67303.30824791899
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 5 ...
# [INFO] KMedoidsClustering function run time: 1.905426
# [INFO] MiniWeightMatching function run time: 0.049320
# [INFO] ILP function run time: 1.582307
# [INFO] ILP function run time: 1.333526
# [INFO] ILP function run time: 2.033675
# [INFO] ILP function run time: 1.696239
# [INFO] ILP function run time: 1.477919
# [INFO] ILP function run time: 1.864263
# [INFO] ILP function run time: 1.800364
# [INFO] ILP function run time: 2.005831
# [INFO] ILP function run time: 1.655603
# [INFO] ILP function run time: 1.487249
# [INFO] ILP function run time: 1.906740
# [OBJECTIVE] old cost: 67303.30824791899, new cost: 66377.0183325848
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 6 ...
# [INFO] KMedoidsClustering function run time: 2.006154
# [INFO] MiniWeightMatching function run time: 0.052629
# [INFO] ILP function run time: 1.269299
# [INFO] ILP function run time: 1.358613
# [INFO] ILP function run time: 1.094476
# [INFO] ILP function run time: 1.130882
# [INFO] ILP function run time: 1.958194
# [INFO] ILP function run time: 1.737926
# [INFO] ILP function run time: 1.304289
# [INFO] ILP function run time: 2.004637
# [INFO] ILP function run time: 1.511630
# [INFO] ILP function run time: 1.049807
# [INFO] ILP function run time: 1.647056
# [INFO] ILP function run time: 1.948064
# [OBJECTIVE] old cost: 66377.0183325848, new cost: 65588.69287168916
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 7 ...
# [INFO] KMedoidsClustering function run time: 2.539560
# [INFO] MiniWeightMatching function run time: 0.058876
# [INFO] ILP function run time: 1.144395
# [INFO] ILP function run time: 1.279754
# [INFO] ILP function run time: 1.329250
# [INFO] ILP function run time: 1.123189
# [INFO] ILP function run time: 1.802053
# [INFO] ILP function run time: 0.911146
# [INFO] ILP function run time: 0.838207
# [INFO] ILP function run time: 1.854359
# [INFO] ILP function run time: 1.698991
# [INFO] ILP function run time: 1.831968
# [INFO] ILP function run time: 1.586045
# [INFO] ILP function run time: 2.157284
# [INFO] ILP function run time: 1.659799
# [OBJECTIVE] old cost: 65588.69287168916, new cost: 64766.56229340239
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 8 ...
# [INFO] KMedoidsClustering function run time: 1.898908
# [INFO] MiniWeightMatching function run time: 0.067210
# [INFO] ILP function run time: 1.165831
# [INFO] ILP function run time: 0.999636
# [INFO] ILP function run time: 1.191848
# [INFO] ILP function run time: 1.098713
# [INFO] ILP function run time: 1.220254
# [INFO] ILP function run time: 0.993027
# [INFO] ILP function run time: 0.776134
# [INFO] ILP function run time: 1.726309
# [INFO] ILP function run time: 1.172529
# [INFO] ILP function run time: 1.447308
# [INFO] ILP function run time: 1.633554
# [INFO] ILP function run time: 1.494038
# [INFO] ILP function run time: 1.428750
# [INFO] ILP function run time: 0.935569
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 64766.56229340239.
# [Result]: Installation Cost: 26000 Transmission Cost: 256.56229340239224 Delay Cost 38510.0 Total Cost 64766.56229340239

# %%
ha.InitializeCleanEnvironment()
ha.OurHeuristic(clustering_type = 'spectral', custom_metric = 'eu')

# %%
ha.InitializeCleanEnvironment()
ha.OurHeuristic(clustering_type = 'spectral', custom_metric = 'en')

# %%
ha.InitializeCleanEnvironment()
ha.OurHeuristic(clustering_type = 'spectral', custom_metric = 'ct')

# %%
ha.InitializeCleanEnvironment()
ha.OurHeuristic(clustering_type = 'spectral', custom_metric = 'cte')

# %%
ha.InitializeCleanEnvironment()
ha.OurHeuristic(clustering_type = 'agglomerative', custom_metric = 'eu')
# Out:
# [INFO] generating distance matrix for agglomerative and eu ...
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.388465
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.145425
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.146136
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.114097
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.133542
# [INFO] MiniWeightMatching function run time: 0.034804
# [INFO] ILP function run time: 3.824562
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.981737
# [INFO] MiniWeightMatching function run time: 0.190759
# [INFO] ILP function run time: 2.961609
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.495733
# [INFO] MiniWeightMatching function run time: 0.054269
# [INFO] ILP function run time: 3.222729
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.210870
# [INFO] MiniWeightMatching function run time: 0.065862
# [INFO] ILP function run time: 2.354795
# [INFO] ILP function run time: 2.039197
# [INFO] ILP function run time: 3.470782
# [INFO] ILP function run time: 2.494708
# [INFO] ILP function run time: 2.004389
# [INFO] ILP function run time: 0.904714
# [INFO] ILP function run time: 0.657267
# [INFO] ILP function run time: 2.547912
# [INFO] ILP function run time: 0.791160
# [INFO] ILP function run time: 1.735513
# [INFO] ILP function run time: 1.533223
# [OBJECTIVE] old cost: inf, new cost: 73870.98815424516
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] AgglomerativeClustering function run time: 2.374873
# [INFO] MiniWeightMatching function run time: 0.054936
# [INFO] ILP function run time: 2.970300
# [INFO] ILP function run time: 1.816743
# [INFO] ILP function run time: 0.894439
# [INFO] ILP function run time: 2.239654
# [INFO] ILP function run time: 1.905969
# [INFO] ILP function run time: 0.932700
# [INFO] ILP function run time: 0.633027
# [INFO] ILP function run time: 2.651923
# [INFO] ILP function run time: 0.997256
# [INFO] ILP function run time: 1.909582
# [INFO] ILP function run time: 1.554627
# [INFO] ILP function run time: 0.443587
# [OBJECTIVE] old cost: 73870.98815424516, new cost: 71109.80553831856
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] AgglomerativeClustering function run time: 2.175765
# [INFO] MiniWeightMatching function run time: 0.056003
# [INFO] ILP function run time: 1.960675
# [INFO] ILP function run time: 2.060837
# [INFO] ILP function run time: 0.958693
# [INFO] ILP function run time: 2.634432
# [INFO] ILP function run time: 2.038116
# [INFO] ILP function run time: 0.917841
# [INFO] ILP function run time: 0.791824
# [INFO] ILP function run time: 1.053549
# [INFO] ILP function run time: 0.973163
# [INFO] ILP function run time: 1.894580
# [INFO] ILP function run time: 1.544010
# [INFO] ILP function run time: 0.445025
# [INFO] ILP function run time: 0.936014
# [OBJECTIVE] old cost: 71109.80553831856, new cost: 70353.05955089336
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] AgglomerativeClustering function run time: 2.194660
# [INFO] MiniWeightMatching function run time: 0.056656
# [INFO] ILP function run time: 2.166226
# [INFO] ILP function run time: 2.630613
# [INFO] ILP function run time: 0.970040
# [INFO] ILP function run time: 1.046560
# [INFO] ILP function run time: 2.055993
# [INFO] ILP function run time: 1.075170
# [INFO] ILP function run time: 0.647487
# [INFO] ILP function run time: 0.539415
# [INFO] ILP function run time: 0.956106
# [INFO] ILP function run time: 1.720971
# [INFO] ILP function run time: 1.553553
# [INFO] ILP function run time: 0.422653
# [INFO] ILP function run time: 1.140390
# [INFO] ILP function run time: 0.656793
# [OBJECTIVE] old cost: 70353.05955089336, new cost: 69470.46636944794
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 5 ...
# [INFO] AgglomerativeClustering function run time: 2.193956
# [INFO] MiniWeightMatching function run time: 0.432702
# [INFO] ILP function run time: 2.624329
# [INFO] ILP function run time: 1.993467
# [INFO] ILP function run time: 1.000762
# [INFO] ILP function run time: 1.187224
# [INFO] ILP function run time: 1.744561
# [INFO] ILP function run time: 1.057789
# [INFO] ILP function run time: 0.640692
# [INFO] ILP function run time: 0.538065
# [INFO] ILP function run time: 0.785458
# [INFO] ILP function run time: 1.048565
# [INFO] ILP function run time: 1.535315
# [INFO] ILP function run time: 0.444901
# [INFO] ILP function run time: 0.940605
# [INFO] ILP function run time: 0.655556
# [INFO] ILP function run time: 0.670026
# [OBJECTIVE] old cost: 69470.46636944794, new cost: 68954.81497293635
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 6 ...
# [INFO] AgglomerativeClustering function run time: 2.185864
# [INFO] MiniWeightMatching function run time: 0.066260
# [INFO] ILP function run time: 1.975584
# [INFO] ILP function run time: 1.171045
# [INFO] ILP function run time: 1.086370
# [INFO] ILP function run time: 1.317008
# [INFO] ILP function run time: 1.856312
# [INFO] ILP function run time: 0.908408
# [INFO] ILP function run time: 0.648046
# [INFO] ILP function run time: 0.529377
# [INFO] ILP function run time: 0.790864
# [INFO] ILP function run time: 0.879017
# [INFO] ILP function run time: 1.556602
# [INFO] ILP function run time: 0.437543
# [INFO] ILP function run time: 0.937301
# [INFO] ILP function run time: 0.647377
# [INFO] ILP function run time: 0.660333
# [INFO] ILP function run time: 0.445095
# [OBJECTIVE] old cost: 68954.81497293635, new cost: 68576.32015608915
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 7 ...
# [INFO] AgglomerativeClustering function run time: 2.182707
# [INFO] MiniWeightMatching function run time: 0.075529
# [INFO] ILP function run time: 1.052131
# [INFO] ILP function run time: 1.722986
# [INFO] ILP function run time: 1.039723
# [INFO] ILP function run time: 1.433000
# [INFO] ILP function run time: 1.527673
# [INFO] ILP function run time: 1.032285
# [INFO] ILP function run time: 0.673223
# [INFO] ILP function run time: 0.740139
# [INFO] ILP function run time: 0.987630
# [INFO] ILP function run time: 1.206298
# [INFO] ILP function run time: 1.185509
# [INFO] ILP function run time: 0.475567
# [INFO] ILP function run time: 0.986327
# [INFO] ILP function run time: 0.718672
# [INFO] ILP function run time: 0.756347
# [INFO] ILP function run time: 0.491665
# [INFO] ILP function run time: 0.461778
# [OBJECTIVE] old cost: 68576.32015608915, new cost: 68419.97684726285
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 8 ...
# [INFO] AgglomerativeClustering function run time: 3.108876
# [INFO] MiniWeightMatching function run time: 0.489118
# [INFO] ILP function run time: 1.842723
# [INFO] ILP function run time: 1.816643
# [INFO] ILP function run time: 1.006867
# [INFO] ILP function run time: 0.926966
# [INFO] ILP function run time: 1.640374
# [INFO] ILP function run time: 1.181094
# [INFO] ILP function run time: 0.735990
# [INFO] ILP function run time: 0.825327
# [INFO] ILP function run time: 0.403700
# [INFO] ILP function run time: 1.014025
# [INFO] ILP function run time: 1.134874
# [INFO] ILP function run time: 0.495077
# [INFO] ILP function run time: 1.181554
# [INFO] ILP function run time: 0.720685
# [INFO] ILP function run time: 0.711564
# [INFO] ILP function run time: 0.799355
# [INFO] ILP function run time: 0.470417
# [INFO] ILP function run time: 0.421018
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 68419.97684726285.
# [Result]: Installation Cost: 34000 Transmission Cost: 229.97684726284933 Delay Cost 34190.0 Total Cost 68419.97684726285

# %%
ha.InitializeCleanEnvironment()
ha.OurHeuristic(clustering_type = 'agglomerative', custom_metric = 'en')
# Out:
# [INFO] generating distance matrix for agglomerative and en ...
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.262902
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.198107
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.150980
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.175183
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.182525
# [INFO] MiniWeightMatching function run time: 0.042425
# [INFO] ILP function run time: 3.050835
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.167722
# [INFO] MiniWeightMatching function run time: 0.050005
# [INFO] ILP function run time: 2.912314
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.176399
# [INFO] MiniWeightMatching function run time: 0.049632
# [INFO] ILP function run time: 3.037532
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.179500
# [INFO] MiniWeightMatching function run time: 0.053410
# [INFO] ILP function run time: 2.027349
# [INFO] ILP function run time: 1.958082
# [INFO] ILP function run time: 3.070663
# [INFO] ILP function run time: 2.301973
# [INFO] ILP function run time: 1.928301
# [INFO] ILP function run time: 1.122035
# [INFO] ILP function run time: 0.649872
# [INFO] ILP function run time: 2.793645
# [INFO] ILP function run time: 0.802055
# [INFO] ILP function run time: 1.800600
# [INFO] ILP function run time: 1.600944
# [OBJECTIVE] old cost: inf, new cost: 73870.98815424516
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] AgglomerativeClustering function run time: 2.227460
# [INFO] MiniWeightMatching function run time: 0.054639
# [INFO] ILP function run time: 2.908436
# [INFO] ILP function run time: 1.792638
# [INFO] ILP function run time: 1.099715
# [INFO] ILP function run time: 2.094253
# [INFO] ILP function run time: 1.885407
# [INFO] ILP function run time: 0.946830
# [INFO] ILP function run time: 0.869720
# [INFO] ILP function run time: 2.506507
# [INFO] ILP function run time: 0.794174
# [INFO] ILP function run time: 1.737287
# [INFO] ILP function run time: 1.578106
# [INFO] ILP function run time: 0.434951
# [OBJECTIVE] old cost: 73870.98815424516, new cost: 71109.80553831856
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] AgglomerativeClustering function run time: 2.219777
# [INFO] MiniWeightMatching function run time: 0.479489
# [INFO] ILP function run time: 1.813632
# [INFO] ILP function run time: 2.285336
# [INFO] ILP function run time: 0.984838
# [INFO] ILP function run time: 2.497777
# [INFO] ILP function run time: 1.926909
# [INFO] ILP function run time: 0.921185
# [INFO] ILP function run time: 0.871299
# [INFO] ILP function run time: 1.054747
# [INFO] ILP function run time: 0.809970
# [INFO] ILP function run time: 1.751097
# [INFO] ILP function run time: 1.546956
# [INFO] ILP function run time: 0.436794
# [INFO] ILP function run time: 0.945566
# [OBJECTIVE] old cost: 71109.80553831856, new cost: 70353.05955089336
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] AgglomerativeClustering function run time: 2.194602
# [INFO] MiniWeightMatching function run time: 0.058487
# [INFO] ILP function run time: 2.555702
# [INFO] ILP function run time: 2.522215
# [INFO] ILP function run time: 0.964139
# [INFO] ILP function run time: 1.061180
# [INFO] ILP function run time: 2.141744
# [INFO] ILP function run time: 0.899752
# [INFO] ILP function run time: 0.661066
# [INFO] ILP function run time: 0.526837
# [INFO] ILP function run time: 0.808037
# [INFO] ILP function run time: 1.730257
# [INFO] ILP function run time: 1.582210
# [INFO] ILP function run time: 0.450287
# [INFO] ILP function run time: 0.932276
# [INFO] ILP function run time: 0.660720
# [OBJECTIVE] old cost: 70353.05955089336, new cost: 69470.46636944794
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 5 ...
# [INFO] AgglomerativeClustering function run time: 2.263115
# [INFO] MiniWeightMatching function run time: 0.062112
# [INFO] ILP function run time: 2.667004
# [INFO] ILP function run time: 1.847934
# [INFO] ILP function run time: 1.142507
# [INFO] ILP function run time: 1.252253
# [INFO] ILP function run time: 1.730848
# [INFO] ILP function run time: 1.115689
# [INFO] ILP function run time: 0.661884
# [INFO] ILP function run time: 0.529626
# [INFO] ILP function run time: 0.807409
# [INFO] ILP function run time: 0.879427
# [INFO] ILP function run time: 1.571852
# [INFO] ILP function run time: 0.433693
# [INFO] ILP function run time: 0.952237
# [INFO] ILP function run time: 0.657632
# [INFO] ILP function run time: 0.673222
# [OBJECTIVE] old cost: 69470.46636944794, new cost: 68954.81497293635
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 6 ...
# [INFO] AgglomerativeClustering function run time: 2.232010
# [INFO] MiniWeightMatching function run time: 0.065915
# [INFO] ILP function run time: 2.047638
# [INFO] ILP function run time: 1.045332
# [INFO] ILP function run time: 0.975659
# [INFO] ILP function run time: 1.317873
# [INFO] ILP function run time: 1.701464
# [INFO] ILP function run time: 0.921706
# [INFO] ILP function run time: 0.644844
# [INFO] ILP function run time: 0.523220
# [INFO] ILP function run time: 0.787294
# [INFO] ILP function run time: 0.890026
# [INFO] ILP function run time: 1.565949
# [INFO] ILP function run time: 0.441361
# [INFO] ILP function run time: 1.209271
# [INFO] ILP function run time: 0.937800
# [INFO] ILP function run time: 0.928768
# [INFO] ILP function run time: 0.461075
# [OBJECTIVE] old cost: 68954.81497293635, new cost: 68576.32015608915
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 7 ...
# [INFO] AgglomerativeClustering function run time: 2.221535
# [INFO] MiniWeightMatching function run time: 0.072697
# [INFO] ILP function run time: 1.078181
# [INFO] ILP function run time: 1.881386
# [INFO] ILP function run time: 1.161929
# [INFO] ILP function run time: 1.332378
# [INFO] ILP function run time: 1.736020
# [INFO] ILP function run time: 1.118692
# [INFO] ILP function run time: 0.638177
# [INFO] ILP function run time: 0.527936
# [INFO] ILP function run time: 0.801374
# [INFO] ILP function run time: 0.890894
# [INFO] ILP function run time: 0.909007
# [INFO] ILP function run time: 0.431397
# [INFO] ILP function run time: 0.940172
# [INFO] ILP function run time: 0.662798
# [INFO] ILP function run time: 0.661424
# [INFO] ILP function run time: 0.450500
# [INFO] ILP function run time: 0.462776
# [OBJECTIVE] old cost: 68576.32015608915, new cost: 68419.97684726285
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 8 ...
# [INFO] AgglomerativeClustering function run time: 2.225858
# [INFO] MiniWeightMatching function run time: 0.079152
# [INFO] ILP function run time: 1.734368
# [INFO] ILP function run time: 1.494877
# [INFO] ILP function run time: 1.152871
# [INFO] ILP function run time: 0.794762
# [INFO] ILP function run time: 1.515601
# [INFO] ILP function run time: 0.925094
# [INFO] ILP function run time: 0.642946
# [INFO] ILP function run time: 0.552845
# [INFO] ILP function run time: 0.345329
# [INFO] ILP function run time: 1.114115
# [INFO] ILP function run time: 0.905929
# [INFO] ILP function run time: 0.437760
# [INFO] ILP function run time: 0.947259
# [INFO] ILP function run time: 0.921733
# [INFO] ILP function run time: 0.679596
# [INFO] ILP function run time: 0.451362
# [INFO] ILP function run time: 0.446881
# [INFO] ILP function run time: 0.423928
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 68419.97684726285.
# [Result]: Installation Cost: 34000 Transmission Cost: 229.97684726284933 Delay Cost 34190.0 Total Cost 68419.97684726285

# %%
ha.InitializeCleanEnvironment()
ha.OurHeuristic(clustering_type = 'agglomerative', custom_metric = 'ct')
# Out:
# [INFO] generating distance matrix for agglomerative and ct ...
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.420981
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.182077
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.200289
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.200366
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.211336
# [INFO] MiniWeightMatching function run time: 0.043507
# [INFO] ILP function run time: 3.101807
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.164223
# [INFO] MiniWeightMatching function run time: 0.046846
# [INFO] ILP function run time: 2.958466
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.179970
# [INFO] MiniWeightMatching function run time: 0.043210
# [INFO] ILP function run time: 3.094892
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.202696
# [INFO] MiniWeightMatching function run time: 0.046067
# [INFO] ILP function run time: 2.412702
# [INFO] ILP function run time: 2.150495
# [INFO] ILP function run time: 3.087637
# [INFO] ILP function run time: 2.072141
# [INFO] ILP function run time: 1.874251
# [INFO] ILP function run time: 1.104870
# [INFO] ILP function run time: 0.649611
# [INFO] ILP function run time: 2.780553
# [INFO] ILP function run time: 0.796126
# [INFO] ILP function run time: 1.757358
# [INFO] ILP function run time: 1.569297
# [OBJECTIVE] old cost: inf, new cost: 73870.98815424516
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] AgglomerativeClustering function run time: 2.233543
# [INFO] MiniWeightMatching function run time: 0.051253
# [INFO] ILP function run time: 3.429699
# [INFO] ILP function run time: 2.284198
# [INFO] ILP function run time: 1.022532
# [INFO] ILP function run time: 2.651336
# [INFO] ILP function run time: 2.412458
# [INFO] ILP function run time: 1.182871
# [INFO] ILP function run time: 0.643572
# [INFO] ILP function run time: 2.777372
# [INFO] ILP function run time: 0.815792
# [INFO] ILP function run time: 1.736331
# [INFO] ILP function run time: 1.574041
# [INFO] ILP function run time: 0.452290
# [OBJECTIVE] old cost: 73870.98815424516, new cost: 71109.80553831856
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] AgglomerativeClustering function run time: 2.301662
# [INFO] MiniWeightMatching function run time: 0.057035
# [INFO] ILP function run time: 1.809865
# [INFO] ILP function run time: 2.265064
# [INFO] ILP function run time: 0.974262
# [INFO] ILP function run time: 2.705391
# [INFO] ILP function run time: 1.908294
# [INFO] ILP function run time: 0.922800
# [INFO] ILP function run time: 0.650681
# [INFO] ILP function run time: 1.142936
# [INFO] ILP function run time: 0.867038
# [INFO] ILP function run time: 1.786173
# [INFO] ILP function run time: 1.682849
# [INFO] ILP function run time: 0.439643
# [INFO] ILP function run time: 1.362788
# [OBJECTIVE] old cost: 71109.80553831856, new cost: 70353.05955089336
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] AgglomerativeClustering function run time: 2.492996
# [INFO] MiniWeightMatching function run time: 0.062872
# [INFO] ILP function run time: 2.763468
# [INFO] ILP function run time: 2.561368
# [INFO] ILP function run time: 0.976977
# [INFO] ILP function run time: 1.077264
# [INFO] ILP function run time: 1.886676
# [INFO] ILP function run time: 1.137296
# [INFO] ILP function run time: 0.650806
# [INFO] ILP function run time: 0.522395
# [INFO] ILP function run time: 0.790473
# [INFO] ILP function run time: 1.971335
# [INFO] ILP function run time: 1.808181
# [INFO] ILP function run time: 0.451612
# [INFO] ILP function run time: 0.946591
# [INFO] ILP function run time: 0.679334
# [OBJECTIVE] old cost: 70353.05955089336, new cost: 69470.46636944794
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 5 ...
# [INFO] AgglomerativeClustering function run time: 2.241446
# [INFO] MiniWeightMatching function run time: 0.061957
# [INFO] ILP function run time: 3.272457
# [INFO] ILP function run time: 2.359476
# [INFO] ILP function run time: 1.009818
# [INFO] ILP function run time: 1.131349
# [INFO] ILP function run time: 1.719170
# [INFO] ILP function run time: 0.910666
# [INFO] ILP function run time: 0.869829
# [INFO] ILP function run time: 0.535684
# [INFO] ILP function run time: 0.795152
# [INFO] ILP function run time: 0.902643
# [INFO] ILP function run time: 1.830117
# [INFO] ILP function run time: 0.443627
# [INFO] ILP function run time: 0.944067
# [INFO] ILP function run time: 0.652197
# [INFO] ILP function run time: 0.685816
# [OBJECTIVE] old cost: 69470.46636944794, new cost: 68954.81497293635
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 6 ...
# [INFO] AgglomerativeClustering function run time: 2.195804
# [INFO] MiniWeightMatching function run time: 0.066064
# [INFO] ILP function run time: 2.411688
# [INFO] ILP function run time: 1.243825
# [INFO] ILP function run time: 1.174328
# [INFO] ILP function run time: 1.329634
# [INFO] ILP function run time: 1.712625
# [INFO] ILP function run time: 0.916857
# [INFO] ILP function run time: 0.639473
# [INFO] ILP function run time: 0.523012
# [INFO] ILP function run time: 0.797676
# [INFO] ILP function run time: 0.887963
# [INFO] ILP function run time: 1.544543
# [INFO] ILP function run time: 0.442148
# [INFO] ILP function run time: 0.935023
# [INFO] ILP function run time: 0.673671
# [INFO] ILP function run time: 0.676894
# [INFO] ILP function run time: 0.455098
# [OBJECTIVE] old cost: 68954.81497293635, new cost: 68576.32015608915
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 7 ...
# [INFO] AgglomerativeClustering function run time: 2.210804
# [INFO] MiniWeightMatching function run time: 0.078527
# [INFO] ILP function run time: 1.048701
# [INFO] ILP function run time: 1.715890
# [INFO] ILP function run time: 0.972402
# [INFO] ILP function run time: 1.338681
# [INFO] ILP function run time: 1.533832
# [INFO] ILP function run time: 1.653847
# [INFO] ILP function run time: 0.693203
# [INFO] ILP function run time: 0.556328
# [INFO] ILP function run time: 0.860234
# [INFO] ILP function run time: 0.970238
# [INFO] ILP function run time: 1.052349
# [INFO] ILP function run time: 0.545805
# [INFO] ILP function run time: 0.939331
# [INFO] ILP function run time: 0.660474
# [INFO] ILP function run time: 0.662893
# [INFO] ILP function run time: 0.464752
# [INFO] ILP function run time: 0.436228
# [OBJECTIVE] old cost: 68576.32015608915, new cost: 68419.97684726285
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 8 ...
# [INFO] AgglomerativeClustering function run time: 2.394960
# [INFO] MiniWeightMatching function run time: 0.075101
# [INFO] ILP function run time: 2.124852
# [INFO] ILP function run time: 1.798813
# [INFO] ILP function run time: 1.369491
# [INFO] ILP function run time: 0.856844
# [INFO] ILP function run time: 1.859871
# [INFO] ILP function run time: 1.016554
# [INFO] ILP function run time: 0.769825
# [INFO] ILP function run time: 0.589669
# [INFO] ILP function run time: 0.369516
# [INFO] ILP function run time: 0.939243
# [INFO] ILP function run time: 0.967382
# [INFO] ILP function run time: 0.447502
# [INFO] ILP function run time: 1.082026
# [INFO] ILP function run time: 0.736065
# [INFO] ILP function run time: 0.742212
# [INFO] ILP function run time: 0.473878
# [INFO] ILP function run time: 0.763303
# [INFO] ILP function run time: 0.462642
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 68419.97684726285.
# [Result]: Installation Cost: 34000 Transmission Cost: 229.97684726284933 Delay Cost 34190.0 Total Cost 68419.97684726285

# %%
ha.InitializeCleanEnvironment()
ha.OurHeuristic(clustering_type = 'agglomerative', custom_metric = 'cte')
# Out:
# [INFO] generating distance matrix for agglomerative and cte ...
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.298764
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.142764
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.188351
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.480022
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.173113
# [INFO] MiniWeightMatching function run time: 0.044114
# [INFO] ILP function run time: 3.663522
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.588568
# [INFO] MiniWeightMatching function run time: 0.202761
# [INFO] ILP function run time: 3.295989
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.526794
# [INFO] MiniWeightMatching function run time: 0.051025
# [INFO] ILP function run time: 3.454625
# [ITERATION] Start iteration 1 ...
# [INFO] AgglomerativeClustering function run time: 2.415558
# [INFO] MiniWeightMatching function run time: 0.056726
# [INFO] ILP function run time: 2.347267
# [INFO] ILP function run time: 1.924180
# [INFO] ILP function run time: 2.880251
# [INFO] ILP function run time: 2.068967
# [INFO] ILP function run time: 1.856798
# [INFO] ILP function run time: 1.132333
# [INFO] ILP function run time: 0.729052
# [INFO] ILP function run time: 2.707961
# [INFO] ILP function run time: 0.829736
# [INFO] ILP function run time: 1.735489
# [INFO] ILP function run time: 1.786261
# [OBJECTIVE] old cost: inf, new cost: 73870.98815424516
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] AgglomerativeClustering function run time: 2.432055
# [INFO] MiniWeightMatching function run time: 0.056331
# [INFO] ILP function run time: 3.088895
# [INFO] ILP function run time: 1.969199
# [INFO] ILP function run time: 1.170148
# [INFO] ILP function run time: 2.355587
# [INFO] ILP function run time: 1.986699
# [INFO] ILP function run time: 0.960845
# [INFO] ILP function run time: 0.990669
# [INFO] ILP function run time: 3.138472
# [INFO] ILP function run time: 0.858153
# [INFO] ILP function run time: 1.922016
# [INFO] ILP function run time: 1.672698
# [INFO] ILP function run time: 0.474418
# [OBJECTIVE] old cost: 73870.98815424516, new cost: 71109.80553831856
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] AgglomerativeClustering function run time: 2.261391
# [INFO] MiniWeightMatching function run time: 0.064289
# [INFO] ILP function run time: 2.209199
# [INFO] ILP function run time: 2.491961
# [INFO] ILP function run time: 1.360643
# [INFO] ILP function run time: 2.846971
# [INFO] ILP function run time: 2.066660
# [INFO] ILP function run time: 1.091314
# [INFO] ILP function run time: 0.644515
# [INFO] ILP function run time: 1.069449
# [INFO] ILP function run time: 0.822734
# [INFO] ILP function run time: 1.722223
# [INFO] ILP function run time: 1.566950
# [INFO] ILP function run time: 0.428309
# [INFO] ILP function run time: 1.180271
# [OBJECTIVE] old cost: 71109.80553831856, new cost: 70353.05955089336
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] AgglomerativeClustering function run time: 2.317544
# [INFO] MiniWeightMatching function run time: 0.064363
# [INFO] ILP function run time: 2.177538
# [INFO] ILP function run time: 2.634913
# [INFO] ILP function run time: 1.003475
# [INFO] ILP function run time: 1.066936
# [INFO] ILP function run time: 2.023062
# [INFO] ILP function run time: 0.911433
# [INFO] ILP function run time: 0.805364
# [INFO] ILP function run time: 0.531687
# [INFO] ILP function run time: 0.796792
# [INFO] ILP function run time: 1.728294
# [INFO] ILP function run time: 1.580069
# [INFO] ILP function run time: 0.430044
# [INFO] ILP function run time: 1.141851
# [INFO] ILP function run time: 0.657939
# [OBJECTIVE] old cost: 70353.05955089336, new cost: 69470.46636944794
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 5 ...
# [INFO] AgglomerativeClustering function run time: 2.229957
# [INFO] MiniWeightMatching function run time: 0.067497
# [INFO] ILP function run time: 2.612199
# [INFO] ILP function run time: 1.886272
# [INFO] ILP function run time: 0.984759
# [INFO] ILP function run time: 1.103163
# [INFO] ILP function run time: 1.736441
# [INFO] ILP function run time: 1.055990
# [INFO] ILP function run time: 0.662154
# [INFO] ILP function run time: 0.687065
# [INFO] ILP function run time: 0.797053
# [INFO] ILP function run time: 0.884511
# [INFO] ILP function run time: 1.535979
# [INFO] ILP function run time: 0.435978
# [INFO] ILP function run time: 0.946675
# [INFO] ILP function run time: 0.678888
# [INFO] ILP function run time: 0.659130
# [OBJECTIVE] old cost: 69470.46636944794, new cost: 68954.81497293635
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 6 ...
# [INFO] AgglomerativeClustering function run time: 2.240038
# [INFO] MiniWeightMatching function run time: 0.071506
# [INFO] ILP function run time: 2.047015
# [INFO] ILP function run time: 1.163001
# [INFO] ILP function run time: 1.079175
# [INFO] ILP function run time: 1.440898
# [INFO] ILP function run time: 1.847255
# [INFO] ILP function run time: 1.055814
# [INFO] ILP function run time: 0.659104
# [INFO] ILP function run time: 0.680008
# [INFO] ILP function run time: 0.790922
# [INFO] ILP function run time: 0.884656
# [INFO] ILP function run time: 1.711856
# [INFO] ILP function run time: 0.431133
# [INFO] ILP function run time: 0.940527
# [INFO] ILP function run time: 0.649968
# [INFO] ILP function run time: 0.675238
# [INFO] ILP function run time: 0.662707
# [OBJECTIVE] old cost: 68954.81497293635, new cost: 68576.32015608915
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 7 ...
# [INFO] AgglomerativeClustering function run time: 2.216116
# [INFO] MiniWeightMatching function run time: 0.078048
# [INFO] ILP function run time: 1.164785
# [INFO] ILP function run time: 1.861039
# [INFO] ILP function run time: 1.098392
# [INFO] ILP function run time: 1.327490
# [INFO] ILP function run time: 1.531418
# [INFO] ILP function run time: 1.075487
# [INFO] ILP function run time: 0.650038
# [INFO] ILP function run time: 0.688727
# [INFO] ILP function run time: 0.799494
# [INFO] ILP function run time: 0.881627
# [INFO] ILP function run time: 0.900762
# [INFO] ILP function run time: 0.613471
# [INFO] ILP function run time: 1.111116
# [INFO] ILP function run time: 0.661800
# [INFO] ILP function run time: 0.664343
# [INFO] ILP function run time: 0.452882
# [INFO] ILP function run time: 0.444091
# [OBJECTIVE] old cost: 68576.32015608915, new cost: 68419.97684726285
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 8 ...
# [INFO] AgglomerativeClustering function run time: 2.229098
# [INFO] MiniWeightMatching function run time: 0.085368
# [INFO] ILP function run time: 1.859469
# [INFO] ILP function run time: 1.426820
# [INFO] ILP function run time: 1.077613
# [INFO] ILP function run time: 0.924228
# [INFO] ILP function run time: 1.655319
# [INFO] ILP function run time: 0.901481
# [INFO] ILP function run time: 0.648661
# [INFO] ILP function run time: 0.536956
# [INFO] ILP function run time: 0.354807
# [INFO] ILP function run time: 1.045800
# [INFO] ILP function run time: 1.084522
# [INFO] ILP function run time: 0.435298
# [INFO] ILP function run time: 1.135208
# [INFO] ILP function run time: 0.661234
# [INFO] ILP function run time: 0.669860
# [INFO] ILP function run time: 0.445818
# [INFO] ILP function run time: 0.446114
# [INFO] ILP function run time: 0.620572
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 68419.97684726285.
# [Result]: Installation Cost: 34000 Transmission Cost: 229.97684726284933 Delay Cost 34190.0 Total Cost 68419.97684726285

# %% [markdown]
# ##### Compare the effects of different parameters on the heuristic algorithm

# %%
ha_nmaxss = HeuristicApproach(DRAW_CONTROL=True, ILP_INFO=False)
ha_nmaxss.GetSimData()

# %%
ha_nmaxss.InitializeCleanEnvironment()
ha_nmaxss.ManualChangeParameter(N_MAX_SS = 3, D_MAX = 150, c = 5, alpha = 3)
ha_nmaxss.OurHeuristic(clustering_type = 'kmeans', custom_metric = 'eu')
# Out:
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.106542
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.139473
# [INFO] MiniWeightMatching function run time: 0.027577
# [INFO] ILP function run time: 4.656014
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.145194
# [INFO] MiniWeightMatching function run time: 0.033756
# [INFO] ILP function run time: 2.394343
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.224384
# [INFO] MiniWeightMatching function run time: 0.038111
# [INFO] ILP function run time: 1.671617
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.235873
# [INFO] MiniWeightMatching function run time: 0.050368
# [INFO] ILP function run time: 1.770905
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.227254
# [INFO] MiniWeightMatching function run time: 0.226139
# [INFO] ILP function run time: 1.721550
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.241454
# [INFO] MiniWeightMatching function run time: 0.045939
# [INFO] ILP function run time: 1.684167
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.253085
# [INFO] MiniWeightMatching function run time: 0.049805
# [INFO] ILP function run time: 1.567108
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.249909
# [INFO] MiniWeightMatching function run time: 0.050445
# [INFO] ILP function run time: 1.001699
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.301275
# [INFO] MiniWeightMatching function run time: 0.055972
# [INFO] ILP function run time: 0.865372
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.350776
# [INFO] MiniWeightMatching function run time: 0.066951
# [INFO] ILP function run time: 0.914786
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.325617
# [INFO] MiniWeightMatching function run time: 0.062297
# [INFO] ILP function run time: 1.037551
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.342274
# [INFO] MiniWeightMatching function run time: 0.066456
# [INFO] ILP function run time: 0.916570
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.368070
# [INFO] MiniWeightMatching function run time: 0.074646
# [INFO] ILP function run time: 1.036214
# [INFO] ILP function run time: 0.563722
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.330417
# [INFO] MiniWeightMatching function run time: 0.339046
# [INFO] ILP function run time: 0.813291
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.392181
# [INFO] MiniWeightMatching function run time: 0.077738
# [INFO] ILP function run time: 1.421188
# [INFO] ILP function run time: 0.645846
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.436496
# [INFO] MiniWeightMatching function run time: 0.255804
# [INFO] ILP function run time: 0.605328
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.460180
# [INFO] MiniWeightMatching function run time: 0.083566
# [INFO] ILP function run time: 0.511860
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.530252
# [INFO] MiniWeightMatching function run time: 0.098909
# [INFO] ILP function run time: 0.576686
# [INFO] ILP function run time: 0.386759
# [INFO] ILP function run time: 0.461032
# [INFO] ILP function run time: 0.500729
# [INFO] ILP function run time: 0.693779
# [INFO] ILP function run time: 0.642527
# [INFO] ILP function run time: 0.796674
# [INFO] ILP function run time: 0.810366
# [INFO] ILP function run time: 0.673778
# [INFO] ILP function run time: 1.040977
# [INFO] ILP function run time: 0.526636
# [INFO] ILP function run time: 0.433315
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.422184
# [INFO] MiniWeightMatching function run time: 0.095892
# [INFO] ILP function run time: 0.730302
# [INFO] ILP function run time: 0.720961
# [INFO] ILP function run time: 0.561789
# [INFO] ILP function run time: 0.406676
# [INFO] ILP function run time: 0.677857
# [INFO] ILP function run time: 0.683489
# [INFO] ILP function run time: 0.597165
# [INFO] ILP function run time: 0.867584
# [INFO] ILP function run time: 0.586555
# [INFO] ILP function run time: 0.654734
# [INFO] ILP function run time: 0.564473
# [INFO] ILP function run time: 0.745213
# [INFO] ILP function run time: 0.662061
# [INFO] ILP function run time: 0.592313
# [INFO] ILP function run time: 0.512048
# [INFO] ILP function run time: 0.379395
# [INFO] ILP function run time: 0.649286
# [INFO] ILP function run time: 0.547605
# [INFO] ILP function run time: 0.595762
# [INFO] ILP function run time: 0.511291
# [INFO] ILP function run time: 0.512512
# [INFO] ILP function run time: 0.532123
# [INFO] ILP function run time: 0.412180
# [OBJECTIVE] old cost: inf, new cost: 69527.93520846016
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] KmeansClustering function run time: 0.476477
# [INFO] MiniWeightMatching function run time: 0.100284
# [INFO] ILP function run time: 0.374351
# [INFO] ILP function run time: 0.528365
# [INFO] ILP function run time: 0.405747
# [INFO] ILP function run time: 0.759821
# [INFO] ILP function run time: 0.526767
# [INFO] ILP function run time: 0.442262
# [INFO] ILP function run time: 0.564871
# [INFO] ILP function run time: 0.457932
# [INFO] ILP function run time: 0.519324
# [INFO] ILP function run time: 0.547283
# [INFO] ILP function run time: 0.662170
# [INFO] ILP function run time: 0.545186
# [INFO] ILP function run time: 0.559648
# [INFO] ILP function run time: 0.490507
# [INFO] ILP function run time: 0.424623
# [INFO] ILP function run time: 0.577228
# [INFO] ILP function run time: 0.670159
# [INFO] ILP function run time: 0.632254
# [INFO] ILP function run time: 0.578713
# [INFO] ILP function run time: 0.628240
# [INFO] ILP function run time: 0.634904
# [INFO] ILP function run time: 0.596488
# [INFO] ILP function run time: 0.465109
# [INFO] ILP function run time: 0.509616
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 69527.93520846016.
# [Result]: Installation Cost: 46000 Transmission Cost: 172.93520846015963 Delay Cost 23355.0 Total Cost 69527.93520846016

# %%
ha_nmaxss.InitializeCleanEnvironment()
ha_nmaxss.ManualChangeParameter(N_MAX_SS = 10, D_MAX = 150, c = 5, alpha = 3)
ha_nmaxss.OurHeuristic(clustering_type = 'kmeans', custom_metric = 'eu')
# Out:
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.131926
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.131443
# [INFO] MiniWeightMatching function run time: 0.045872
# [INFO] ILP function run time: 4.282968
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.144184
# [INFO] MiniWeightMatching function run time: 0.268059
# [INFO] ILP function run time: 4.148647
# [INFO] ILP function run time: 3.865918
# [INFO] ILP function run time: 3.568413
# [INFO] ILP function run time: 2.931928
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.171316
# [INFO] MiniWeightMatching function run time: 0.036899
# [INFO] ILP function run time: 2.564189
# [INFO] ILP function run time: 3.076554
# [INFO] ILP function run time: 2.574511
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.228180
# [INFO] MiniWeightMatching function run time: 0.037807
# [INFO] ILP function run time: 2.569807
# [INFO] ILP function run time: 2.624302
# [INFO] ILP function run time: 2.416125
# [INFO] ILP function run time: 3.899771
# [INFO] ILP function run time: 3.567215
# [INFO] ILP function run time: 3.753193
# [INFO] ILP function run time: 2.947919
# [INFO] ILP function run time: 1.996081
# [OBJECTIVE] old cost: inf, new cost: 70977.3148254776
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] KmeansClustering function run time: 0.223400
# [INFO] MiniWeightMatching function run time: 0.043736
# [INFO] ILP function run time: 2.421196
# [INFO] ILP function run time: 2.765234
# [INFO] ILP function run time: 1.983153
# [INFO] ILP function run time: 2.291347
# [INFO] ILP function run time: 1.915108
# [INFO] ILP function run time: 2.455262
# [INFO] ILP function run time: 2.560031
# [INFO] ILP function run time: 2.747841
# [INFO] ILP function run time: 2.146346
# [OBJECTIVE] old cost: 70977.3148254776, new cost: 68463.17274842551
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] KmeansClustering function run time: 0.224392
# [INFO] MiniWeightMatching function run time: 0.052826
# [INFO] ILP function run time: 2.656698
# [INFO] ILP function run time: 2.724435
# [INFO] ILP function run time: 1.631708
# [INFO] ILP function run time: 2.080440
# [INFO] ILP function run time: 1.703803
# [INFO] ILP function run time: 2.362515
# [INFO] ILP function run time: 2.328462
# [INFO] ILP function run time: 2.021137
# [INFO] ILP function run time: 1.538847
# [INFO] ILP function run time: 1.825721
# [OBJECTIVE] old cost: 68463.17274842551, new cost: 67499.3754915037
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] KmeansClustering function run time: 0.231033
# [INFO] MiniWeightMatching function run time: 0.052893
# [INFO] ILP function run time: 2.129014
# [INFO] ILP function run time: 1.246455
# [INFO] ILP function run time: 1.816738
# [INFO] ILP function run time: 1.952939
# [INFO] ILP function run time: 1.847092
# [INFO] ILP function run time: 1.274040
# [INFO] ILP function run time: 1.876660
# [INFO] ILP function run time: 1.424625
# [INFO] ILP function run time: 1.607334
# [INFO] ILP function run time: 2.094552
# [INFO] ILP function run time: 1.732326
# [OBJECTIVE] old cost: 67499.3754915037, new cost: 65701.53248930008
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 5 ...
# [INFO] KmeansClustering function run time: 0.247754
# [INFO] MiniWeightMatching function run time: 0.055460
# [INFO] ILP function run time: 1.605980
# [INFO] ILP function run time: 2.063086
# [INFO] ILP function run time: 1.396911
# [INFO] ILP function run time: 1.405757
# [INFO] ILP function run time: 2.178709
# [INFO] ILP function run time: 1.633276
# [INFO] ILP function run time: 1.448492
# [INFO] ILP function run time: 1.715934
# [INFO] ILP function run time: 1.214543
# [INFO] ILP function run time: 1.738395
# [INFO] ILP function run time: 1.290352
# [INFO] ILP function run time: 1.269850
# [OBJECTIVE] old cost: 65701.53248930008, new cost: 65246.161675868345
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 6 ...
# [INFO] KmeansClustering function run time: 0.257141
# [INFO] MiniWeightMatching function run time: 0.054815
# [INFO] ILP function run time: 1.179125
# [INFO] ILP function run time: 0.961976
# [INFO] ILP function run time: 1.013259
# [INFO] ILP function run time: 1.264786
# [INFO] ILP function run time: 1.813674
# [INFO] ILP function run time: 1.279812
# [INFO] ILP function run time: 1.678944
# [INFO] ILP function run time: 1.323867
# [INFO] ILP function run time: 1.220462
# [INFO] ILP function run time: 1.508789
# [INFO] ILP function run time: 1.417241
# [INFO] ILP function run time: 1.416071
# [INFO] ILP function run time: 1.426268
# [OBJECTIVE] old cost: 65246.161675868345, new cost: 63894.545482260815
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 7 ...
# [INFO] KmeansClustering function run time: 0.329614
# [INFO] MiniWeightMatching function run time: 0.062645
# [INFO] ILP function run time: 1.498770
# [INFO] ILP function run time: 1.037109
# [INFO] ILP function run time: 1.433839
# [INFO] ILP function run time: 1.240028
# [INFO] ILP function run time: 1.059341
# [INFO] ILP function run time: 1.336526
# [INFO] ILP function run time: 1.410205
# [INFO] ILP function run time: 1.182175
# [INFO] ILP function run time: 1.340910
# [INFO] ILP function run time: 1.334890
# [INFO] ILP function run time: 1.116026
# [INFO] ILP function run time: 1.462423
# [INFO] ILP function run time: 1.312538
# [INFO] ILP function run time: 1.043230
# [OBJECTIVE] old cost: 63894.545482260815, new cost: 63840.24608725752
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 8 ...
# [INFO] KmeansClustering function run time: 0.310515
# [INFO] MiniWeightMatching function run time: 0.063592
# [INFO] ILP function run time: 1.325339
# [INFO] ILP function run time: 1.066696
# [INFO] ILP function run time: 1.134046
# [INFO] ILP function run time: 1.041266
# [INFO] ILP function run time: 0.949240
# [INFO] ILP function run time: 1.290496
# [INFO] ILP function run time: 1.115488
# [INFO] ILP function run time: 1.023105
# [INFO] ILP function run time: 0.967074
# [INFO] ILP function run time: 1.214115
# [INFO] ILP function run time: 1.295531
# [INFO] ILP function run time: 1.059033
# [INFO] ILP function run time: 1.015046
# [INFO] ILP function run time: 1.153213
# [INFO] ILP function run time: 1.296485
# [OBJECTIVE] old cost: 63840.24608725752, new cost: 63602.58394880201
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 9 ...
# [INFO] KmeansClustering function run time: 0.329171
# [INFO] MiniWeightMatching function run time: 0.074764
# [INFO] ILP function run time: 1.028634
# [INFO] ILP function run time: 0.963041
# [INFO] ILP function run time: 1.218061
# [INFO] ILP function run time: 0.955381
# [INFO] ILP function run time: 1.205929
# [INFO] ILP function run time: 1.016925
# [INFO] ILP function run time: 1.013184
# [INFO] ILP function run time: 0.691308
# [INFO] ILP function run time: 1.276266
# [INFO] ILP function run time: 0.967272
# [INFO] ILP function run time: 1.146397
# [INFO] ILP function run time: 1.441232
# [INFO] ILP function run time: 1.157041
# [INFO] ILP function run time: 0.918483
# [INFO] ILP function run time: 0.822214
# [INFO] ILP function run time: 0.913438
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 63602.58394880201.
# [Result]: Installation Cost: 30000 Transmission Cost: 227.5839488020065 Delay Cost 33375.0 Total Cost 63602.58394880201

# %%
ha_nmaxss.InitializeCleanEnvironment()
ha_nmaxss.ManualChangeParameter(N_MAX_SS = 10, D_MAX = 100, c = 0.5, alpha = 3)
ha_nmaxss.OurHeuristic(clustering_type = 'kmeans', custom_metric = 'eu')
# Out:
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.120386
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.121935
# [INFO] MiniWeightMatching function run time: 0.027409
# [INFO] ILP function run time: 2.124991
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.145217
# [INFO] MiniWeightMatching function run time: 0.032108
# [INFO] ILP function run time: 1.318334
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.169273
# [INFO] MiniWeightMatching function run time: 0.038163
# [INFO] ILP function run time: 0.998337
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.223979
# [INFO] MiniWeightMatching function run time: 0.039690
# [INFO] ILP function run time: 0.966073
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.215443
# [INFO] MiniWeightMatching function run time: 0.041641
# [INFO] ILP function run time: 0.786066
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.217488
# [INFO] MiniWeightMatching function run time: 0.043238
# [INFO] ILP function run time: 0.800360
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.226543
# [INFO] MiniWeightMatching function run time: 0.047582
# [INFO] ILP function run time: 0.724802
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.241741
# [INFO] MiniWeightMatching function run time: 0.225013
# [INFO] ILP function run time: 0.546521
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.254081
# [INFO] MiniWeightMatching function run time: 0.058181
# [INFO] ILP function run time: 0.712152
# [INFO] ILP function run time: 0.739036
# [INFO] ILP function run time: 0.639213
# [INFO] ILP function run time: 0.811382
# [INFO] ILP function run time: 0.672842
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.330004
# [INFO] MiniWeightMatching function run time: 0.269385
# [INFO] ILP function run time: 0.616904
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.310573
# [INFO] MiniWeightMatching function run time: 0.065345
# [INFO] ILP function run time: 0.742409
# [INFO] ILP function run time: 0.650150
# [INFO] ILP function run time: 0.741096
# [INFO] ILP function run time: 0.603312
# [INFO] ILP function run time: 0.571982
# [INFO] ILP function run time: 0.649113
# [INFO] ILP function run time: 0.451019
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.327544
# [INFO] MiniWeightMatching function run time: 0.067602
# [INFO] ILP function run time: 0.624127
# [INFO] ILP function run time: 0.492678
# [INFO] ILP function run time: 0.596601
# [INFO] ILP function run time: 0.591080
# [INFO] ILP function run time: 0.761421
# [INFO] ILP function run time: 0.786564
# [INFO] ILP function run time: 0.577305
# [INFO] ILP function run time: 0.639957
# [INFO] ILP function run time: 0.665156
# [INFO] ILP function run time: 0.590971
# [INFO] ILP function run time: 0.563121
# [INFO] ILP function run time: 0.765826
# [INFO] ILP function run time: 0.752421
# [INFO] ILP function run time: 0.784417
# [INFO] ILP function run time: 0.520140
# [INFO] ILP function run time: 0.785966
# [OBJECTIVE] old cost: inf, new cost: 38205.396479917435
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] KmeansClustering function run time: 0.343264
# [INFO] MiniWeightMatching function run time: 0.068935
# [INFO] ILP function run time: 0.503525
# [INFO] ILP function run time: 0.483765
# [INFO] ILP function run time: 0.543226
# [INFO] ILP function run time: 0.639677
# [INFO] ILP function run time: 0.550112
# [INFO] ILP function run time: 0.591593
# [INFO] ILP function run time: 0.561673
# [INFO] ILP function run time: 0.476394
# [INFO] ILP function run time: 0.601783
# [INFO] ILP function run time: 0.463847
# [INFO] ILP function run time: 0.565734
# [INFO] ILP function run time: 0.636692
# [INFO] ILP function run time: 0.466849
# [INFO] ILP function run time: 0.491200
# [INFO] ILP function run time: 0.477854
# [INFO] ILP function run time: 0.609960
# [INFO] ILP function run time: 0.560471
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 38205.396479917435.
# [Result]: Installation Cost: 32000 Transmission Cost: 111.39647991743732 Delay Cost 6094.0 Total Cost 38205.396479917435

# %%
ha_nmaxss.InitializeCleanEnvironment()
ha_nmaxss.ManualChangeParameter(N_MAX_SS = 10, D_MAX = 100, c = 5, alpha = 3)
ha_nmaxss.OurHeuristic(clustering_type = 'kmeans', custom_metric = 'eu')
# Out:
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.122626
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.122175
# [INFO] MiniWeightMatching function run time: 0.026609
# [INFO] ILP function run time: 2.143384
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.144518
# [INFO] MiniWeightMatching function run time: 0.032492
# [INFO] ILP function run time: 1.387260
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.174163
# [INFO] MiniWeightMatching function run time: 0.036270
# [INFO] ILP function run time: 0.844757
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.225206
# [INFO] MiniWeightMatching function run time: 0.042319
# [INFO] ILP function run time: 0.820136
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.217148
# [INFO] MiniWeightMatching function run time: 0.040537
# [INFO] ILP function run time: 0.773743
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.217121
# [INFO] MiniWeightMatching function run time: 0.046481
# [INFO] ILP function run time: 0.801186
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.234121
# [INFO] MiniWeightMatching function run time: 0.046370
# [INFO] ILP function run time: 0.726158
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.241547
# [INFO] MiniWeightMatching function run time: 0.053627
# [INFO] ILP function run time: 0.544720
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.251516
# [INFO] MiniWeightMatching function run time: 0.227972
# [INFO] ILP function run time: 0.899707
# [INFO] ILP function run time: 0.585453
# [INFO] ILP function run time: 0.630235
# [INFO] ILP function run time: 0.823495
# [INFO] ILP function run time: 0.859741
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.328976
# [INFO] MiniWeightMatching function run time: 0.060729
# [INFO] ILP function run time: 0.421372
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.307682
# [INFO] MiniWeightMatching function run time: 0.222806
# [INFO] ILP function run time: 0.922936
# [INFO] ILP function run time: 0.845981
# [INFO] ILP function run time: 0.571258
# [INFO] ILP function run time: 0.610861
# [INFO] ILP function run time: 0.767492
# [INFO] ILP function run time: 0.664100
# [INFO] ILP function run time: 0.441821
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.327538
# [INFO] MiniWeightMatching function run time: 0.066869
# [INFO] ILP function run time: 0.641733
# [INFO] ILP function run time: 0.494956
# [INFO] ILP function run time: 0.604241
# [INFO] ILP function run time: 0.602233
# [INFO] ILP function run time: 0.776950
# [INFO] ILP function run time: 0.813818
# [INFO] ILP function run time: 0.591690
# [INFO] ILP function run time: 0.448573
# [INFO] ILP function run time: 0.655358
# [INFO] ILP function run time: 0.592532
# [INFO] ILP function run time: 0.564020
# [INFO] ILP function run time: 0.771847
# [INFO] ILP function run time: 0.536442
# [INFO] ILP function run time: 0.570531
# [INFO] ILP function run time: 0.514940
# [INFO] ILP function run time: 0.795837
# [OBJECTIVE] old cost: inf, new cost: 93051.39647991746
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] KmeansClustering function run time: 0.375166
# [INFO] MiniWeightMatching function run time: 0.071606
# [INFO] ILP function run time: 0.522707
# [INFO] ILP function run time: 0.678376
# [INFO] ILP function run time: 0.547616
# [INFO] ILP function run time: 0.645438
# [INFO] ILP function run time: 0.546916
# [INFO] ILP function run time: 0.637487
# [INFO] ILP function run time: 0.572763
# [INFO] ILP function run time: 0.685049
# [INFO] ILP function run time: 0.635397
# [INFO] ILP function run time: 0.468410
# [INFO] ILP function run time: 0.588539
# [INFO] ILP function run time: 0.641063
# [INFO] ILP function run time: 0.682046
# [INFO] ILP function run time: 0.510910
# [INFO] ILP function run time: 0.478458
# [INFO] ILP function run time: 0.815554
# [INFO] ILP function run time: 0.794771
# [OBJECTIVE] old cost: 93051.39647991746, new cost: 92407.59018047864
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] KmeansClustering function run time: 0.317583
# [INFO] MiniWeightMatching function run time: 0.076056
# [INFO] ILP function run time: 0.477562
# [INFO] ILP function run time: 0.665264
# [INFO] ILP function run time: 0.548668
# [INFO] ILP function run time: 0.585252
# [INFO] ILP function run time: 0.411778
# [INFO] ILP function run time: 0.490369
# [INFO] ILP function run time: 0.481678
# [INFO] ILP function run time: 0.575255
# [INFO] ILP function run time: 0.816666
# [INFO] ILP function run time: 0.426543
# [INFO] ILP function run time: 0.546103
# [INFO] ILP function run time: 0.476616
# [INFO] ILP function run time: 0.572352
# [INFO] ILP function run time: 0.665106
# [INFO] ILP function run time: 0.731370
# [INFO] ILP function run time: 0.543571
# [INFO] ILP function run time: 0.682960
# [INFO] ILP function run time: 0.658991
# [OBJECTIVE] old cost: 92407.59018047864, new cost: 92162.76554987425
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] KmeansClustering function run time: 0.347341
# [INFO] MiniWeightMatching function run time: 0.080185
# [INFO] ILP function run time: 0.403463
# [INFO] ILP function run time: 0.753898
# [INFO] ILP function run time: 0.403182
# [INFO] ILP function run time: 0.463926
# [INFO] ILP function run time: 0.567343
# [INFO] ILP function run time: 0.452736
# [INFO] ILP function run time: 0.516330
# [INFO] ILP function run time: 0.458737
# [INFO] ILP function run time: 0.397718
# [INFO] ILP function run time: 0.658852
# [INFO] ILP function run time: 0.433810
# [INFO] ILP function run time: 0.548826
# [INFO] ILP function run time: 0.464947
# [INFO] ILP function run time: 0.441075
# [INFO] ILP function run time: 0.543573
# [INFO] ILP function run time: 0.474591
# [INFO] ILP function run time: 0.382245
# [INFO] ILP function run time: 0.570899
# [INFO] ILP function run time: 0.449743
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 92162.76554987425.
# [Result]: Installation Cost: 36000 Transmission Cost: 102.76554987424606 Delay Cost 56060.0 Total Cost 92162.76554987425

# %%
ha_nmaxss.InitializeCleanEnvironment()
ha_nmaxss.ManualChangeParameter(N_MAX_SS = 10, D_MAX = 100, c = 50, alpha = 3)
ha_nmaxss.OurHeuristic(clustering_type = 'kmeans', custom_metric = 'eu')
# Out:
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.119381
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.129242
# [INFO] MiniWeightMatching function run time: 0.027727
# [INFO] ILP function run time: 2.165380
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.145801
# [INFO] MiniWeightMatching function run time: 0.035145
# [INFO] ILP function run time: 1.218700
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.168471
# [INFO] MiniWeightMatching function run time: 0.035262
# [INFO] ILP function run time: 0.832002
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.224578
# [INFO] MiniWeightMatching function run time: 0.041866
# [INFO] ILP function run time: 0.828353
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.215297
# [INFO] MiniWeightMatching function run time: 0.040106
# [INFO] ILP function run time: 0.796371
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.222270
# [INFO] MiniWeightMatching function run time: 0.047584
# [INFO] ILP function run time: 0.826562
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.231332
# [INFO] MiniWeightMatching function run time: 0.049638
# [INFO] ILP function run time: 0.722776
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.252730
# [INFO] MiniWeightMatching function run time: 0.055211
# [INFO] ILP function run time: 0.552986
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.251866
# [INFO] MiniWeightMatching function run time: 0.229287
# [INFO] ILP function run time: 0.888302
# [INFO] ILP function run time: 0.747253
# [INFO] ILP function run time: 0.631257
# [INFO] ILP function run time: 0.826163
# [INFO] ILP function run time: 0.672767
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.332184
# [INFO] MiniWeightMatching function run time: 0.275853
# [INFO] ILP function run time: 0.418534
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.306939
# [INFO] MiniWeightMatching function run time: 0.066703
# [INFO] ILP function run time: 0.741000
# [INFO] ILP function run time: 0.651847
# [INFO] ILP function run time: 0.569777
# [INFO] ILP function run time: 0.602708
# [INFO] ILP function run time: 0.774738
# [INFO] ILP function run time: 0.663646
# [INFO] ILP function run time: 0.633737
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.325825
# [INFO] MiniWeightMatching function run time: 0.065323
# [INFO] ILP function run time: 0.634205
# [INFO] ILP function run time: 0.497521
# [INFO] ILP function run time: 0.616825
# [INFO] ILP function run time: 0.586716
# [INFO] ILP function run time: 0.772045
# [INFO] ILP function run time: 0.625283
# [INFO] ILP function run time: 0.578361
# [INFO] ILP function run time: 0.443569
# [INFO] ILP function run time: 0.839638
# [INFO] ILP function run time: 0.595508
# [INFO] ILP function run time: 0.571907
# [INFO] ILP function run time: 0.767725
# [INFO] ILP function run time: 0.761667
# [INFO] ILP function run time: 0.790942
# [INFO] ILP function run time: 0.515011
# [INFO] ILP function run time: 0.565751
# [OBJECTIVE] old cost: inf, new cost: 641511.3964799175
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] KmeansClustering function run time: 0.371944
# [INFO] MiniWeightMatching function run time: 0.074942
# [INFO] ILP function run time: 0.503274
# [INFO] ILP function run time: 0.475583
# [INFO] ILP function run time: 0.545474
# [INFO] ILP function run time: 0.648304
# [INFO] ILP function run time: 0.557625
# [INFO] ILP function run time: 0.593384
# [INFO] ILP function run time: 0.555978
# [INFO] ILP function run time: 0.484536
# [INFO] ILP function run time: 0.620811
# [INFO] ILP function run time: 0.458902
# [INFO] ILP function run time: 0.593455
# [INFO] ILP function run time: 0.639289
# [INFO] ILP function run time: 0.460856
# [INFO] ILP function run time: 0.500200
# [INFO] ILP function run time: 0.472671
# [INFO] ILP function run time: 0.833169
# [INFO] ILP function run time: 0.769420
# [OBJECTIVE] old cost: 641511.3964799175, new cost: 617107.5901804786
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] KmeansClustering function run time: 0.318233
# [INFO] MiniWeightMatching function run time: 0.075774
# [INFO] ILP function run time: 0.478738
# [INFO] ILP function run time: 0.675401
# [INFO] ILP function run time: 0.547080
# [INFO] ILP function run time: 0.571253
# [INFO] ILP function run time: 0.597831
# [INFO] ILP function run time: 0.497129
# [INFO] ILP function run time: 0.488116
# [INFO] ILP function run time: 0.374565
# [INFO] ILP function run time: 0.607140
# [INFO] ILP function run time: 0.425458
# [INFO] ILP function run time: 0.548604
# [INFO] ILP function run time: 0.684435
# [INFO] ILP function run time: 0.780340
# [INFO] ILP function run time: 0.663011
# [INFO] ILP function run time: 0.496634
# [INFO] ILP function run time: 0.549105
# [INFO] ILP function run time: 0.453233
# [INFO] ILP function run time: 0.425004
# [OBJECTIVE] old cost: 617107.5901804786, new cost: 596702.7655498743
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] KmeansClustering function run time: 0.344001
# [INFO] MiniWeightMatching function run time: 0.087312
# [INFO] ILP function run time: 0.597156
# [INFO] ILP function run time: 0.555436
# [INFO] ILP function run time: 0.390623
# [INFO] ILP function run time: 0.646711
# [INFO] ILP function run time: 0.538236
# [INFO] ILP function run time: 0.444208
# [INFO] ILP function run time: 0.509537
# [INFO] ILP function run time: 0.662973
# [INFO] ILP function run time: 0.598865
# [INFO] ILP function run time: 0.457614
# [INFO] ILP function run time: 0.452570
# [INFO] ILP function run time: 0.541465
# [INFO] ILP function run time: 0.463541
# [INFO] ILP function run time: 0.449881
# [INFO] ILP function run time: 0.550865
# [INFO] ILP function run time: 0.468923
# [INFO] ILP function run time: 0.386748
# [INFO] ILP function run time: 0.586577
# [INFO] ILP function run time: 0.684164
# [OBJECTIVE] old cost: 596702.7655498743, new cost: 581950.311902952
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 5 ...
# [INFO] KmeansClustering function run time: 0.431603
# [INFO] MiniWeightMatching function run time: 0.081183
# [INFO] ILP function run time: 0.501920
# [INFO] ILP function run time: 0.656984
# [INFO] ILP function run time: 0.680270
# [INFO] ILP function run time: 0.419650
# [INFO] ILP function run time: 0.466838
# [INFO] ILP function run time: 0.415116
# [INFO] ILP function run time: 0.368562
# [INFO] ILP function run time: 0.406120
# [INFO] ILP function run time: 0.732691
# [INFO] ILP function run time: 0.515333
# [INFO] ILP function run time: 0.351050
# [INFO] ILP function run time: 0.406178
# [INFO] ILP function run time: 0.366182
# [INFO] ILP function run time: 0.493811
# [INFO] ILP function run time: 0.481538
# [INFO] ILP function run time: 0.394781
# [INFO] ILP function run time: 0.658374
# [INFO] ILP function run time: 0.379162
# [INFO] ILP function run time: 0.510701
# [INFO] ILP function run time: 0.584822
# [OBJECTIVE] old cost: 581950.311902952, new cost: 559845.8253744184
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 6 ...
# [INFO] KmeansClustering function run time: 0.453743
# [INFO] MiniWeightMatching function run time: 0.094328
# [INFO] ILP function run time: 0.426830
# [INFO] ILP function run time: 0.599221
# [INFO] ILP function run time: 0.376656
# [INFO] ILP function run time: 0.284529
# [INFO] ILP function run time: 0.499379
# [INFO] ILP function run time: 0.410115
# [INFO] ILP function run time: 0.451560
# [INFO] ILP function run time: 0.449087
# [INFO] ILP function run time: 0.492118
# [INFO] ILP function run time: 0.385330
# [INFO] ILP function run time: 0.517965
# [INFO] ILP function run time: 0.378286
# [INFO] ILP function run time: 0.322022
# [INFO] ILP function run time: 0.482218
# [INFO] ILP function run time: 0.354768
# [INFO] ILP function run time: 0.390676
# [INFO] ILP function run time: 0.336453
# [INFO] ILP function run time: 0.421385
# [INFO] ILP function run time: 0.387066
# [INFO] ILP function run time: 0.730360
# [INFO] ILP function run time: 0.411231
# [OBJECTIVE] old cost: 559845.8253744184, new cost: 542392.8307519214
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 7 ...
# [INFO] KmeansClustering function run time: 0.438683
# [INFO] MiniWeightMatching function run time: 0.094591
# [INFO] ILP function run time: 0.708629
# [INFO] ILP function run time: 0.272570
# [INFO] ILP function run time: 0.311073
# [INFO] ILP function run time: 0.332282
# [INFO] ILP function run time: 0.424665
# [INFO] ILP function run time: 0.398989
# [INFO] ILP function run time: 0.647066
# [INFO] ILP function run time: 0.459526
# [INFO] ILP function run time: 0.411599
# [INFO] ILP function run time: 0.501022
# [INFO] ILP function run time: 0.333950
# [INFO] ILP function run time: 0.398395
# [INFO] ILP function run time: 0.444512
# [INFO] ILP function run time: 0.457793
# [INFO] ILP function run time: 0.526218
# [INFO] ILP function run time: 0.338792
# [INFO] ILP function run time: 0.457711
# [INFO] ILP function run time: 0.443044
# [INFO] ILP function run time: 0.332571
# [INFO] ILP function run time: 0.358554
# [INFO] ILP function run time: 0.374586
# [INFO] ILP function run time: 0.612385
# [OBJECTIVE] old cost: 542392.8307519214, new cost: 528589.7447650078
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 8 ...
# [INFO] KmeansClustering function run time: 0.435748
# [INFO] MiniWeightMatching function run time: 0.100384
# [INFO] ILP function run time: 0.443046
# [INFO] ILP function run time: 0.581425
# [INFO] ILP function run time: 0.353666
# [INFO] ILP function run time: 0.286348
# [INFO] ILP function run time: 0.449671
# [INFO] ILP function run time: 0.428402
# [INFO] ILP function run time: 0.438719
# [INFO] ILP function run time: 0.756223
# [INFO] ILP function run time: 0.372647
# [INFO] ILP function run time: 1.074912
# [INFO] ILP function run time: 0.450423
# [INFO] ILP function run time: 0.389778
# [INFO] ILP function run time: 0.687413
# [INFO] ILP function run time: 0.394199
# [INFO] ILP function run time: 0.347044
# [INFO] ILP function run time: 0.576084
# [INFO] ILP function run time: 0.428144
# [INFO] ILP function run time: 0.599364
# [INFO] ILP function run time: 0.628813
# [INFO] ILP function run time: 0.313731
# [INFO] ILP function run time: 0.337699
# [INFO] ILP function run time: 0.468134
# [INFO] ILP function run time: 0.286014
# [OBJECTIVE] old cost: 528589.7447650078, new cost: 512186.08178767527
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 9 ...
# [INFO] KmeansClustering function run time: 0.705594
# [INFO] MiniWeightMatching function run time: 0.146690
# [INFO] ILP function run time: 0.381371
# [INFO] ILP function run time: 0.451057
# [INFO] ILP function run time: 0.302579
# [INFO] ILP function run time: 0.384445
# [INFO] ILP function run time: 0.352981
# [INFO] ILP function run time: 0.376673
# [INFO] ILP function run time: 0.509413
# [INFO] ILP function run time: 0.308168
# [INFO] ILP function run time: 0.432309
# [INFO] ILP function run time: 0.326631
# [INFO] ILP function run time: 0.424095
# [INFO] ILP function run time: 0.427914
# [INFO] ILP function run time: 0.439051
# [INFO] ILP function run time: 0.407228
# [INFO] ILP function run time: 0.329667
# [INFO] ILP function run time: 0.398795
# [INFO] ILP function run time: 0.400688
# [INFO] ILP function run time: 0.432807
# [INFO] ILP function run time: 0.388118
# [INFO] ILP function run time: 0.589095
# [INFO] ILP function run time: 0.397211
# [INFO] ILP function run time: 0.396882
# [INFO] ILP function run time: 0.324223
# [INFO] ILP function run time: 0.351245
# [OBJECTIVE] old cost: 512186.08178767527, new cost: 501432.9341752383
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 10 ...
# [INFO] KmeansClustering function run time: 0.559032
# [INFO] MiniWeightMatching function run time: 0.125872
# [INFO] ILP function run time: 0.342461
# [INFO] ILP function run time: 0.355168
# [INFO] ILP function run time: 0.234123
# [INFO] ILP function run time: 0.344425
# [INFO] ILP function run time: 0.384213
# [INFO] ILP function run time: 0.400536
# [INFO] ILP function run time: 0.352459
# [INFO] ILP function run time: 0.308913
# [INFO] ILP function run time: 0.572126
# [INFO] ILP function run time: 0.372702
# [INFO] ILP function run time: 0.354710
# [INFO] ILP function run time: 0.293863
# [INFO] ILP function run time: 0.282462
# [INFO] ILP function run time: 0.370118
# [INFO] ILP function run time: 0.335381
# [INFO] ILP function run time: 0.642044
# [INFO] ILP function run time: 0.384048
# [INFO] ILP function run time: 0.898580
# [INFO] ILP function run time: 0.443011
# [INFO] ILP function run time: 0.313324
# [INFO] ILP function run time: 0.286171
# [INFO] ILP function run time: 0.424888
# [INFO] ILP function run time: 0.378528
# [INFO] ILP function run time: 0.448602
# [INFO] ILP function run time: 0.427085
# [OBJECTIVE] old cost: 501432.9341752383, new cost: 482332.0440031252
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 11 ...
# [INFO] KmeansClustering function run time: 0.508741
# [INFO] MiniWeightMatching function run time: 0.121321
# [INFO] ILP function run time: 0.287421
# [INFO] ILP function run time: 0.356192
# [INFO] ILP function run time: 0.415621
# [INFO] ILP function run time: 0.619043
# [INFO] ILP function run time: 0.459943
# [INFO] ILP function run time: 0.694295
# [INFO] ILP function run time: 0.325022
# [INFO] ILP function run time: 0.336376
# [INFO] ILP function run time: 0.479755
# [INFO] ILP function run time: 0.286617
# [INFO] ILP function run time: 0.393840
# [INFO] ILP function run time: 0.369356
# [INFO] ILP function run time: 0.309565
# [INFO] ILP function run time: 0.381122
# [INFO] ILP function run time: 0.450376
# [INFO] ILP function run time: 0.561505
# [INFO] ILP function run time: 0.500561
# [INFO] ILP function run time: 0.350698
# [INFO] ILP function run time: 0.394113
# [INFO] ILP function run time: 0.476000
# [INFO] ILP function run time: 0.373853
# [INFO] ILP function run time: 0.565406
# [INFO] ILP function run time: 0.681016
# [INFO] ILP function run time: 0.313657
# [INFO] ILP function run time: 0.596569
# [INFO] ILP function run time: 0.287156
# [OBJECTIVE] old cost: 482332.0440031252, new cost: 471479.85786003945
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 12 ...
# [INFO] KmeansClustering function run time: 0.683454
# [INFO] MiniWeightMatching function run time: 0.542245
# [INFO] ILP function run time: 0.351771
# [INFO] ILP function run time: 0.331295
# [INFO] ILP function run time: 0.433511
# [INFO] ILP function run time: 0.405063
# [INFO] ILP function run time: 0.332440
# [INFO] ILP function run time: 0.407419
# [INFO] ILP function run time: 0.502247
# [INFO] ILP function run time: 0.258779
# [INFO] ILP function run time: 0.463433
# [INFO] ILP function run time: 0.251900
# [INFO] ILP function run time: 0.406872
# [INFO] ILP function run time: 0.398788
# [INFO] ILP function run time: 0.545016
# [INFO] ILP function run time: 0.280389
# [INFO] ILP function run time: 0.401446
# [INFO] ILP function run time: 0.366360
# [INFO] ILP function run time: 0.525714
# [INFO] ILP function run time: 0.245002
# [INFO] ILP function run time: 0.298792
# [INFO] ILP function run time: 0.368436
# [INFO] ILP function run time: 0.274218
# [INFO] ILP function run time: 0.235662
# [INFO] ILP function run time: 0.248553
# [INFO] ILP function run time: 0.365459
# [INFO] ILP function run time: 0.427767
# [INFO] ILP function run time: 0.664225
# [INFO] ILP function run time: 0.309513
# [OBJECTIVE] old cost: 471479.85786003945, new cost: 461677.7146106063
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 13 ...
# [INFO] KmeansClustering function run time: 0.836354
# [INFO] MiniWeightMatching function run time: 0.659104
# [INFO] ILP function run time: 0.224376
# [INFO] ILP function run time: 0.248153
# [INFO] ILP function run time: 0.383927
# [INFO] ILP function run time: 0.438110
# [INFO] ILP function run time: 0.355707
# [INFO] ILP function run time: 0.389722
# [INFO] ILP function run time: 0.298001
# [INFO] ILP function run time: 0.286998
# [INFO] ILP function run time: 0.265736
# [INFO] ILP function run time: 0.357112
# [INFO] ILP function run time: 0.329019
# [INFO] ILP function run time: 0.302777
# [INFO] ILP function run time: 0.704605
# [INFO] ILP function run time: 0.223654
# [INFO] ILP function run time: 0.244036
# [INFO] ILP function run time: 0.325009
# [INFO] ILP function run time: 0.252388
# [INFO] ILP function run time: 0.291053
# [INFO] ILP function run time: 0.266508
# [INFO] ILP function run time: 0.377645
# [INFO] ILP function run time: 0.280704
# [INFO] ILP function run time: 0.594363
# [INFO] ILP function run time: 0.307482
# [INFO] ILP function run time: 0.346040
# [INFO] ILP function run time: 0.315908
# [INFO] ILP function run time: 0.298036
# [INFO] ILP function run time: 0.263875
# [INFO] ILP function run time: 0.231373
# [OBJECTIVE] old cost: 461677.7146106063, new cost: 454426.39347027545
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 14 ...
# [INFO] KmeansClustering function run time: 0.514135
# [INFO] MiniWeightMatching function run time: 0.480802
# [INFO] ILP function run time: 0.234921
# [INFO] ILP function run time: 0.252773
# [INFO] ILP function run time: 0.229381
# [INFO] ILP function run time: 0.261084
# [INFO] ILP function run time: 0.343535
# [INFO] ILP function run time: 0.273952
# [INFO] ILP function run time: 0.332352
# [INFO] ILP function run time: 0.306513
# [INFO] ILP function run time: 0.332082
# [INFO] ILP function run time: 0.264221
# [INFO] ILP function run time: 0.264057
# [INFO] ILP function run time: 0.257348
# [INFO] ILP function run time: 0.271115
# [INFO] ILP function run time: 0.202802
# [INFO] ILP function run time: 0.466624
# [INFO] ILP function run time: 0.251670
# [INFO] ILP function run time: 0.221240
# [INFO] ILP function run time: 0.287292
# [INFO] ILP function run time: 0.140246
# [INFO] ILP function run time: 0.259251
# [INFO] ILP function run time: 0.230769
# [INFO] ILP function run time: 0.366789
# [INFO] ILP function run time: 0.384238
# [INFO] ILP function run time: 0.535144
# [INFO] ILP function run time: 0.295391
# [INFO] ILP function run time: 0.306692
# [INFO] ILP function run time: 0.266114
# [INFO] ILP function run time: 0.243110
# [INFO] ILP function run time: 0.212399
# [OBJECTIVE] old cost: 454426.39347027545, new cost: 442723.9054580306
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 15 ...
# [INFO] KmeansClustering function run time: 0.580945
# [INFO] MiniWeightMatching function run time: 0.139436
# [INFO] ILP function run time: 0.447277
# [INFO] ILP function run time: 0.521691
# [INFO] ILP function run time: 0.416806
# [INFO] ILP function run time: 0.510645
# [INFO] ILP function run time: 0.262621
# [INFO] ILP function run time: 0.306468
# [INFO] ILP function run time: 0.414510
# [INFO] ILP function run time: 0.288546
# [INFO] ILP function run time: 0.280568
# [INFO] ILP function run time: 0.237339
# [INFO] ILP function run time: 0.247152
# [INFO] ILP function run time: 0.513962
# [INFO] ILP function run time: 0.185670
# [INFO] ILP function run time: 0.286020
# [INFO] ILP function run time: 0.828983
# [INFO] ILP function run time: 0.762339
# [INFO] ILP function run time: 0.512265
# [INFO] ILP function run time: 0.278904
# [INFO] ILP function run time: 0.236874
# [INFO] ILP function run time: 0.387049
# [INFO] ILP function run time: 0.147458
# [INFO] ILP function run time: 0.274704
# [INFO] ILP function run time: 0.260971
# [INFO] ILP function run time: 0.375586
# [INFO] ILP function run time: 0.366458
# [INFO] ILP function run time: 0.218565
# [INFO] ILP function run time: 0.249729
# [INFO] ILP function run time: 0.268151
# [INFO] ILP function run time: 0.381871
# [INFO] ILP function run time: 0.232011
# [OBJECTIVE] old cost: 442723.9054580306, new cost: 437272.0581551259
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 16 ...
# [INFO] KmeansClustering function run time: 0.643856
# [INFO] MiniWeightMatching function run time: 0.146346
# [INFO] ILP function run time: 0.364392
# [INFO] ILP function run time: 0.214767
# [INFO] ILP function run time: 0.234535
# [INFO] ILP function run time: 0.284729
# [INFO] ILP function run time: 0.245663
# [INFO] ILP function run time: 0.285637
# [INFO] ILP function run time: 0.504523
# [INFO] ILP function run time: 0.385099
# [INFO] ILP function run time: 0.222944
# [INFO] ILP function run time: 0.268769
# [INFO] ILP function run time: 0.324388
# [INFO] ILP function run time: 0.300142
# [INFO] ILP function run time: 0.334523
# [INFO] ILP function run time: 0.238636
# [INFO] ILP function run time: 0.759917
# [INFO] ILP function run time: 0.205318
# [INFO] ILP function run time: 0.291126
# [INFO] ILP function run time: 0.232053
# [INFO] ILP function run time: 0.275331
# [INFO] ILP function run time: 0.402285
# [INFO] ILP function run time: 0.283106
# [INFO] ILP function run time: 0.211082
# [INFO] ILP function run time: 0.246070
# [INFO] ILP function run time: 0.208154
# [INFO] ILP function run time: 0.314424
# [INFO] ILP function run time: 0.268769
# [INFO] ILP function run time: 0.521018
# [INFO] ILP function run time: 0.228387
# [INFO] ILP function run time: 0.251966
# [INFO] ILP function run time: 0.221006
# [INFO] ILP function run time: 0.310633
# [OBJECTIVE] old cost: 437272.0581551259, new cost: 427971.13289199624
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 17 ...
# [INFO] KmeansClustering function run time: 0.599907
# [INFO] MiniWeightMatching function run time: 0.254008
# [INFO] ILP function run time: 0.327849
# [INFO] ILP function run time: 0.212906
# [INFO] ILP function run time: 0.326915
# [INFO] ILP function run time: 0.547560
# [INFO] ILP function run time: 0.658855
# [INFO] ILP function run time: 0.297587
# [INFO] ILP function run time: 0.223420
# [INFO] ILP function run time: 0.265348
# [INFO] ILP function run time: 0.558410
# [INFO] ILP function run time: 0.198782
# [INFO] ILP function run time: 0.300140
# [INFO] ILP function run time: 0.311536
# [INFO] ILP function run time: 0.231911
# [INFO] ILP function run time: 0.184604
# [INFO] ILP function run time: 0.251498
# [INFO] ILP function run time: 0.319005
# [INFO] ILP function run time: 0.307572
# [INFO] ILP function run time: 0.303999
# [INFO] ILP function run time: 0.488159
# [INFO] ILP function run time: 0.255972
# [INFO] ILP function run time: 0.320160
# [INFO] ILP function run time: 0.295257
# [INFO] ILP function run time: 0.296450
# [INFO] ILP function run time: 0.315111
# [INFO] ILP function run time: 0.349765
# [INFO] ILP function run time: 0.198429
# [INFO] ILP function run time: 0.209809
# [INFO] ILP function run time: 0.290223
# [INFO] ILP function run time: 0.276253
# [INFO] ILP function run time: 0.234165
# [INFO] ILP function run time: 0.268017
# [INFO] ILP function run time: 0.219788
# [OBJECTIVE] old cost: 427971.13289199624, new cost: 420119.51701859257
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 18 ...
# [INFO] KmeansClustering function run time: 0.547989
# [INFO] MiniWeightMatching function run time: 0.163564
# [INFO] ILP function run time: 0.279688
# [INFO] ILP function run time: 0.275863
# [INFO] ILP function run time: 0.260336
# [INFO] ILP function run time: 0.235457
# [INFO] ILP function run time: 0.333086
# [INFO] ILP function run time: 0.227691
# [INFO] ILP function run time: 0.229824
# [INFO] ILP function run time: 0.245895
# [INFO] ILP function run time: 0.267275
# [INFO] ILP function run time: 0.376798
# [INFO] ILP function run time: 0.161203
# [INFO] ILP function run time: 0.203772
# [INFO] ILP function run time: 0.275331
# [INFO] ILP function run time: 0.194177
# [INFO] ILP function run time: 0.208357
# [INFO] ILP function run time: 0.259988
# [INFO] ILP function run time: 0.511231
# [INFO] ILP function run time: 0.194992
# [INFO] ILP function run time: 0.489392
# [INFO] ILP function run time: 0.232807
# [INFO] ILP function run time: 0.207524
# [INFO] ILP function run time: 0.202704
# [INFO] ILP function run time: 0.235497
# [INFO] ILP function run time: 0.252568
# [INFO] ILP function run time: 0.203057
# [INFO] ILP function run time: 0.277625
# [INFO] ILP function run time: 0.290960
# [INFO] ILP function run time: 0.241330
# [INFO] ILP function run time: 0.467726
# [INFO] ILP function run time: 0.258581
# [INFO] ILP function run time: 0.476107
# [INFO] ILP function run time: 0.189494
# [INFO] ILP function run time: 0.180982
# [OBJECTIVE] old cost: 420119.51701859257, new cost: 416317.72967421525
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 19 ...
# [INFO] KmeansClustering function run time: 0.710401
# [INFO] MiniWeightMatching function run time: 0.487590
# [INFO] ILP function run time: 0.265574
# [INFO] ILP function run time: 0.287987
# [INFO] ILP function run time: 0.186775
# [INFO] ILP function run time: 0.190016
# [INFO] ILP function run time: 0.331339
# [INFO] ILP function run time: 0.475228
# [INFO] ILP function run time: 0.271163
# [INFO] ILP function run time: 0.190447
# [INFO] ILP function run time: 0.211764
# [INFO] ILP function run time: 0.197519
# [INFO] ILP function run time: 0.174979
# [INFO] ILP function run time: 0.215402
# [INFO] ILP function run time: 0.257051
# [INFO] ILP function run time: 0.266333
# [INFO] ILP function run time: 0.324650
# [INFO] ILP function run time: 0.480937
# [INFO] ILP function run time: 0.207351
# [INFO] ILP function run time: 0.169919
# [INFO] ILP function run time: 0.205719
# [INFO] ILP function run time: 0.185334
# [INFO] ILP function run time: 0.278881
# [INFO] ILP function run time: 0.225788
# [INFO] ILP function run time: 0.271559
# [INFO] ILP function run time: 0.266304
# [INFO] ILP function run time: 0.220229
# [INFO] ILP function run time: 0.289660
# [INFO] ILP function run time: 0.244074
# [INFO] ILP function run time: 0.256009
# [INFO] ILP function run time: 0.230335
# [INFO] ILP function run time: 0.250762
# [INFO] ILP function run time: 0.201220
# [INFO] ILP function run time: 0.306195
# [INFO] ILP function run time: 0.241292
# [INFO] ILP function run time: 0.239912
# [OBJECTIVE] old cost: 416317.72967421525, new cost: 407966.4152604337
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 20 ...
# [INFO] KmeansClustering function run time: 0.766096
# [INFO] MiniWeightMatching function run time: 0.262096
# [INFO] ILP function run time: 0.184813
# [INFO] ILP function run time: 0.286951
# [INFO] ILP function run time: 0.284143
# [INFO] ILP function run time: 0.311192
# [INFO] ILP function run time: 0.288382
# [INFO] ILP function run time: 0.122356
# [INFO] ILP function run time: 0.251367
# [INFO] ILP function run time: 0.198652
# [INFO] ILP function run time: 0.151191
# [INFO] ILP function run time: 0.308264
# [INFO] ILP function run time: 0.176135
# [INFO] ILP function run time: 0.161438
# [INFO] ILP function run time: 0.291032
# [INFO] ILP function run time: 0.217667
# [INFO] ILP function run time: 0.277993
# [INFO] ILP function run time: 0.357484
# [INFO] ILP function run time: 0.366997
# [INFO] ILP function run time: 0.244138
# [INFO] ILP function run time: 0.247620
# [INFO] ILP function run time: 0.311328
# [INFO] ILP function run time: 0.248131
# [INFO] ILP function run time: 0.166743
# [INFO] ILP function run time: 0.250172
# [INFO] ILP function run time: 0.281483
# [INFO] ILP function run time: 0.293260
# [INFO] ILP function run time: 0.281188
# [INFO] ILP function run time: 0.314098
# [INFO] ILP function run time: 0.248932
# [INFO] ILP function run time: 0.271621
# [INFO] ILP function run time: 0.199518
# [INFO] ILP function run time: 0.264781
# [INFO] ILP function run time: 0.228543
# [INFO] ILP function run time: 0.284049
# [INFO] ILP function run time: 0.526425
# [INFO] ILP function run time: 0.323172
# [OBJECTIVE] old cost: 407966.4152604337, new cost: 397615.4319964329
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 21 ...
# [INFO] KmeansClustering function run time: 0.581400
# [INFO] MiniWeightMatching function run time: 0.153972
# [INFO] ILP function run time: 0.255470
# [INFO] ILP function run time: 0.169665
# [INFO] ILP function run time: 0.175863
# [INFO] ILP function run time: 0.255064
# [INFO] ILP function run time: 0.262990
# [INFO] ILP function run time: 0.518726
# [INFO] ILP function run time: 0.323418
# [INFO] ILP function run time: 0.210788
# [INFO] ILP function run time: 0.286257
# [INFO] ILP function run time: 0.185213
# [INFO] ILP function run time: 0.386575
# [INFO] ILP function run time: 0.201840
# [INFO] ILP function run time: 0.224083
# [INFO] ILP function run time: 0.152073
# [INFO] ILP function run time: 0.328358
# [INFO] ILP function run time: 0.386118
# [INFO] ILP function run time: 0.210098
# [INFO] ILP function run time: 0.220141
# [INFO] ILP function run time: 0.216781
# [INFO] ILP function run time: 0.217091
# [INFO] ILP function run time: 0.190720
# [INFO] ILP function run time: 0.254889
# [INFO] ILP function run time: 0.343834
# [INFO] ILP function run time: 0.765453
# [INFO] ILP function run time: 0.251729
# [INFO] ILP function run time: 0.184117
# [INFO] ILP function run time: 0.192877
# [INFO] ILP function run time: 0.198951
# [INFO] ILP function run time: 0.198445
# [INFO] ILP function run time: 0.266720
# [INFO] ILP function run time: 0.254276
# [INFO] ILP function run time: 0.203816
# [INFO] ILP function run time: 0.286519
# [INFO] ILP function run time: 0.147643
# [INFO] ILP function run time: 0.151058
# [INFO] ILP function run time: 0.171401
# [OBJECTIVE] old cost: 397615.4319964329, new cost: 390214.5179200712
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 22 ...
# [INFO] KmeansClustering function run time: 0.846546
# [INFO] MiniWeightMatching function run time: 0.499285
# [INFO] ILP function run time: 0.337980
# [INFO] ILP function run time: 0.511105
# [INFO] ILP function run time: 0.186169
# [INFO] ILP function run time: 0.212008
# [INFO] ILP function run time: 0.279827
# [INFO] ILP function run time: 0.281166
# [INFO] ILP function run time: 0.202649
# [INFO] ILP function run time: 0.197341
# [INFO] ILP function run time: 0.158253
# [INFO] ILP function run time: 0.135971
# [INFO] ILP function run time: 0.177899
# [INFO] ILP function run time: 0.361191
# [INFO] ILP function run time: 0.221366
# [INFO] ILP function run time: 0.243945
# [INFO] ILP function run time: 0.154348
# [INFO] ILP function run time: 0.221266
# [INFO] ILP function run time: 0.230911
# [INFO] ILP function run time: 0.258268
# [INFO] ILP function run time: 0.283839
# [INFO] ILP function run time: 0.304370
# [INFO] ILP function run time: 0.180606
# [INFO] ILP function run time: 0.178645
# [INFO] ILP function run time: 0.178933
# [INFO] ILP function run time: 0.240055
# [INFO] ILP function run time: 0.331288
# [INFO] ILP function run time: 0.124890
# [INFO] ILP function run time: 0.220501
# [INFO] ILP function run time: 0.239229
# [INFO] ILP function run time: 0.294823
# [INFO] ILP function run time: 0.165297
# [INFO] ILP function run time: 0.276700
# [INFO] ILP function run time: 0.254191
# [INFO] ILP function run time: 0.315910
# [INFO] ILP function run time: 0.215360
# [INFO] ILP function run time: 0.235001
# [INFO] ILP function run time: 0.202875
# [INFO] ILP function run time: 0.168857
# [OBJECTIVE] old cost: 390214.5179200712, new cost: 387913.44964742183
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 23 ...
# [INFO] KmeansClustering function run time: 0.620943
# [INFO] MiniWeightMatching function run time: 0.167922
# [INFO] ILP function run time: 0.172994
# [INFO] ILP function run time: 0.181163
# [INFO] ILP function run time: 0.217574
# [INFO] ILP function run time: 0.166413
# [INFO] ILP function run time: 0.245552
# [INFO] ILP function run time: 0.170805
# [INFO] ILP function run time: 0.224671
# [INFO] ILP function run time: 0.169958
# [INFO] ILP function run time: 0.196266
# [INFO] ILP function run time: 0.231986
# [INFO] ILP function run time: 0.163501
# [INFO] ILP function run time: 0.188778
# [INFO] ILP function run time: 0.200681
# [INFO] ILP function run time: 0.211557
# [INFO] ILP function run time: 0.189485
# [INFO] ILP function run time: 0.228370
# [INFO] ILP function run time: 0.157392
# [INFO] ILP function run time: 0.175245
# [INFO] ILP function run time: 0.267735
# [INFO] ILP function run time: 0.162362
# [INFO] ILP function run time: 0.149945
# [INFO] ILP function run time: 0.419077
# [INFO] ILP function run time: 0.136168
# [INFO] ILP function run time: 0.253487
# [INFO] ILP function run time: 0.167728
# [INFO] ILP function run time: 0.200657
# [INFO] ILP function run time: 0.259645
# [INFO] ILP function run time: 0.268536
# [INFO] ILP function run time: 0.290372
# [INFO] ILP function run time: 0.204957
# [INFO] ILP function run time: 0.165576
# [INFO] ILP function run time: 0.200937
# [INFO] ILP function run time: 0.283969
# [INFO] ILP function run time: 0.219590
# [INFO] ILP function run time: 0.241979
# [INFO] ILP function run time: 0.257684
# [INFO] ILP function run time: 0.304327
# [INFO] ILP function run time: 0.177802
# [OBJECTIVE] old cost: 387913.44964742183, new cost: 380562.3396295285
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 24 ...
# [INFO] KmeansClustering function run time: 0.978004
# [INFO] MiniWeightMatching function run time: 0.186073
# [INFO] ILP function run time: 0.267483
# [INFO] ILP function run time: 0.154970
# [INFO] ILP function run time: 0.262977
# [INFO] ILP function run time: 0.167859
# [INFO] ILP function run time: 0.260163
# [INFO] ILP function run time: 0.149858
# [INFO] ILP function run time: 0.166603
# [INFO] ILP function run time: 0.228722
# [INFO] ILP function run time: 0.130993
# [INFO] ILP function run time: 0.107073
# [INFO] ILP function run time: 0.205815
# [INFO] ILP function run time: 0.165580
# [INFO] ILP function run time: 0.189524
# [INFO] ILP function run time: 0.217381
# [INFO] ILP function run time: 0.225131
# [INFO] ILP function run time: 0.170436
# [INFO] ILP function run time: 0.209925
# [INFO] ILP function run time: 0.166493
# [INFO] ILP function run time: 0.175022
# [INFO] ILP function run time: 0.389182
# [INFO] ILP function run time: 0.132369
# [INFO] ILP function run time: 0.199617
# [INFO] ILP function run time: 0.468892
# [INFO] ILP function run time: 0.167166
# [INFO] ILP function run time: 0.139798
# [INFO] ILP function run time: 0.212729
# [INFO] ILP function run time: 0.156566
# [INFO] ILP function run time: 0.205813
# [INFO] ILP function run time: 0.215219
# [INFO] ILP function run time: 0.162243
# [INFO] ILP function run time: 0.184940
# [INFO] ILP function run time: 0.226920
# [INFO] ILP function run time: 0.193219
# [INFO] ILP function run time: 0.251117
# [INFO] ILP function run time: 0.323775
# [INFO] ILP function run time: 0.211735
# [INFO] ILP function run time: 0.319443
# [INFO] ILP function run time: 0.140722
# [INFO] ILP function run time: 0.203474
# [OBJECTIVE] old cost: 380562.3396295285, new cost: 380210.70622964523
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 25 ...
# [INFO] KmeansClustering function run time: 0.775138
# [INFO] MiniWeightMatching function run time: 0.401885
# [INFO] ILP function run time: 0.148934
# [INFO] ILP function run time: 0.241355
# [INFO] ILP function run time: 0.226373
# [INFO] ILP function run time: 0.219276
# [INFO] ILP function run time: 0.220755
# [INFO] ILP function run time: 0.476686
# [INFO] ILP function run time: 0.215096
# [INFO] ILP function run time: 0.178196
# [INFO] ILP function run time: 0.123665
# [INFO] ILP function run time: 0.209109
# [INFO] ILP function run time: 0.171405
# [INFO] ILP function run time: 0.206453
# [INFO] ILP function run time: 0.205813
# [INFO] ILP function run time: 0.148385
# [INFO] ILP function run time: 0.197191
# [INFO] ILP function run time: 0.177803
# [INFO] ILP function run time: 0.461574
# [INFO] ILP function run time: 0.173433
# [INFO] ILP function run time: 0.167214
# [INFO] ILP function run time: 0.230900
# [INFO] ILP function run time: 0.155135
# [INFO] ILP function run time: 0.168947
# [INFO] ILP function run time: 0.157423
# [INFO] ILP function run time: 0.161212
# [INFO] ILP function run time: 0.160088
# [INFO] ILP function run time: 0.187710
# [INFO] ILP function run time: 0.187298
# [INFO] ILP function run time: 0.202347
# [INFO] ILP function run time: 0.141137
# [INFO] ILP function run time: 0.218371
# [INFO] ILP function run time: 0.156557
# [INFO] ILP function run time: 0.307229
# [INFO] ILP function run time: 0.216436
# [INFO] ILP function run time: 0.152573
# [INFO] ILP function run time: 0.186891
# [INFO] ILP function run time: 0.749535
# [INFO] ILP function run time: 0.143016
# [INFO] ILP function run time: 0.217860
# [INFO] ILP function run time: 0.201563
# [INFO] ILP function run time: 0.132394
# [OBJECTIVE] old cost: 380210.70622964523, new cost: 369060.3207962878
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 26 ...
# [INFO] KmeansClustering function run time: 0.716783
# [INFO] MiniWeightMatching function run time: 0.184215
# [INFO] ILP function run time: 0.153571
# [INFO] ILP function run time: 0.187464
# [INFO] ILP function run time: 0.253561
# [INFO] ILP function run time: 0.211610
# [INFO] ILP function run time: 0.167299
# [INFO] ILP function run time: 0.198767
# [INFO] ILP function run time: 0.138238
# [INFO] ILP function run time: 0.125757
# [INFO] ILP function run time: 0.181873
# [INFO] ILP function run time: 0.155958
# [INFO] ILP function run time: 0.147101
# [INFO] ILP function run time: 0.163283
# [INFO] ILP function run time: 0.430371
# [INFO] ILP function run time: 0.154939
# [INFO] ILP function run time: 0.153998
# [INFO] ILP function run time: 0.108088
# [INFO] ILP function run time: 0.186538
# [INFO] ILP function run time: 0.126079
# [INFO] ILP function run time: 0.215175
# [INFO] ILP function run time: 0.140035
# [INFO] ILP function run time: 0.173334
# [INFO] ILP function run time: 0.172728
# [INFO] ILP function run time: 0.194139
# [INFO] ILP function run time: 0.177409
# [INFO] ILP function run time: 0.160694
# [INFO] ILP function run time: 0.143900
# [INFO] ILP function run time: 0.374435
# [INFO] ILP function run time: 0.438557
# [INFO] ILP function run time: 0.439710
# [INFO] ILP function run time: 0.127718
# [INFO] ILP function run time: 0.191599
# [INFO] ILP function run time: 0.179934
# [INFO] ILP function run time: 0.161664
# [INFO] ILP function run time: 0.225543
# [INFO] ILP function run time: 0.177526
# [INFO] ILP function run time: 0.156630
# [INFO] ILP function run time: 0.128780
# [INFO] ILP function run time: 0.195933
# [INFO] ILP function run time: 0.173529
# [INFO] ILP function run time: 0.160492
# [INFO] ILP function run time: 0.155366
# [OBJECTIVE] old cost: 369060.3207962878, new cost: 364559.25485164317
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 27 ...
# [INFO] KmeansClustering function run time: 0.728820
# [INFO] MiniWeightMatching function run time: 0.512302
# [INFO] ILP function run time: 0.138717
# [INFO] ILP function run time: 0.183287
# [INFO] ILP function run time: 0.198328
# [INFO] ILP function run time: 0.151328
# [INFO] ILP function run time: 0.156622
# [INFO] ILP function run time: 0.118353
# [INFO] ILP function run time: 0.167373
# [INFO] ILP function run time: 0.198669
# [INFO] ILP function run time: 0.193611
# [INFO] ILP function run time: 0.188720
# [INFO] ILP function run time: 0.216450
# [INFO] ILP function run time: 0.175987
# [INFO] ILP function run time: 0.150362
# [INFO] ILP function run time: 0.142091
# [INFO] ILP function run time: 0.175793
# [INFO] ILP function run time: 0.197061
# [INFO] ILP function run time: 0.186439
# [INFO] ILP function run time: 0.178030
# [INFO] ILP function run time: 0.199628
# [INFO] ILP function run time: 0.419803
# [INFO] ILP function run time: 0.149722
# [INFO] ILP function run time: 0.179246
# [INFO] ILP function run time: 0.139032
# [INFO] ILP function run time: 0.155436
# [INFO] ILP function run time: 0.125981
# [INFO] ILP function run time: 0.160772
# [INFO] ILP function run time: 0.412429
# [INFO] ILP function run time: 0.140940
# [INFO] ILP function run time: 0.159729
# [INFO] ILP function run time: 0.157052
# [INFO] ILP function run time: 0.412967
# [INFO] ILP function run time: 0.191520
# [INFO] ILP function run time: 0.155295
# [INFO] ILP function run time: 0.170793
# [INFO] ILP function run time: 0.143969
# [INFO] ILP function run time: 0.123630
# [INFO] ILP function run time: 0.189940
# [INFO] ILP function run time: 0.161221
# [INFO] ILP function run time: 0.113047
# [INFO] ILP function run time: 0.177241
# [INFO] ILP function run time: 0.136454
# [INFO] ILP function run time: 0.138947
# [OBJECTIVE] old cost: 364559.25485164317, new cost: 363357.454701955
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 28 ...
# [INFO] KmeansClustering function run time: 0.771501
# [INFO] MiniWeightMatching function run time: 0.183392
# [INFO] ILP function run time: 0.135242
# [INFO] ILP function run time: 0.194518
# [INFO] ILP function run time: 0.142315
# [INFO] ILP function run time: 0.171761
# [INFO] ILP function run time: 0.158258
# [INFO] ILP function run time: 0.183021
# [INFO] ILP function run time: 0.104920
# [INFO] ILP function run time: 0.168608
# [INFO] ILP function run time: 0.166573
# [INFO] ILP function run time: 0.163462
# [INFO] ILP function run time: 0.123783
# [INFO] ILP function run time: 0.132843
# [INFO] ILP function run time: 0.436014
# [INFO] ILP function run time: 0.161834
# [INFO] ILP function run time: 0.152183
# [INFO] ILP function run time: 0.174365
# [INFO] ILP function run time: 0.181547
# [INFO] ILP function run time: 0.181532
# [INFO] ILP function run time: 0.126318
# [INFO] ILP function run time: 0.141365
# [INFO] ILP function run time: 0.152159
# [INFO] ILP function run time: 0.140864
# [INFO] ILP function run time: 0.180259
# [INFO] ILP function run time: 0.144858
# [INFO] ILP function run time: 0.147546
# [INFO] ILP function run time: 0.103024
# [INFO] ILP function run time: 0.144057
# [INFO] ILP function run time: 0.418515
# [INFO] ILP function run time: 0.130910
# [INFO] ILP function run time: 0.126541
# [INFO] ILP function run time: 0.198160
# [INFO] ILP function run time: 0.163876
# [INFO] ILP function run time: 0.178819
# [INFO] ILP function run time: 0.174224
# [INFO] ILP function run time: 0.162437
# [INFO] ILP function run time: 0.177217
# [INFO] ILP function run time: 0.178165
# [INFO] ILP function run time: 0.168948
# [INFO] ILP function run time: 0.176530
# [INFO] ILP function run time: 0.199244
# [INFO] ILP function run time: 0.169801
# [INFO] ILP function run time: 0.193935
# [INFO] ILP function run time: 0.186272
# [OBJECTIVE] old cost: 363357.454701955, new cost: 355607.11660895543
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 29 ...
# [INFO] KmeansClustering function run time: 0.745687
# [INFO] MiniWeightMatching function run time: 0.184872
# [INFO] ILP function run time: 0.168299
# [INFO] ILP function run time: 0.146600
# [INFO] ILP function run time: 0.115989
# [INFO] ILP function run time: 0.111375
# [INFO] ILP function run time: 0.152750
# [INFO] ILP function run time: 0.163131
# [INFO] ILP function run time: 0.202528
# [INFO] ILP function run time: 0.147473
# [INFO] ILP function run time: 0.202545
# [INFO] ILP function run time: 0.413401
# [INFO] ILP function run time: 0.150055
# [INFO] ILP function run time: 0.907706
# [INFO] ILP function run time: 0.318446
# [INFO] ILP function run time: 0.966658
# [INFO] ILP function run time: 0.176504
# [INFO] ILP function run time: 1.658471
# [INFO] ILP function run time: 0.309569
# [INFO] ILP function run time: 0.122258
# [INFO] ILP function run time: 0.260339
# [INFO] ILP function run time: 0.126862
# [INFO] ILP function run time: 0.333077
# [INFO] ILP function run time: 0.257739
# [INFO] ILP function run time: 0.375478
# [INFO] ILP function run time: 0.587950
# [INFO] ILP function run time: 0.290906
# [INFO] ILP function run time: 0.156231
# [INFO] ILP function run time: 0.400294
# [INFO] ILP function run time: 0.142254
# [INFO] ILP function run time: 0.280410
# [INFO] ILP function run time: 0.197585
# [INFO] ILP function run time: 0.231614
# [INFO] ILP function run time: 0.129179
# [INFO] ILP function run time: 0.149704
# [INFO] ILP function run time: 0.141566
# [INFO] ILP function run time: 0.130071
# [INFO] ILP function run time: 0.163688
# [INFO] ILP function run time: 0.143216
# [INFO] ILP function run time: 0.165913
# [INFO] ILP function run time: 0.125843
# [INFO] ILP function run time: 0.157765
# [INFO] ILP function run time: 0.156926
# [INFO] ILP function run time: 0.170803
# [INFO] ILP function run time: 0.222843
# [INFO] ILP function run time: 0.121388
# [OBJECTIVE] old cost: 355607.11660895543, new cost: 354656.17948685057
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 30 ...
# [INFO] KmeansClustering function run time: 0.728504
# [INFO] MiniWeightMatching function run time: 0.425823
# [INFO] ILP function run time: 0.145916
# [INFO] ILP function run time: 0.120509
# [INFO] ILP function run time: 0.128773
# [INFO] ILP function run time: 0.135943
# [INFO] ILP function run time: 0.115878
# [INFO] ILP function run time: 0.154439
# [INFO] ILP function run time: 0.147771
# [INFO] ILP function run time: 0.186354
# [INFO] ILP function run time: 0.174697
# [INFO] ILP function run time: 0.446921
# [INFO] ILP function run time: 0.193189
# [INFO] ILP function run time: 0.160006
# [INFO] ILP function run time: 0.129135
# [INFO] ILP function run time: 0.199239
# [INFO] ILP function run time: 0.150395
# [INFO] ILP function run time: 0.180868
# [INFO] ILP function run time: 0.172480
# [INFO] ILP function run time: 0.158591
# [INFO] ILP function run time: 0.156243
# [INFO] ILP function run time: 0.131999
# [INFO] ILP function run time: 0.148712
# [INFO] ILP function run time: 0.155021
# [INFO] ILP function run time: 0.124177
# [INFO] ILP function run time: 0.120715
# [INFO] ILP function run time: 0.127529
# [INFO] ILP function run time: 0.157455
# [INFO] ILP function run time: 0.164259
# [INFO] ILP function run time: 0.134467
# [INFO] ILP function run time: 0.386258
# [INFO] ILP function run time: 0.130487
# [INFO] ILP function run time: 0.171006
# [INFO] ILP function run time: 0.159198
# [INFO] ILP function run time: 0.407404
# [INFO] ILP function run time: 0.403694
# [INFO] ILP function run time: 0.178978
# [INFO] ILP function run time: 0.417535
# [INFO] ILP function run time: 0.169421
# [INFO] ILP function run time: 0.106106
# [INFO] ILP function run time: 0.160898
# [INFO] ILP function run time: 0.185405
# [INFO] ILP function run time: 0.151434
# [INFO] ILP function run time: 0.158668
# [INFO] ILP function run time: 0.127332
# [INFO] ILP function run time: 0.120165
# [INFO] ILP function run time: 0.143607
# [OBJECTIVE] old cost: 354656.17948685057, new cost: 353205.24425982917
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 31 ...
# [INFO] KmeansClustering function run time: 0.774979
# [INFO] MiniWeightMatching function run time: 0.531892
# [INFO] ILP function run time: 0.420035
# [INFO] ILP function run time: 0.178230
# [INFO] ILP function run time: 0.168033
# [INFO] ILP function run time: 0.124818
# [INFO] ILP function run time: 0.128354
# [INFO] ILP function run time: 0.134094
# [INFO] ILP function run time: 0.135766
# [INFO] ILP function run time: 0.169878
# [INFO] ILP function run time: 0.140152
# [INFO] ILP function run time: 0.172070
# [INFO] ILP function run time: 0.127111
# [INFO] ILP function run time: 0.126743
# [INFO] ILP function run time: 0.131038
# [INFO] ILP function run time: 0.171121
# [INFO] ILP function run time: 0.144735
# [INFO] ILP function run time: 0.148459
# [INFO] ILP function run time: 0.141504
# [INFO] ILP function run time: 0.112755
# [INFO] ILP function run time: 0.197296
# [INFO] ILP function run time: 0.126834
# [INFO] ILP function run time: 0.155173
# [INFO] ILP function run time: 0.108414
# [INFO] ILP function run time: 0.111433
# [INFO] ILP function run time: 0.158651
# [INFO] ILP function run time: 0.151664
# [INFO] ILP function run time: 0.117915
# [INFO] ILP function run time: 0.098776
# [INFO] ILP function run time: 0.147632
# [INFO] ILP function run time: 0.177094
# [INFO] ILP function run time: 0.157756
# [INFO] ILP function run time: 0.153947
# [INFO] ILP function run time: 0.140419
# [INFO] ILP function run time: 0.178931
# [INFO] ILP function run time: 0.166345
# [INFO] ILP function run time: 0.199999
# [INFO] ILP function run time: 0.112224
# [INFO] ILP function run time: 0.198918
# [INFO] ILP function run time: 0.396956
# [INFO] ILP function run time: 0.128250
# [INFO] ILP function run time: 0.098722
# [INFO] ILP function run time: 0.147338
# [INFO] ILP function run time: 0.148046
# [INFO] ILP function run time: 0.156156
# [INFO] ILP function run time: 0.106201
# [INFO] ILP function run time: 0.177594
# [INFO] ILP function run time: 0.089152
# [OBJECTIVE] old cost: 353205.24425982917, new cost: 348054.4565524659
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 32 ...
# [INFO] KmeansClustering function run time: 0.726531
# [INFO] MiniWeightMatching function run time: 0.424590
# [INFO] ILP function run time: 0.131984
# [INFO] ILP function run time: 0.149097
# [INFO] ILP function run time: 0.145125
# [INFO] ILP function run time: 0.129290
# [INFO] ILP function run time: 0.059153
# [INFO] ILP function run time: 0.137450
# [INFO] ILP function run time: 0.103055
# [INFO] ILP function run time: 0.155165
# [INFO] ILP function run time: 0.141350
# [INFO] ILP function run time: 0.140014
# [INFO] ILP function run time: 0.170704
# [INFO] ILP function run time: 0.115114
# [INFO] ILP function run time: 0.141943
# [INFO] ILP function run time: 0.136271
# [INFO] ILP function run time: 0.188643
# [INFO] ILP function run time: 0.156697
# [INFO] ILP function run time: 0.179282
# [INFO] ILP function run time: 0.203453
# [INFO] ILP function run time: 0.144165
# [INFO] ILP function run time: 0.125933
# [INFO] ILP function run time: 0.140567
# [INFO] ILP function run time: 0.069816
# [INFO] ILP function run time: 0.478937
# [INFO] ILP function run time: 0.168030
# [INFO] ILP function run time: 0.181842
# [INFO] ILP function run time: 0.156341
# [INFO] ILP function run time: 0.156323
# [INFO] ILP function run time: 0.151376
# [INFO] ILP function run time: 0.088813
# [INFO] ILP function run time: 0.160258
# [INFO] ILP function run time: 0.161145
# [INFO] ILP function run time: 0.147599
# [INFO] ILP function run time: 0.128238
# [INFO] ILP function run time: 0.167757
# [INFO] ILP function run time: 0.126265
# [INFO] ILP function run time: 0.141319
# [INFO] ILP function run time: 0.404746
# [INFO] ILP function run time: 0.151031
# [INFO] ILP function run time: 0.128494
# [INFO] ILP function run time: 0.123766
# [INFO] ILP function run time: 0.132703
# [INFO] ILP function run time: 0.122516
# [INFO] ILP function run time: 0.145574
# [INFO] ILP function run time: 0.093513
# [INFO] ILP function run time: 0.197124
# [INFO] ILP function run time: 0.101770
# [INFO] ILP function run time: 0.124212
# [OBJECTIVE] old cost: 348054.4565524659, new cost: 345903.46130118327
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 33 ...
# [INFO] KmeansClustering function run time: 0.787184
# [INFO] MiniWeightMatching function run time: 0.546147
# [INFO] ILP function run time: 0.128972
# [INFO] ILP function run time: 0.173821
# [INFO] ILP function run time: 0.121124
# [INFO] ILP function run time: 0.109690
# [INFO] ILP function run time: 0.132223
# [INFO] ILP function run time: 0.147979
# [INFO] ILP function run time: 0.156437
# [INFO] ILP function run time: 0.128453
# [INFO] ILP function run time: 0.117831
# [INFO] ILP function run time: 0.155951
# [INFO] ILP function run time: 0.118763
# [INFO] ILP function run time: 0.166420
# [INFO] ILP function run time: 0.128159
# [INFO] ILP function run time: 0.135527
# [INFO] ILP function run time: 0.123755
# [INFO] ILP function run time: 0.136225
# [INFO] ILP function run time: 0.144059
# [INFO] ILP function run time: 0.179428
# [INFO] ILP function run time: 0.137198
# [INFO] ILP function run time: 0.126937
# [INFO] ILP function run time: 0.151438
# [INFO] ILP function run time: 0.126670
# [INFO] ILP function run time: 0.123042
# [INFO] ILP function run time: 0.146126
# [INFO] ILP function run time: 0.141668
# [INFO] ILP function run time: 0.425955
# [INFO] ILP function run time: 0.152884
# [INFO] ILP function run time: 0.169675
# [INFO] ILP function run time: 0.094558
# [INFO] ILP function run time: 0.115209
# [INFO] ILP function run time: 0.110434
# [INFO] ILP function run time: 0.119495
# [INFO] ILP function run time: 0.149375
# [INFO] ILP function run time: 0.133415
# [INFO] ILP function run time: 0.108860
# [INFO] ILP function run time: 0.119638
# [INFO] ILP function run time: 0.120815
# [INFO] ILP function run time: 0.144082
# [INFO] ILP function run time: 0.442094
# [INFO] ILP function run time: 0.121932
# [INFO] ILP function run time: 0.414864
# [INFO] ILP function run time: 0.173731
# [INFO] ILP function run time: 0.126437
# [INFO] ILP function run time: 0.159756
# [INFO] ILP function run time: 0.123856
# [INFO] ILP function run time: 0.151426
# [INFO] ILP function run time: 0.148990
# [INFO] ILP function run time: 0.096974
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 345903.46130118327.
# [Result]: Installation Cost: 94000 Transmission Cost: 53.461301183269825 Delay Cost 251850.0 Total Cost 345903.46130118327

# %%
ha_nmaxss.InitializeCleanEnvironment()
ha_nmaxss.ManualChangeParameter(N_MAX_SS = 10, D_MAX = 100, c = 5, alpha = 2)
ha_nmaxss.OurHeuristic(clustering_type = 'kmeans', custom_metric = 'eu')
# Out:
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.127975
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.123728
# [INFO] MiniWeightMatching function run time: 0.028328
# [INFO] ILP function run time: 2.413982
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.144537
# [INFO] MiniWeightMatching function run time: 0.038079
# [INFO] ILP function run time: 1.338976
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.171775
# [INFO] MiniWeightMatching function run time: 0.035300
# [INFO] ILP function run time: 0.898947
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.227062
# [INFO] MiniWeightMatching function run time: 0.040389
# [INFO] ILP function run time: 0.897927
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.216453
# [INFO] MiniWeightMatching function run time: 0.044637
# [INFO] ILP function run time: 1.001004
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.218884
# [INFO] MiniWeightMatching function run time: 0.045989
# [INFO] ILP function run time: 1.244108
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.318569
# [INFO] MiniWeightMatching function run time: 0.051887
# [INFO] ILP function run time: 1.071611
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.291993
# [INFO] MiniWeightMatching function run time: 0.052973
# [INFO] ILP function run time: 0.603084
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.287236
# [INFO] MiniWeightMatching function run time: 0.058980
# [INFO] ILP function run time: 0.777467
# [INFO] ILP function run time: 0.632820
# [INFO] ILP function run time: 0.791286
# [INFO] ILP function run time: 1.005568
# [INFO] ILP function run time: 0.800662
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.333438
# [INFO] MiniWeightMatching function run time: 0.095971
# [INFO] ILP function run time: 0.436396
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.343997
# [INFO] MiniWeightMatching function run time: 0.068104
# [INFO] ILP function run time: 0.865330
# [INFO] ILP function run time: 0.878955
# [INFO] ILP function run time: 1.211401
# [INFO] ILP function run time: 0.660179
# [INFO] ILP function run time: 0.605208
# [INFO] ILP function run time: 0.846926
# [INFO] ILP function run time: 0.558105
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.438879
# [INFO] MiniWeightMatching function run time: 0.075474
# [INFO] ILP function run time: 1.012443
# [INFO] ILP function run time: 0.738857
# [INFO] ILP function run time: 0.961635
# [INFO] ILP function run time: 0.681603
# [INFO] ILP function run time: 0.867703
# [INFO] ILP function run time: 0.996517
# [INFO] ILP function run time: 0.932508
# [INFO] ILP function run time: 0.517564
# [INFO] ILP function run time: 0.952798
# [INFO] ILP function run time: 0.611256
# [INFO] ILP function run time: 0.778146
# [INFO] ILP function run time: 0.843293
# [INFO] ILP function run time: 0.632191
# [INFO] ILP function run time: 0.659339
# [INFO] ILP function run time: 0.554051
# [INFO] ILP function run time: 0.941515
# [OBJECTIVE] old cost: inf, new cost: 92941.3531567062
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] KmeansClustering function run time: 0.475350
# [INFO] MiniWeightMatching function run time: 0.505448
# [INFO] ILP function run time: 0.535265
# [INFO] ILP function run time: 0.494307
# [INFO] ILP function run time: 0.780168
# [INFO] ILP function run time: 0.831232
# [INFO] ILP function run time: 0.780576
# [INFO] ILP function run time: 0.615572
# [INFO] ILP function run time: 0.779867
# [INFO] ILP function run time: 0.497300
# [INFO] ILP function run time: 0.650345
# [INFO] ILP function run time: 0.471121
# [INFO] ILP function run time: 0.627720
# [INFO] ILP function run time: 1.051336
# [INFO] ILP function run time: 0.479901
# [INFO] ILP function run time: 0.523488
# [INFO] ILP function run time: 0.547144
# [INFO] ILP function run time: 1.759870
# [INFO] ILP function run time: 1.026809
# [OBJECTIVE] old cost: 92941.3531567062, new cost: 92301.30961770797
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] KmeansClustering function run time: 0.366848
# [INFO] MiniWeightMatching function run time: 0.088126
# [INFO] ILP function run time: 0.539469
# [INFO] ILP function run time: 0.847931
# [INFO] ILP function run time: 0.865412
# [INFO] ILP function run time: 0.824539
# [INFO] ILP function run time: 0.518691
# [INFO] ILP function run time: 0.595011
# [INFO] ILP function run time: 0.508751
# [INFO] ILP function run time: 0.384988
# [INFO] ILP function run time: 0.831862
# [INFO] ILP function run time: 0.527642
# [INFO] ILP function run time: 0.923433
# [INFO] ILP function run time: 0.790847
# [INFO] ILP function run time: 0.716390
# [INFO] ILP function run time: 1.064932
# [INFO] ILP function run time: 0.567181
# [INFO] ILP function run time: 0.861093
# [INFO] ILP function run time: 0.586957
# [INFO] ILP function run time: 0.518490
# [OBJECTIVE] old cost: 92301.30961770797, new cost: 92061.2612158294
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] KmeansClustering function run time: 0.458911
# [INFO] MiniWeightMatching function run time: 0.100214
# [INFO] ILP function run time: 0.551889
# [INFO] ILP function run time: 0.685486
# [INFO] ILP function run time: 0.465586
# [INFO] ILP function run time: 0.534388
# [INFO] ILP function run time: 0.911287
# [INFO] ILP function run time: 0.669416
# [INFO] ILP function run time: 0.629048
# [INFO] ILP function run time: 0.514992
# [INFO] ILP function run time: 0.424494
# [INFO] ILP function run time: 0.540247
# [INFO] ILP function run time: 0.553833
# [INFO] ILP function run time: 0.698399
# [INFO] ILP function run time: 0.644571
# [INFO] ILP function run time: 0.504301
# [INFO] ILP function run time: 0.612613
# [INFO] ILP function run time: 0.929950
# [INFO] ILP function run time: 0.521290
# [INFO] ILP function run time: 0.632496
# [INFO] ILP function run time: 0.475699
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 92061.2612158294.
# [Result]: Installation Cost: 36000 Transmission Cost: 1.261215829406865 Delay Cost 56060.0 Total Cost 92061.2612158294

# %%
ha_nmaxss.InitializeCleanEnvironment()
ha_nmaxss.ManualChangeParameter(N_MAX_SS = 10, D_MAX = 100, c = 5, alpha = 4)
ha_nmaxss.OurHeuristic(clustering_type = 'kmeans', custom_metric = 'eu')
# Out:
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.129371
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.130710
# [INFO] MiniWeightMatching function run time: 0.032669
# [INFO] ILP function run time: 2.411686
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.172343
# [INFO] MiniWeightMatching function run time: 0.030621
# [INFO] ILP function run time: 1.488692
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.231694
# [INFO] MiniWeightMatching function run time: 0.041918
# [INFO] ILP function run time: 1.102360
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.281159
# [INFO] MiniWeightMatching function run time: 0.067159
# [INFO] ILP function run time: 1.079264
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.292124
# [INFO] MiniWeightMatching function run time: 0.049602
# [INFO] ILP function run time: 1.081904
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.219177
# [INFO] MiniWeightMatching function run time: 0.045988
# [INFO] ILP function run time: 0.827418
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.237242
# [INFO] MiniWeightMatching function run time: 0.052394
# [INFO] ILP function run time: 0.776308
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.274389
# [INFO] MiniWeightMatching function run time: 0.058800
# [INFO] ILP function run time: 0.596867
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.254879
# [INFO] MiniWeightMatching function run time: 0.218813
# [INFO] ILP function run time: 1.191107
# [INFO] ILP function run time: 0.662883
# [INFO] ILP function run time: 0.796611
# [INFO] ILP function run time: 1.501203
# [INFO] ILP function run time: 1.075356
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.354579
# [INFO] MiniWeightMatching function run time: 0.067039
# [INFO] ILP function run time: 0.697128
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.390517
# [INFO] MiniWeightMatching function run time: 0.246263
# [INFO] ILP function run time: 0.786834
# [INFO] ILP function run time: 0.678048
# [INFO] ILP function run time: 0.578767
# [INFO] ILP function run time: 0.625459
# [INFO] ILP function run time: 0.595727
# [INFO] ILP function run time: 1.047900
# [INFO] ILP function run time: 1.030670
# [ITERATION] Start iteration 1 ...
# [INFO] KmeansClustering function run time: 0.393604
# [INFO] MiniWeightMatching function run time: 0.069724
# [INFO] ILP function run time: 0.676788
# [INFO] ILP function run time: 0.572773
# [INFO] ILP function run time: 1.058762
# [INFO] ILP function run time: 0.943224
# [INFO] ILP function run time: 1.119174
# [INFO] ILP function run time: 0.815427
# [INFO] ILP function run time: 0.636700
# [INFO] ILP function run time: 4.210040
# [INFO] ILP function run time: 0.876245
# [INFO] ILP function run time: 1.155202
# [INFO] ILP function run time: 0.589778
# [INFO] ILP function run time: 0.972701
# [INFO] ILP function run time: 0.758218
# [INFO] ILP function run time: 0.679068
# [INFO] ILP function run time: 0.633449
# [INFO] ILP function run time: 0.930458
# [OBJECTIVE] old cost: inf, new cost: 102288.76685888495
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 2 ...
# [INFO] KmeansClustering function run time: 0.509618
# [INFO] MiniWeightMatching function run time: 0.255610
# [INFO] ILP function run time: 0.657033
# [INFO] ILP function run time: 0.550984
# [INFO] ILP function run time: 0.561721
# [INFO] ILP function run time: 0.882695
# [INFO] ILP function run time: 0.599180
# [INFO] ILP function run time: 0.614584
# [INFO] ILP function run time: 0.839865
# [INFO] ILP function run time: 0.520875
# [INFO] ILP function run time: 0.634189
# [INFO] ILP function run time: 0.474612
# [INFO] ILP function run time: 0.574194
# [INFO] ILP function run time: 0.662846
# [INFO] ILP function run time: 0.480494
# [INFO] ILP function run time: 0.742076
# [INFO] ILP function run time: 0.497788
# [INFO] ILP function run time: 0.749547
# [INFO] ILP function run time: 0.558365
# [OBJECTIVE] old cost: 102288.76685888495, new cost: 101310.26495643923
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 3 ...
# [INFO] KmeansClustering function run time: 0.341755
# [INFO] MiniWeightMatching function run time: 0.434754
# [INFO] ILP function run time: 0.828726
# [INFO] ILP function run time: 0.488109
# [INFO] ILP function run time: 0.556185
# [INFO] ILP function run time: 0.631350
# [INFO] ILP function run time: 0.433890
# [INFO] ILP function run time: 0.508153
# [INFO] ILP function run time: 0.531552
# [INFO] ILP function run time: 0.411031
# [INFO] ILP function run time: 0.626596
# [INFO] ILP function run time: 0.430596
# [INFO] ILP function run time: 0.565906
# [INFO] ILP function run time: 0.496954
# [INFO] ILP function run time: 0.590133
# [INFO] ILP function run time: 0.721493
# [INFO] ILP function run time: 0.491798
# [INFO] ILP function run time: 0.564118
# [INFO] ILP function run time: 0.481100
# [INFO] ILP function run time: 0.585432
# [OBJECTIVE] old cost: 101310.26495643923, new cost: 100603.80322476222
# [DESCRIBE] Optimal route and lowest cost not found.
# [ITERATION] Start iteration 4 ...
# [INFO] KmeansClustering function run time: 0.343758
# [INFO] MiniWeightMatching function run time: 0.083719
# [INFO] ILP function run time: 0.833768
# [INFO] ILP function run time: 0.608090
# [INFO] ILP function run time: 0.409091
# [INFO] ILP function run time: 0.469665
# [INFO] ILP function run time: 0.631775
# [INFO] ILP function run time: 0.475737
# [INFO] ILP function run time: 0.742202
# [INFO] ILP function run time: 0.707708
# [INFO] ILP function run time: 0.391330
# [INFO] ILP function run time: 0.664477
# [INFO] ILP function run time: 0.434948
# [INFO] ILP function run time: 0.765849
# [INFO] ILP function run time: 0.491968
# [INFO] ILP function run time: 0.459455
# [INFO] ILP function run time: 0.558416
# [INFO] ILP function run time: 0.766935
# [INFO] ILP function run time: 0.437744
# [INFO] ILP function run time: 0.631385
# [INFO] ILP function run time: 0.510164
# [DESCRIBE] The best routing and lowest cost have been found. The minimum cost is 100603.80322476222.
# [Result]: Installation Cost: 36000 Transmission Cost: 8543.803224762218 Delay Cost 56060.0 Total Cost 100603.80322476222
